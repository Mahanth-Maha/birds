# %%
import pandas as pd

# %%
df1 = pd.read_csv('assets/birds.csv',index_col='ID')
df1.head(2)
# Out:
#    Common Bird Names
# ID
# 1   Abbott's babbler
# 2     Abbott's booby

# %%
# !pip install openpyxl
df2 = pd.read_excel('assets/DCPP_Group_Assignment/Birds_Dataset.xlsx',index_col='Common Name')
df2.head(2)
# Out:
#                             Serial No Conservation status   Kingdom    Phylum  \
# Common Name
# Abyssinian crimsonwing              1      Least Concern   Animalia  Chordata
# Abyssinian ground hornbill          2         Vulnerable   Animalia  Chordata
#
#                            Class           Order       Family        Genus  \
# Common Name
# Abyssinian crimsonwing      Aves   Passeriformes  Estrildidae  Cryptospiza
# Abyssinian ground hornbill  Aves  Bucerotiformes   Bucorvidae     Bucorvus
#
#                                    Species  \
# Common Name
# Abyssinian crimsonwing       C. salvadorii
# Abyssinian ground hornbill  B. abyssinicus
#
#                                                        Binomial Name  \
# Common Name
# Abyssinian crimsonwing      Cryptospiza salvadoriiReichenow, 1892[2]
# Abyssinian ground hornbill      Bucorvus abyssinicus(Boddaert, 1783)
#
#                                                                   Description  \
# Common Name
# Abyssinian crimsonwing      The Abyssinian crimsonwing (Cryptospiza salvad...
# Abyssinian ground hornbill  The Abyssinian ground hornbill or northern gro...
#
#                                                                    Categories  \
# Common Name
# Abyssinian crimsonwing      Articles with species microformats, Articles w...
# Abyssinian ground hornbill  Articles with species microformats, Articles w...
#
#                                                                    References  \
# Common Name
# Abyssinian crimsonwing      http://www.hbw.com/species/ethiopian-crimsonwi...
# Abyssinian ground hornbill  http://www.hbw.com/species/northern-ground-hor...
#
#                                                                      Wiki URL  \
# Common Name
# Abyssinian crimsonwing      https://en.wikipedia.org/wiki/Abyssinian_crims...
# Abyssinian ground hornbill  https://en.wikipedia.org/wiki/Abyssinian_groun...
#
#                                                                         Image  \
# Common Name
# Abyssinian crimsonwing      https://upload.wikimedia.org/wikipedia/commons...
# Abyssinian ground hornbill  https://upload.wikimedia.org/wikipedia/commons...
#
#                              Country Habitat
# Common Name
# Abyssinian crimsonwing      Ethiopia  forest
# Abyssinian ground hornbill       NaN     NaN

# %%
# Opening new dataset
df1 = pd.read_csv('assets/birds_attributed.csv',index_col='Name')
df1.index.names = ['Common Name']
df1.head(2)
# Out:
#                   Scientific Name  Other names  Country of origin  Species  \
# Common Name
# Abbott's babbler              NaN          NaN                NaN      NaN
# Abbott's booby                NaN          NaN                NaN      NaN
#
#                   Genera  Size  Family   Order  Order_count  Found_in  ...  \
# Common Name                                                            ...
# Abbott's babbler     NaN   NaN      NaN    NaN          NaN       NaN  ...
# Abbott's booby       NaN   NaN      NaN    NaN          NaN       NaN  ...
#
#                   Color  Food intake  Beaks  Age span  Hearing range  \
# Common Name
# Abbott's babbler    NaN          NaN    NaN       NaN            NaN
# Abbott's booby      NaN          NaN    NaN       NaN            NaN
#
#                   hearing threshold  habitat tropical  habitat terrestrial  \
# Common Name
# Abbott's babbler                NaN               NaN                  NaN
# Abbott's booby                  NaN               NaN                  NaN
#
#                   visual system  auditory system
# Common Name
# Abbott's babbler            NaN              NaN
# Abbott's booby              NaN              NaN
#
# [2 rows x 25 columns]

# %%
# Out:
# (6867, 17)

# %%
df = pd.merge(df1,df2,how='outer',on=['Common Name'])
df.head(2)
# Out:
#                   Scientific Name  Other names  Country of origin  Species_x  \
# Common Name
# Abbott's babbler              NaN          NaN                NaN        NaN
# Abbott's booby                NaN          NaN                NaN        NaN
#
#                   Genera  Size  Family   Order_x  Order_count  Found_in  ...  \
# Common Name                                                              ...
# Abbott's babbler     NaN   NaN      NaN      NaN          NaN       NaN  ...
# Abbott's booby       NaN   NaN      NaN      NaN          NaN       NaN  ...
#
#                   Genus  Species_y  Binomial Name  Description  Categories  \
# Common Name
# Abbott's babbler    NaN        NaN            NaN          NaN         NaN
# Abbott's booby      NaN        NaN            NaN          NaN         NaN
#
#                   References  Wiki URL  Image  Country  Habitat
# Common Name
# Abbott's babbler         NaN       NaN    NaN      NaN      NaN
# Abbott's booby           NaN       NaN    NaN      NaN      NaN
#
# [2 rows x 42 columns]

# %%
df.to_csv("./assets/BirdsClassificationMain.csv")
