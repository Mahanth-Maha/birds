# %%
import pandas as pd
ebird = pd.read_pickle('../assets/rescrape/ebird_data.pkl')
ebird.head(2)
# Out:
#          Common Name   Kingdom    Phylum Class          Order     Family  \
# 0     Abbott's Booby  Animalia  Chordata  Aves     Suliformes    Sulidae
# 0  Abbott's Starling  Animalia  Chordata  Aves  Passeriformes  Sturnidae
#
#          Binomial Name                               Link  \
# 0     Papasula abbotti  https://ebird.org/species/abbboo2
# 0  Poeoptera femoralis  https://ebird.org/species/abbsta2
#
#                                          Description
# 0  Gangly, stretched-out-looking black-and-white ...
# 0  A small, distinctive starling with a tiny rang...

# %%
eol = pd.read_pickle('../assets/rescrape_eol/eol_data.pkl')
eol.head(2)
# Out:
#         Common Name   Kingdom    Phylum Class                            Link  \
# 0     Abbotts booby  Animalia  Chordata  Aves  https://eol.org/pages/45513856
# 0  Abbotts starling  Animalia  Chordata  Aves  https://eol.org/pages/45515541
#
#                                          Description      auditory system  \
# 0  Papasula (Abbott's Booby) is a genus of birds ...  tympanic middle ear
# 0  Poeoptera femoralis (Abbott's Starling) is a s...  tympanic middle ear
#
#   conservation status ecomorphological guild hearing range  ...  \
# 0          endangered               nectonic       5000 Hz  ...
# 0          vulnerable                    NaN       5000 Hz  ...
#
#   vegetative plant height leaf arrangement developmental mode wing morphology  \
# 0                     NaN              NaN                NaN             NaN
# 0                     NaN              NaN                NaN             NaN
#
#   supporting structures and enclosures diet breadth  \
# 0                                  NaN          NaN
# 0                                  NaN          NaN
#
#   geographic range (size of area) habitat breadth social group size  \
# 0                             NaN             NaN               NaN
# 0                             NaN             NaN               NaN
#
#   territorial
# 0         NaN
# 0         NaN
#
# [2 rows x 113 columns]

# %%
wiki = pd.read_pickle('../assets/rescrape_wiki/wiki_data_v2.pkl')

wiki.head(2)
# Out:
#                               Binomial Name  \
# 0  Cryptospiza salvadoriiReichenow, 1892[2]
# 1      Bucorvus abyssinicus(Boddaert, 1783)
#
#                                           Categories Class  \
# 0  Articles with species microformats, Articles w...  Aves
# 1  Articles with species microformats, Articles w...  Aves
#
#                   Common Name Conservation status   Country  \
# 0      Abyssinian crimsonwing      Least Concern   Ethiopia
# 1  Abyssinian ground hornbill         Vulnerable        NaN
#
#                                          Description       Family  \
# 0  The Abyssinian crimsonwing (Cryptospiza salvad...  Estrildidae
# 1  The Abyssinian ground hornbill or northern gro...   Bucorvidae
#
#          Genus Habitat                                              Image  \
# 0  Cryptospiza  forest  https://upload.wikimedia.org/wikipedia/commons...
# 1     Bucorvus     NaN  https://upload.wikimedia.org/wikipedia/commons...
#
#     Kingdom           Order    Phylum  \
# 0  Animalia   Passeriformes  Chordata
# 1  Animalia  Bucerotiformes  Chordata
#
#                                           References         Species  \
# 0  http://www.hbw.com/species/ethiopian-crimsonwi...   C. salvadorii
# 1  http://www.hbw.com/species/northern-ground-hor...  B. abyssinicus
#
#                                             Wiki URL
# 0  https://en.wikipedia.org/wiki/Abyssinian_crims...
# 1  https://en.wikipedia.org/wiki/Abyssinian_groun...

# %%
names = pd.read_csv('../assets/final_names_unq.csv')
names.head(2)
# Out:
#    ID      Common Name
# 0   1  Abbotts babbler
# 1   2    Abbotts booby

# %%
eird_col = list(ebird.columns)
eol_col = list(eol.columns)
wiki_col = list(wiki.columns)
names_col = list(names.columns)
eird_len = ebird.shape[0]
eol_len = eol.shape[0]
wiki_len = wiki.shape[0]
names_len = names.shape[0]
comb_col = list(set(eird_col+eol_col+wiki_col+names_col))
# print(eird_col,eol_col ,wiki_col,names_col ,eird_len ,eol_len ,wiki_len,names_len)
print(comb_col)
# Out:
# ['life cycle habit', 'genome size', 'diet breadth', 'Leaf Complexity', 'water depth', 'Genus', 'hearing range', 'seed dry mass', 'leaf lamina area', 'produces', 'mutualistic with', 'basal metabolic rate', 'References', 'social system', 'Link', 'parasite of', 'plant lifeform', 'reproduction', 'fire resistance', 'vegetative plant height', 'number of public records in bold', 'ecoregion', 'visits flowers of', 'foraging habitat', 'trophic level', 'native range includes', 'visual system', 'fruit type', 'mineralized skeleton contains', 'is eaten by', 'middle toe length', 'eats', 'standard length', 'habitat', 'calcareous soil tolerance', 'is vector for', 'Description', 'tarsometatarsus + middle toe length', 'life span', 'photosynthetic pathway', 'habitat breadth', 'Image', 'Phylum', 'parasitized by', 'Categories', 'bill length', 'after harvest regrowth rate', 'symbiont of', 'motility', 'fruit or seed color', 'population trend', 'initial mortality rate', 'used for', 'Total length', 'Common Name', 'Habitat', 'trophic guild', 'plant growth form', 'body temperature', 'fire tolerance', 'anaerobic soil tolerance', 'seeds per pound', 'preyed upon by', 'has pathogen', 'Species', 'harvested in', 'egg mass', 'hearing threshold', 'leaf morphology', 'mineralized tissue contains', 'host of', 'clutch/brood/litter size', 'behavioral circadian rhythm', 'developmental mode', 'parental care', 'social group size', 'growth rate', 'invasive in', 'geographic range (size of area)', 'biogeographic realm', 'precipitation tolerance', 'Class', 'leaf nitrogen per dry mass', 'prenatal development duration', 'mating system', 'preys on', 'Conservation status', 'temperature at range midpoint latitude', 'is killed by', 'Order', 'type specimen repository', 'Binomial Name', 'territorial', 'visits', 'Country', 'ecomorphological guild', 'locomotion', 'planting density', 'leaf arrangement', 'body length', 'tarsus length', 'mortality rate doubling time', 'has host', 'diet includes', 'has ectoparasite', 'body shape', 'spore arrangement', 'Family', 'bloom period', 'Kingdom', 'litters per year', 'wing morphology', 'leaf mass per area', 'sensory system', 'onset of fertility', 'geographic distribution includes', 'has endoparasite', 'leaf sheddability', 'auditory system', 'conservation status', 'pathogen of', 'weight', 'ID', 'body mass', 'supporting structures and enclosures', 'Wiki URL']

# %%
import re
def split_upper(s):
    return list(filter(None, re.split("([A-Z][^A-Z]*)", s)))

# %%
wiki.drop_duplicates(subset=['Binomial Name'],inplace=True)
wiki = wiki.set_index('Common Name')
# cn = 'Abbotts babbler'
# bn = 'Binomial Name'
# split_upper(wiki.loc[cn,bn].split(' ')[1])[0]
names = names.set_index('Common Name')

types_of_birds_df = pd.read_csv('../assets/final_names_unq.csv',index_col='ID')
list_of_bird_names = [ types_of_birds_df.loc[ _ ,'Common Name'] for _ in range(1,types_of_birds_df.shape[0]) ]

wiki.head(10)
# wiki.drop_duplicates(subset=[''],inplace=True)
# Out:
#                                                           Binomial Name  \
# Common Name
# Abyssinian crimsonwing         Cryptospiza salvadoriiReichenow, 1892[2]
# Abyssinian ground hornbill         Bucorvus abyssinicus(Boddaert, 1783)
# Abyssinian ground thrush           Geokichla piaggiae(Bouvier, 1877)[2]
# Abyssinian longclaw                   Macronyx flavicollisRüppell, 1840
# Abyssinian roller                     Coracias abyssinicusHermann, 1783
# Abyssinian scimitarbill              Rhinopomastus minor(Rüppell, 1845)
# Abyssinian slaty flycatcher  Melaenornis chocolatinus(Rüppell, 1840)[2]
# Abyssinian thrush              Turdus abyssinicusJ. F. Gmelin (1789)[2]
# Abbotts babbler                         Malacocincla abbottiBlyth, 1845
# Abbotts booby                           Papasula abbotti(Ridgway, 1893)
#
#                                                                     Categories  \
# Common Name
# Abyssinian crimsonwing       Articles with species microformats, Articles w...
# Abyssinian ground hornbill   Articles with species microformats, Articles w...
# Abyssinian ground thrush     Articles with species microformats, Articles w...
# Abyssinian longclaw          All stub articles, Articles with species micro...
# Abyssinian roller            Articles with species microformats, Articles w...
# Abyssinian scimitarbill      All stub articles, Articles with species micro...
# Abyssinian slaty flycatcher  Articles with species microformats, Articles w...
# Abyssinian thrush            Articles with species microformats, Articles w...
# Abbotts babbler              Articles with species microformats, Articles w...
# Abbotts booby                Articles with species microformats, Articles w...
#
#                             Class Conservation status           Country  \
# Common Name
# Abyssinian crimsonwing       Aves      Least Concern           Ethiopia
# Abyssinian ground hornbill   Aves         Vulnerable                NaN
# Abyssinian ground thrush     Aves      Least Concern                NaN
# Abyssinian longclaw          Aves    Near Threatened           Ethiopia
# Abyssinian roller            Aves      Least Concern            Senegal
# Abyssinian scimitarbill      Aves      Least Concern        South Sudan
# Abyssinian slaty flycatcher  Aves      Least Concern           Ethiopia
# Abyssinian thrush            Aves      Least Concern           Ethiopia
# Abbotts babbler              Aves      Least Concern                NaN
# Abbotts booby                Aves         Endangered   Christmas Island
#
#                                                                    Description  \
# Common Name
# Abyssinian crimsonwing       The Abyssinian crimsonwing (Cryptospiza salvad...
# Abyssinian ground hornbill   The Abyssinian ground hornbill or northern gro...
# Abyssinian ground thrush     The Abyssinian ground thrush (Geokichla piaggi...
# Abyssinian longclaw          The Abyssinian longclaw (Macronyx flavicollis)...
# Abyssinian roller            The Abyssinian roller (Coracias abyssinicus), ...
# Abyssinian scimitarbill      The Abyssinian scimitarbill (Rhinopomastus min...
# Abyssinian slaty flycatcher  The Abyssinian slaty flycatcher (Melaenornis c...
# Abyssinian thrush            The Abyssinian thrush (Turdus abyssinicus) is ...
# Abbotts babbler              Abbott's babbler (Malacocincla abbotti) is a s...
# Abbotts booby                Abbott's booby (Papasula abbotti) is an endang...
#
#                                     Family                          Genus  \
# Common Name
# Abyssinian crimsonwing         Estrildidae                    Cryptospiza
# Abyssinian ground hornbill      Bucorvidae                       Bucorvus
# Abyssinian ground thrush          Turdidae                      Geokichla
# Abyssinian longclaw           Motacillidae                       Macronyx
# Abyssinian roller               Coraciidae                       Coracias
# Abyssinian scimitarbill      Phoeniculidae                  Rhinopomastus
# Abyssinian slaty flycatcher   Muscicapidae                    Melaenornis
# Abyssinian thrush                 Turdidae                         Turdus
# Abbotts babbler               Pellorneidae                   Malacocincla
# Abbotts booby                      Sulidae  PapasulaOlson & Warheit, 1988
#
#                             Habitat  \
# Common Name
# Abyssinian crimsonwing       forest
# Abyssinian ground hornbill      NaN
# Abyssinian ground thrush     forest
# Abyssinian longclaw             NaN
# Abyssinian roller               NaN
# Abyssinian scimitarbill         NaN
# Abyssinian slaty flycatcher     NaN
# Abyssinian thrush               NaN
# Abbotts babbler              forest
# Abbotts booby                forest
#
#                                                                          Image  \
# Common Name
# Abyssinian crimsonwing       https://upload.wikimedia.org/wikipedia/commons...
# Abyssinian ground hornbill   https://upload.wikimedia.org/wikipedia/commons...
# Abyssinian ground thrush     https://upload.wikimedia.org/wikipedia/commons...
# Abyssinian longclaw          https://upload.wikimedia.org/wikipedia/commons...
# Abyssinian roller            https://upload.wikimedia.org/wikipedia/commons...
# Abyssinian scimitarbill      https://upload.wikimedia.org/wikipedia/commons...
# Abyssinian slaty flycatcher  https://upload.wikimedia.org/wikipedia/commons...
# Abyssinian thrush            https://upload.wikimedia.org/wikipedia/commons...
# Abbotts babbler              https://upload.wikimedia.org/wikipedia/commons...
# Abbotts booby                https://upload.wikimedia.org/wikipedia/commons...
#
#                               Kingdom           Order    Phylum  \
# Common Name
# Abyssinian crimsonwing       Animalia   Passeriformes  Chordata
# Abyssinian ground hornbill   Animalia  Bucerotiformes  Chordata
# Abyssinian ground thrush     Animalia   Passeriformes  Chordata
# Abyssinian longclaw          Animalia   Passeriformes  Chordata
# Abyssinian roller            Animalia   Coraciiformes  Chordata
# Abyssinian scimitarbill      Animalia  Bucerotiformes  Chordata
# Abyssinian slaty flycatcher  Animalia   Passeriformes  Chordata
# Abyssinian thrush            Animalia   Passeriformes  Chordata
# Abbotts babbler              Animalia   Passeriformes  Chordata
# Abbotts booby                Animalia      Suliformes  Chordata
#
#                                                                     References  \
# Common Name
# Abyssinian crimsonwing       http://www.hbw.com/species/ethiopian-crimsonwi...
# Abyssinian ground hornbill   http://www.hbw.com/species/northern-ground-hor...
# Abyssinian ground thrush     http://www.hbw.com/species/abyssinian-ground-t...
# Abyssinian longclaw          http://datazone.birdlife.org/species/factsheet...
# Abyssinian roller            http://www.hbw.com/node/55858, http://datazone...
# Abyssinian scimitarbill      http://datazone.birdlife.org/species/factsheet...
# Abyssinian slaty flycatcher  http://www.hbw.com/species/abyssinian-slaty-fl...
# Abyssinian thrush            http://www.birdforum.net/opus/Abyssinian_Thrus...
# Abbotts babbler              http://ibc.lynxeds.com/species/abbotts-babbler...
# Abbotts booby                http://www.environment.gov.au/biodiversity/thr...
#
#                                      Species  \
# Common Name
# Abyssinian crimsonwing         C. salvadorii
# Abyssinian ground hornbill    B. abyssinicus
# Abyssinian ground thrush         G. piaggiae
# Abyssinian longclaw           M. flavicollis
# Abyssinian roller             C. abyssinicus
# Abyssinian scimitarbill             R. minor
# Abyssinian slaty flycatcher  M. chocolatinus
# Abyssinian thrush             T. abyssinicus
# Abbotts babbler                   M. abbotti
# Abbotts booby                     P. abbotti
#
#                                                                       Wiki URL
# Common Name
# Abyssinian crimsonwing       https://en.wikipedia.org/wiki/Abyssinian_crims...
# Abyssinian ground hornbill   https://en.wikipedia.org/wiki/Abyssinian_groun...
# Abyssinian ground thrush     https://en.wikipedia.org/wiki/Abyssinian_groun...
# Abyssinian longclaw          https://en.wikipedia.org/wiki/Abyssinian_longclaw
# Abyssinian roller              https://en.wikipedia.org/wiki/Abyssinian_roller
# Abyssinian scimitarbill      https://en.wikipedia.org/wiki/Abyssinian_scimi...
# Abyssinian slaty flycatcher  https://en.wikipedia.org/wiki/Abyssinian_slaty...
# Abyssinian thrush              https://en.wikipedia.org/wiki/Abyssinian_thrush
# Abbotts babbler               https://en.wikipedia.org/wiki/Abbott%27s_babbler
# Abbotts booby                   https://en.wikipedia.org/wiki/Abbott%27s_booby

# %%
# wiki.loc['Abbotts sunbird','Binomial Name']

# %%
fail = []
def clean_bn(cn,wiki):
    try:
        # print('h')
        bn = wiki.loc[cn,'Binomial Name']
        # print(bn)
        if '†' in bn:
            wiki.loc[cn,'Binomial Name'] = bn.replace('†','')
        if '(' in bn:
            # print(wiki.loc[cn,'Binomial Name'].split(' ')[0] + wiki.loc[cn,'Binomial Name'].split(' ')[1].split('(')[0])
            wiki.loc[cn,'Binomial Name'] = wiki.loc[cn,'Binomial Name'].split(' ')[0] +' '+ wiki.loc[cn,'Binomial Name'].split(' ')[1].split('(')[0]
        else:
            # print(wiki.loc[cn,'Binomial Name'])
            wiki.loc[cn,'Binomial Name'] = wiki.loc[cn,'Binomial Name'].split(' ')[0] +' '+ split_upper(wiki.loc[cn,'Binomial Name'].split(' ')[1])[0]
    except Exception:
        # print('Failed :',cn)
        fail.append(cn)
    finally:
        return wiki
        # pass

# clean_bn('Abyssinian crimsonwing',wiki).head(5)
# clean_bn('Abyssinian longclaw',wiki)

# %%
for i in list_of_bird_names:
    wiki = clean_bn(i,wiki)
wiki.head(10)
# Out:
# Malacocincla abbottiBlyth, 1845
# Malacocincla abbottiBlyth, 1845
# Papasula abbotti(Ridgway, 1893)
# Papasulaabbotti
# Poeoptera femoralis(Richmond, 1897)
# Poeopterafemoralis
# Failed : Abbotts sunbird
# Passer hemileucusOgilvie-Grant & Forbes, 1900
# Passer hemileucusOgilvie-Grant & Forbes, 1900
# Ciconia abdimiiLichtenstein, 1823
# Ciconia abdimiiLichtenstein, 1823
# Failed : Aberdare cisticola
# Horornis flavolivaceus(Blyth, 1845)
# Horornisflavolivaceus
# Melozone aberti(Baird, 1852)
# Melozoneaberti
# Failed : Abyssinian catbird
# Cryptospiza salvadoriiReichenow, 1892[2]
# Cryptospiza salvadoriiReichenow, 1892[2]
# Bucorvus abyssinicus(Boddaert, 1783)
# Bucorvusabyssinicus
# Geokichla piaggiae(Bouvier, 1877)[2]
# Geokichlapiaggiae
# Macronyx flavicollisRüppell, 1840
# Macronyx flavicollisRüppell, 1840
# Asio abyssinicus(Guérin-Méneville, 1843)
# Asioabyssinicus
# Coracias abyssinicusHermann, 1783
# Coracias abyssinicusHermann, 1783
# Rhinopomastus minor(Rüppell, 1845)
# Rhinopomastusminor
# Melaenornis chocolatinus(Rüppell, 1840)[2]
# Melaenornischocolatinus
# Turdus abyssinicusJ. F. Gmelin (1789)[2]
# TurdusabyssinicusJ.
# Estrilda ochrogasterSalvadori, 1897
# Estrilda ochrogasterSalvadori, 1897
# Oenanthe lugubris(Rüppell, 1837)
# Oenanthelugubris
# Zosterops abyssinicusGuérin-Méneville, 1843
# Zosterops abyssinicusGuérin-Méneville, 1843
# Dendropicos abyssinicus(Stanley, 1814)[2]
# Dendropicosabyssinicus
# Tricholaema leucomelas(Boddaert, 1783)
# Tricholaemaleucomelas
# Melaniparus thruppi(Shelley, 1885)[2]
# Melaniparusthruppi
# Empidonax virescens(Vieillot, 1818)
# Empidonaxvirescens
# Pycnonotus snouckaertiSiebers, 1928
# Pycnonotus snouckaertiSiebers, 1928
# Melanerpes formicivorus(Swainson, 1827)
# Melanerpesformicivorus
# Thamnophilus divisoriusWhitney, Oren & Brumfield, 2004
# Thamnophilus divisoriusWhitney, Oren & Brumfield, 2004
# Hemitriccus cohnhafti(Zimmer et al., 2013)
# Hemitriccuscohnhafti
# Streptopelia hypopyrrha(Reichenow, 1910)
# Streptopeliahypopyrrha
# Setophaga adelaidae(Baird, 1865)
# Setophagaadelaidae
# Pygoscelis adeliae(Hombron & Jacquinot, 1841)
# Pygoscelisadeliae
# Edolisoma admiralitatisRothschild & Hartert, 1914
# Edolisoma admiralitatisRothschild & Hartert, 1914
# Columba unicinctaCassin, 1860
# Columba unicinctaCassin, 1860
# Argya huttoni(Blyth, 1847)
# Argyahuttoni
# Pyrgilauda theresae(R. Meinertzhagen, 1937)
# Pyrgilaudatheresae
# Glaucidium capense(Smith, 1834)
# Glaucidiumcapense
# Anas sparsaEyton, 1838
# Anas sparsaEyton, 1838
# Apus barbatus(Sclater, 1866)
# Apusbarbatus
# Elminia longicauda(Swainson, 1838)[2]
# Elminialongicauda
# Cyanistes teneriffae(Lesson, 1831)
# Cyanistesteneriffae
# Smithornis capensis(Smith, 1839)[2]
# Smithorniscapensis
# Crithagra citrinelloides(Rüppell, 1840)
# Crithagracitrinelloides
# Streptopelia roseogrisea(Sundevall, 1857)
# Streptopeliaroseogrisea
# Failed : African crake
# Rhodopechys alienusWhitaker, 1897
# Rhodopechys alienusWhitaker, 1897
# Cuculus gularisStephens, 1815
# Cuculus gularisStephens, 1815
# Aviceda cuculoidesSwainson, 1837
# Aviceda cuculoidesSwainson, 1837
# Anhinga rufa(Daudin, 1802)
# Anhingarufa
# Curruca deserti(Loche, 1858)
# Currucadeserti
# Muscicapa adusta(Boie, 1828)
# Muscicapaadusta
# Ispidina leconteiCassin, 1856
# Ispidina leconteiCassin, 1856
# Chrysococcyx cupreus(Shaw, 1792)
# Chrysococcyxcupreus
# Podica senegalensis(Vieillot, 1817)
# Podicasenegalensis
# Lagonosticta rubricata(Lichtenstein, 1823)[2]
# Lagonostictarubricata
# Haliaeetus vocifer(Daudin, 1800)
# Haliaeetusvocifer
# Oriolus auratusVieillot, 1817
# Oriolus auratusVieillot, 1817
# Accipiter tachiro(Daudin, 1800)
# Accipitertachiro
# Tyto capensis(Smith, 1834)
# Tytocapensis
# Treron calvus(Temminck, 1811)
# Treroncalvus
# Melaenornis microrhynchus(Reichenow, 1887)
# Melaenornismicrorhynchus
# Lophoceros nasutus(Linnaeus, 1766)
# Lophocerosnasutus
# Dendropicos goertae(Statius Muller, 1776)
# Dendropicosgoertae
# Polyboroides typusSmith, 1829
# Polyboroides typusSmith, 1829
# Aquila spilogaster(Bonaparte, 1850)
# Aquilaspilogaster
# Sylvia abyssinica(Rüppell, 1840)
# Sylviaabyssinica
# Falco cuvieriiSmith, 1830
# Falco cuvieriiSmith, 1830
# Upupa africanaBechstein, 1811
# Upupa africanaBechstein, 1811
# Actophilornis africanus(Gmelin, 1789)
# Actophilornisafricanus
# Circus ranivorusDaudin, 1800
# Circus ranivorusDaudin, 1800
# Columba arquatrixTemminck, 1808
# Columba arquatrixTemminck, 1808
# Anastomus lamelligerusTemminck, 1823
# Anastomus lamelligerusTemminck, 1823
# Haematopus moquini(Bonaparte, 1856)
# Haematopusmoquini
# Cypsiurus parvus(Lichtenstein, 1823)
# Cypsiurusparvus
# Terpsiphone viridis(Müller, 1776)
# Terpsiphoneviridis
# Spheniscus demersus(Linnaeus, 1758)
# Spheniscusdemersus
# Sasia africanaVerreaux & Verreaux, 1855
# Sasia africanaVerreaux & Verreaux, 1855
# Lophoceros fasciatus(Shaw, 1811)
# Lophocerosfasciatus
# Motacilla aguimpTemminck, 1820[2]
# Motacilla aguimpTemminck, 1820[2]
# Anthus cinnamomeusRüppell, 1840
# Anthus cinnamomeusRüppell, 1840
# Pitta angolensisVieillot, 1816
# Pitta angolensisVieillot, 1816
# Nettapus auritus(Boddaert, 1783)
# Nettapusauritus
# Ispidina picta(Boddaert, 1783)
# Ispidinapicta
# Rallus caerulescensGmelin, 1789
# Rallus caerulescensGmelin, 1789
# Pycnonotus nigricans(Vieillot, 1818)
# Pycnonotusnigricans
# Acrocephalus baeticatus(Vieillot, 1817)
# Acrocephalusbaeticatus
# Pseudochelidon eurystominaHartlaub, 1861[2]Holotype from Gabon
# Pseudochelidon eurystominaHartlaub, 1861[2]Holotype from Gabon
# Anthus crenatusFinsch & Hartlaub, 1870
# Anthus crenatusFinsch & Hartlaub, 1870
# Threskiornis aethiopicus(Latham, 1790)
# Threskiornisaethiopicus
# Otus senegalensis(Swainson, 1837)
# Otussenegalensis
# Megabyas flammulatus(Verreaux & Verreaux, 1855)
# Megabyasflammulatus
# Euodice cantans(Gmelin, 1789)
# Euodicecantans
# Rynchops flavirostrisVieillot, 1816
# Rynchops flavirostrisVieillot, 1816
# Gallinago nigripennisBonaparte, 1839
# Gallinago nigripennisBonaparte, 1839
# Platalea albaScopoli, 1786
# Platalea albaScopoli, 1786
# Salpornis salvadori(Bocage, 1878)
# Salpornissalvadori
# Saxicola torquatus(Linnaeus, 1766)
# Saxicolatorquatus
# Porphyrio madagascariensis(Latham, 1801)
# Porphyriomadagascariensis
# Turdus peliosBonaparte, 1850[2]
# Turdus peliosBonaparte, 1850[2]
# Vanellus senegallus(Linnaeus, 1766)
# Vanellussenegallus
# Strix woodfordii(Smith A., 1834)
# Strixwoodfordii
# Iduna natalensisA. Smith, 1847[2]
# Iduna natalensisA. Smith, 1847[2]
# Agamia agami(Gmelin, 1789)
# Agamiaagami
# Uromyias agilis(Sclater, 1856)
# Uromyiasagilis
# †Acrocephalus nijoiYamashina, 1940
# Acrocephalus nijoiYamashina, 1940
# Certhilauda brevirostrisRoberts, 1941
# Certhilauda brevirostrisRoberts, 1941
# Pternistis ahantensis(Temminck, 1854)
# Pternistisahantensis
# Hydrobates cheimomnestes(Ainley, 1980)
# Hydrobatescheimomnestes
# Failed : Akekee
# Failed : Akiapolaau
# Failed : Akiapōlāau
# Failed : Akikiki
# Failed : Akohekohe
# Failed : Ākohekohe
# Bubo leucostictusHartlaub, 1855[1]
# Bubo leucostictusHartlaub, 1855[1]
# Myrmotherula snowiTeixeira & Gonzaga, 1983
# Myrmotherula snowiTeixeira & Gonzaga, 1983
# Mitu mitu(Linnaeus, 1766)
# Mitumitu
# †Philydor novaesiTeixeira & Gonzaga, 1983
# Philydor novaesiTeixeira & Gonzaga, 1983
# Phylloscartes ceciliaeTeixeira, 1987
# Phylloscartes ceciliaeTeixeira, 1987
# †Tachybaptus rufolavatus(Delacour, 1932)
# Tachybaptusrufolavatus
# Glaucidium albertinumPrigogine, 1983
# Glaucidium albertinumPrigogine, 1983
# Laniarius holomelas(Jackson, 1906)
# Laniariusholomelas
# Menura albertiBonaparte, 1850
# Menura albertiBonaparte, 1850
# †Nesillas aldabranaBenson & Penny, 1968
# Nesillas aldabranaBenson & Penny, 1968
# Dicrurus aldabranus(Ridgway, 1893)
# Dicrurusaldabranus
# Foudia aldabranaRidgway, 1893
# Foudia aldabranaRidgway, 1893
# Zosterops aldabrensisRidgway, 1894
# Zosterops aldabrensisRidgway, 1894
# Empidonax alnorum(Brewster, 1895)
# Empidonaxalnorum
# Onychoprion aleuticus(Baird, 1869)
# Onychoprionaleuticus
# Psittacula eupatria(Linnaeus, 1766)
# Psittaculaeupatria
# Sitta ledantiVielliard, 1976
# Sitta ledantiVielliard, 1976
# Porphyrio alleniThomson, 1842
# Porphyrio alleniThomson, 1842
# Selasphorus sasin(Lesson, R, 1829)
# Selasphorussasin
# Percnostola arenarumM.L. Isler, J.A. Alonso, P.R. Isler & B.M. Whitney, 2001
# Percnostola arenarumM.L. Isler, J.A. Alonso, P.R. Isler & B.M. Whitney, 2001
# Ninox plesseniStresemann, 1929
# Ninox plesseniStresemann, 1929
# Myzomela prawiradilagaeIrham et al., 2019
# Myzomela prawiradilagaeIrham et al., 2019
# Prunella collaris(Scopoli, 1769)
# Prunellacollaris
# Pyrrhocorax graculus(Linnaeus, 1766)
# Pyrrhocoraxgraculus
# Failed : Alpine leaf warbler
# Anthus gutturalisDe Vis, 1894
# Anthus gutturalisDe Vis, 1894
# Tachymarptis melba(Linnaeus, 1758)
# Tachymarptismelba
# Zoothera mollissima(Blyth, 1842)
# Zootheramollissima
# Phylloscopus soror(Alström & Olsson, 1999)
# Phylloscopussoror
# Hylopezus whittakeriCarneiro, et al. 2012
# Hylopezus whittakeriCarneiro, et al. 2012
# Prunella himalayana(Blyth, 1842)
# Prunellahimalayana
# Tetraogallus altaicus(Gebler, 1836)
# Tetraogallusaltaicus
# Icterus gularis(Wagler, 1829)
# Icterusgularis
# Geothlypis flavovelata(Ridgway, 1896)
# Geothlypisflavovelata
# Zoothera major(Ogawa, 1905)
# Zootheramajor
# Scolopax miraHartert, 1916
# Scolopax miraHartert, 1916
# Hedydipna pallidigasterSclater & Moreau, 1935
# Hedydipna pallidigasterSclater & Moreau, 1935
# Amazilis amazilia(Lesson, 1827)
# Amazilisamazilia
# Chloroceryle amazona(Latham, 1790)
# Chloroceryleamazona
# Hylopezus berlepschi(Hellmayr, 1903)
# Hylopezusberlepschi
# Thamnophilus amazonicusSclater, 1858
# Thamnophilus amazonicusSclater, 1858
# Dendrocolaptes certhia(Boddaert, 1783)
# Dendrocolaptescerthia
# Knipolegus poecilocercus(Pelzeln, 1868)
# Knipoleguspoecilocercus
# Cyanoloxia rothschildii(Bartlett, E, 1890)
# Cyanoloxiarothschildii
# Inezia subflava(Sclater & Salvin, 1873)
# Ineziasubflava
# Momotus momota(Linnaeus, 1766)
# Momotusmomota
# Glaucidium hardyiVielliard, 1989
# Glaucidium hardyiVielliard, 1989
# Onychorhynchus coronatus(Statius Müller, PL, 1776)
# Onychorhynchuscoronatus
# Sublegatus obscuriorTodd, 1920
# Sublegatus obscuriorTodd, 1920
# Myrmotherula multostriataSclater, 1858
# Myrmotherula multostriataSclater, 1858
# Trogon ramonianusDeville & Des Murs, 1849
# Trogon ramonianusDeville & Des Murs, 1849
# Cephalopterus ornatusGeoffroy Saint-Hilaire, 1809
# Cephalopterus ornatusGeoffroy Saint-Hilaire, 1809
# Zosterops kuehniHartert, 1906
# Zosterops kuehniHartert, 1906
# Macropygia amboinensis(Linnaeus, 1766)
# Macropygiaamboinensis
# Failed : Ameline swiftlet
# Recurvirostra americanaGmelin, 1789
# Recurvirostra americanaGmelin, 1789
# Tyto furcata(Temminck, 1827)
# Tytofurcata
# Botaurus lentiginosus(Rackett, 1813) [2]
# Botauruslentiginosus
# Anas rubripes(Brewster, 1902)
# Anasrubripes
# Cypseloides niger(Gmelin, 1789)
# Cypseloidesniger
# Failed : American bushtit
# Fulica americanaGmelin, 1789
# Fulica americanaGmelin, 1789
# Corvus brachyrhynchosBrehm, 1822
# Corvus brachyrhynchosBrehm, 1822
# Failed : American dipper
# Empidonax oberholseriPhillips, 1939
# Empidonax oberholseriPhillips, 1939
# Failed : American flamingo
# Pluvialis dominica(Statius Muller, 1776)
# Pluvialisdominica
# Failed : American goldfinch
# Empidonax wrightii(S.F. Baird, 1858)
# Empidonaxwrightii
# Larus smithsonianusCoues, 1862
# Larus smithsonianusCoues, 1862
# Falco sparveriusLinnaeus, 1758
# Falco sparveriusLinnaeus, 1758
# Haematopus palliatusTemminck, 1820
# Haematopus palliatusTemminck, 1820
# Failed : American purple gallinule
# Chloroceryle aenea(Pallas, 1764)
# Chloroceryleaenea
# Failed : American redstart
# Failed : American robin
# Failed : American threetoed woodpecker
# Spizelloides arborea(Wilson, 1810)
# Spizelloidesarborea
# Eudocimus albus(Linnaeus, 1758)
# Eudocimusalbus
# Pelecanus erythrorhynchosGmelin, 1789
# Pelecanus erythrorhynchosGmelin, 1789
# Mareca americana(Gmelin, 1789)
# Marecaamericana
# Scolopax minorGmelin, 1789
# Scolopax minorGmelin, 1789
# Failed : American yellow warbler
# Phapitreron amethystinusBonaparte, 1855
# Phapitreron amethystinusBonaparte, 1855
# Chalcomitra amethystina(Shaw, 1812)
# Chalcomitraamethystina
# Calliphlox amethystinaBoddaert, 1783
# Calliphlox amethystinaBoddaert, 1783
# Lampornis amethystinusSwainson, 1827
# Lampornis amethystinusSwainson, 1827
# Heliangelus amethysticollisd'Orbigny & Lafresnaye, 1838
# Heliangelus amethysticollisd'Orbigny & Lafresnaye, 1838
# Scytalopus whitneyiNiels Krabbe et al., 2020
# Scytalopus whitneyiNiels Krabbe et al., 2020
# Diomedea amsterdamensisRoux JP, Jouventin, Mougin, Stahl & Weimerskirch 1983[2]
# Diomedea amsterdamensisRoux JP, Jouventin, Mougin, Stahl & Weimerskirch 1983[2]
# †Mareca mareculaOlson & Jouventin, 1996
# Mareca mareculaOlson & Jouventin, 1996
# Falco amurensisRadde, 1863
# Falco amurensisRadde, 1863
# Terpsiphone incei(Gould, 1852)
# Terpsiphoneincei
# Estrilda poliopareiaReichenow, 1902
# Estrilda poliopareiaReichenow, 1902
# Scytalopus affinisZimmer, 1939
# Scytalopus affinisZimmer, 1939
# Stactolaema anchietae(Barboza du Bocage, 1869)
# Stactolaemaanchietae
# Anthreptes anchietae(Barboza du Bocage, 1878)
# Anthreptesanchietae
# Herpsilochmus gentryiWhitney & Alvarez Alonso, 1998
# Herpsilochmus gentryiWhitney & Alvarez Alonso, 1998
# Synthliboramphus antiquus(Gmelin, 1789)
# Synthliboramphusantiquus
# Brachypodius fuscoflavescens(Hume, 1873)
# Brachypodiusfuscoflavescens
# Centropus andamanensisBeavan, 1867[2]
# Centropus andamanensisBeavan, 1867[2]
# Rallina canningi(Blyth, 1863)
# Rallinacanningi
# Macropygia rufipennisBlyth, 1846
# Macropygia rufipennisBlyth, 1846
# Coracina dobsoni(Ball, 1872)
# Coracinadobsoni
# Dicrurus andamanensisBeavan, 1867
# Dicrurus andamanensisBeavan, 1867
# Dicaeum virescens(Hume, 1873)
# Dicaeumvirescens
# Treron chloropterus(Blyth, 1845)
# Treronchloropterus
# Ninox affinisBeavan, 1867
# Ninox affinisBeavan, 1867
# Tyto deroepstorffi(Hume, 1875)
# Tytoderoepstorffi
# Caprimulgus andamanicusHume, 1873
# Caprimulgus andamanicusHume, 1873
# Otus balli(Hume, 1873)
# Otusballi
# Spilornis elgini(Blyth, 1863)
# Spilorniselgini
# Copsychus albiventris(Blyth, 1859)
# Copsychusalbiventris
# Anas albogularis(Hume, 1873)
# Anasalbogularis
# Dendrocitta bayleyiiTytler, 1863
# Dendrocitta bayleyiiTytler, 1863
# Columba palumboides(Hume, 1873)
# Columbapalumboides
# Dryocopus hodgei(Blyth, 1860)
# Dryocopushodgei
# Recurvirostra andinaPhilippi & Landbeck, 1861
# Recurvirostra andinaPhilippi & Landbeck, 1861
# Rupicola peruvianus(Latham, 1790)
# Rupicolaperuvianus
# Failed : Andean condor
# Failed : Andean coot
# Oxyura ferruginea(Eyton, 1838)
# Oxyuraferruginea
# Uranomitra franciae(Bourcier & Mulsant, 1846)
# Uranomitrafranciae
# Phoenicoparrus andinus(Philippi, 1854)
# Phoenicoparrusandinus
# Colaptes rupicolaD'Orbigny, 1840
# Colaptes rupicolaD'Orbigny, 1840
# Chloephaga melanoptera(Eyton, 1838)
# Chloephagamelanoptera
# Penelope montagnii(Bonaparte, 1856)
# Penelopemontagnii
# Chroicocephalus serranus(Tschudi, 1844)
# Chroicocephalusserranus
# Oreotrochilus estellad'Orbigny & Lafresnaye, 1838
# Oreotrochilus estellad'Orbigny & Lafresnaye, 1838
# Theristicus branickii(von Berlepsch and Stolzmann, 1894)
# Theristicusbranickii
# Laniisoma buckleyi(Sclater & Salvin, 1880)
# Laniisomabuckleyi
# Vanellus resplendens(Tschudi, 1843)
# Vanellusresplendens
# Momotus aequatorialisGould, 1858
# Momotus aequatorialisGould, 1858
# Lessonia oreas(Sclater & Salvin, 1869)
# Lessoniaoreas
# Bolborhynchus orbygnesius(Souancé, 1856)
# Bolborhynchusorbygnesius
# Nyctibius maculosusRidgway, 1912
# Nyctibius maculosusRidgway, 1912
# Glaucidium jardinii(Bonaparte, 1855)
# Glaucidiumjardinii
# Spinus spinescens(Bonaparte, 1851)
# Spinusspinescens
# Turdus nigricepsCabanis, 1874
# Turdus nigricepsCabanis, 1874
# Myadestes ralloides(D'Orbigny, 1840)
# Myadestesralloides
# Orochelidon andecola(D'Orbigny & Lafresnaye, 1837)
# Orochelidonandecola
# Aeronautes andecolus(d'Orbigny & Lafresnaye, 1837)
# Aeronautesandecolus
# Anas andiumSclater & Salvin, 1873
# Anas andiumSclater & Salvin, 1873
# Nothoprocta pentlandiiGray 1867[2]
# Nothoprocta pentlandiiGray 1867[2]
# Leptasthenura andicolaSclater, 1870
# Leptasthenura andicolaSclater, 1870
# Batis minulla(Barboza du Bocage, 1874)
# Batisminulla
# Cossypha ansorgei(Hartert, 1907)
# Cossyphaansorgei
# Mirafra angolensisBarboza du Bocage, 1880
# Mirafra angolensisBarboza du Bocage, 1880
# Melaenornis brunneus(Cabanis, 1886)
# Melaenornisbrunneus
# Hirundo angolensisBarboza du Bocage, 1868
# Hirundo angolensisBarboza du Bocage, 1868
# Coccopygia bocageiShelley, 1903
# Coccopygia bocageiShelley, 1903
# Failed : Anhinga
# Failed : Anianiau
# Failed : Anjouan brush warbler
# Otus capnodes(Gurney, 1889)
# Otuscapnodes
# Cinnyris comorensisPeters, 1864
# Cinnyris comorensisPeters, 1864
# Crithagra ankoberensis(Ash, 1979)
# Crithagraankoberensis
# Prinia rockiDeignan, 1957
# Prinia rockiDeignan, 1957
# Calypte anna(Lesson, 1829)
# Calypteanna
# Terpsiphone smithii(Fraser, 1843)
# Terpsiphonesmithii
# Zosterops griseovirescensBarboza du Bocage, 1893
# Zosterops griseovirescensBarboza du Bocage, 1893
# Eurillas ansorgei(Hartert, 1907)
# Eurillasansorgei
# Thalassoica antarctica(J. F. Gmelin 1789)[2]
# Thalassoicaantarctica
# Pachyptila desolataGmelin, 1789
# Pachyptila desolataGmelin, 1789
# Leucocarbo bransfieldensisMurphy, 1936
# Leucocarbo bransfieldensisMurphy, 1936
# Sterna vittataGmelin, 1789
# Sterna vittataGmelin, 1789
# Myrmecocichla aethiopsCabanis, 1850
# Myrmecocichla aethiopsCabanis, 1850
# Myrmecocichla formicivora(Wilkes, 1817)
# Myrmecocichlaformicivora
# Nyctidromus anthonyi(Chapman, 1923)
# Nyctidromusanthonyi
# Orthorhyncus cristatus(Linnaeus, 1758)
# Orthorhyncuscristatus
# Chlorophonia musica(Gmelin, 1789)
# Chlorophoniamusica
# Anthracothorax dominicus(Linnaeus, 1766)
# Anthracothoraxdominicus
# Chordeiles gundlachiiLawrence, 1856
# Chordeiles gundlachiiLawrence, 1856
# Tachornis phoenicobiaGosse, 1847
# Tachornis phoenicobiaGosse, 1847
# Nesoctites micromegas(Sundevall, 1866)
# Nesoctitesmicromegas
# Spinus dominicensis(Bryant, 1868)
# Spinusdominicensis
# Pogonotriccus lanyoni(Graves, 1988)
# Pogonotriccuslanyoni
# Atlapetes blancaeDonegan, 2007
# Atlapetes blancaeDonegan, 2007
# Thryophilus sernaiLara et al., 2012
# Thryophilus sernaiLara et al., 2012
# Diomedea antipodensis(Robertson & Warham 1992)[2]
# Diomedeaantipodensis
# Cyanoramphus unicolor(Lear, 1831)
# Cyanoramphusunicolor
# Failed : Apapane
# Myiarchus apicalisSclater & Salvin, 1881
# Myiarchus apicalisSclater & Salvin, 1881
# Falco femoralisTemminck, 1822
# Falco femoralisTemminck, 1822
# Goodfellowia mirandaHartert, 1903
# Goodfellowia mirandaHartert, 1903
# Aethopyga boltoniMearns, 1905
# Aethopyga boltoniMearns, 1905
# Cistothorus apolinariChapman, 1914
# Cistothorus apolinariChapman, 1914
# Phibalura bolivianaChapman, 1930
# Phibalura bolivianaChapman, 1930
# Struthidea cinereaGould, 1837
# Struthidea cinereaGould, 1837
# Xanthomixis apperti(Colston, 1972)
# Xanthomixisapperti
# Cinnyris buettikoferi(Hartert, 1896)
# Cinnyrisbuettikoferi
# Atlapetes forbesiMorrison, 1947
# Atlapetes forbesiMorrison, 1947
# Synallaxis courseniBlake, 1971
# Synallaxis courseniBlake, 1971
# Acrocephalus paludicola(Vieillot, 1817)
# Acrocephaluspaludicola
# Prunella fagani(Ogilvie-Grant, 1913)
# Prunellafagani
# Argya squamiceps(Cretzschmar, 1827)
# Argyasquamiceps
# Ardeotis arabs(Linnaeus, 1758)
# Ardeotisarabs
# Passer euchlorus(Bonaparte, 1850)
# Passereuchlorus
# Rhynchostruthus percivaliOgilvie-Grant, 1900
# Rhynchostruthus percivaliOgilvie-Grant, 1900
# Alectoris melanocephala(Rüppell, 1835)
# Alectorismelanocephala
# Otus pamelae(Bates, 1937)
# Otuspamelae
# Crithagra rothschildi(Ogilvie-Grant, 1902)
# Crithagrarothschildi
# Curruca leucomelaena(Hemprich and Ehrenberg, 1833, central Midyan, Saudi Arabia)
# Currucaleucomelaena
# Estrilda rufibarba(Cabanis, 1851)
# Estrildarufibarba
# Oenanthe lugentoides(Seebohm, 1881)
# Oenanthelugentoides
# Dendrocoptes dorae(Bates & Kinnear, 1935)
# Dendrocoptesdorae
# Rhipidura dryasGould, 1843
# Rhipidura dryasGould, 1843
# Colluricincla megarhyncha(Quoy & Gaimard, 1832)
# Colluricinclamegarhyncha
# Antilophia bokermanniCoelho & Silva, 1998
# Antilophia bokermanniCoelho & Silva, 1998
# Leptasthenura setaria(Temminck, 1824)
# Leptasthenurasetaria
# Archboldia papuensisRand, 1940
# Archboldia papuensisRand, 1940
# Newtonia archboldiDelacour & Berlioz, 1931
# Newtonia archboldiDelacour & Berlioz, 1931
# Failed : Archbolds nightjar
# Failed : Archbolds owletnightjar
# Buteo archeri(WL Sclater, 1918)
# Buteoarcheri
# Cossypha archeri(Sharpe, 1902)
# Cossyphaarcheri
# Failed : Archers lark
# Acanthis hornemanni(Holbøll, 1843)
# Acanthishornemanni
# Sterna paradisaeaPontoppidan, 1763[2]
# Sterna paradisaeaPontoppidan, 1763[2]
# Phylloscopus borealis(Blasius, 1858)
# Phylloscopusborealis
# Astrapia nigra(Gmelin, 1788)
# Astrapianigra
# Ailuroedus arfakianusMeyer, AB, 1874
# Ailuroedus arfakianusMeyer, AB, 1874
# Melipotes gymnopsSclater, 1873
# Melipotes gymnopsSclater, 1873
# Herpsilochmus stotziWhitney et al., 2013
# Herpsilochmus stotziWhitney et al., 2013
# Leuconotopicus arizonae(Hargitt, 1886)
# Leuconotopicusarizonae
# Larus armenicusButurlin, 1934
# Larus armenicusButurlin, 1934
# Myrmecocichla arnotti(Tristram, 1869)
# Myrmecocichlaarnotti
# Picumnus minutissimus(Pallas, 1782)
# Picumnusminutissimus
# Setophaga pharetra(Gosse, 1847)
# Setophagapharetra
# Turdoides jardineii(Smith, 1836)
# Turdoidesjardineii
# †Mundia elpenor(Olson, 1973)
# Mundiaelpenor
# Fregata aquila(Linnaeus, 1758)
# Fregataaquila
# †Nycticorax olsoni(N. P. Ashmole, K. E. L. Simmons & W. R. P. Bourne, 2003)
# Nycticoraxolsoni
# Montecincla meridionalis(Blanford, 1880)
# Montecinclameridionalis
# Myrmoborus lugubris(Cabanis, 1847)
# Myrmoboruslugubris
# Geospizopsis plebejusTschudi, 1844
# Geospizopsis plebejusTschudi, 1844
# Anairetes alpinus(Carriker, 1933)
# Anairetesalpinus
# Cranioleuca curtata(Sclater, 1870)
# Cranioleucacurtata
# Coccycua cinerea(Vieillot, 1817)
# Coccycuacinerea
# Myornis senilis(Lafresnaye, 1840)
# Myornissenilis
# Mirafra ashiColston, 1982
# Mirafra ashiColston, 1982
# Herpsilochmus parkeriDavis & O'Neill, 1986
# Herpsilochmus parkeriDavis & O'Neill, 1986
# Casiornis fuscusSclater & Salvin, 1873
# Casiornis fuscusSclater & Salvin, 1873
# Mustelirallus albicollis(Vieillot, 1819)
# Mustelirallusalbicollis
# Myiarchus cinerascens(Lawrence, 1851)
# Myiarchuscinerascens
# Conopophaga peruvianaDes Murs, 1856
# Conopophaga peruvianaDes Murs, 1856
# Euchrepomis spodioptila(Sclater & Salvin, 1881)
# Euchrepomisspodioptila
# Hemixos flavalaBlyth, 1845
# Hemixos flavalaBlyth, 1845
# Cisticola cinereolusSalvadori, 1888
# Cisticola cinereolusSalvadori, 1888
# Dicrurus leucophaeusVieillot, 1817
# Dicrurus leucophaeusVieillot, 1817
# Dicaeum vulneratumWallace, 1863
# Dicaeum vulneratumWallace, 1863
# Muscicapa caerulescens(Hartlaub, 1865)
# Muscicapacaerulescens
# Pericrocotus divaricatus(Raffles, 1822)
# Pericrocotusdivaricatus
# Myzomela cineracea(P. L. Sclater, 1879)
# Myzomelacineracea
# Prinia socialis(Sykes, 1832)
# Priniasocialis
# Heteromyias albispecularis(Salvadori, 1876)
# Heteromyiasalbispecularis
# Lamprotornis unicolorShelley, 1881
# Lamprotornis unicolorShelley, 1881
# Hydrobates homochroa(Coues, 1864)
# Hydrobateshomochroa
# Orthotomus ruficeps(Lesson, 1830)
# Orthotomusruficeps
# Geokichla cinerea(Bourns & Worcester, 1894)
# Geokichlacinerea
# Melaniparus cinerascens(Vieillot, 1818)
# Melaniparuscinerascens
# Columba pulchricollisBlyth, 1846
# Columba pulchricollisBlyth, 1846
# Mulleripicus fulvus(Quoy & Gaimard, 1830)
# Mulleripicusfulvus
# Artamus fuscusVieillot, 1817
# Artamus fuscusVieillot, 1817
# Zosterops citrinellaBonaparte, 1850
# Zosterops citrinellaBonaparte, 1850
# Muscicapa randiAmadon & du Pont, 1970
# Muscicapa randiAmadon & du Pont, 1970
# Eremopterix griseus(Scopoli, 1786)
# Eremopterixgriseus
# Tyto glaucops(Kaup, 1852)
# Tytoglaucops
# Pycnonotus cinereifrons(Tweeddale, 1878)
# Pycnonotuscinereifrons
# Pellorneum cinereiceps(Tweeddale, 1878)
# Pellorneumcinereiceps
# Chloephaga poliocephalaP.L. Sclater, 1857
# Chloephaga poliocephalaP.L. Sclater, 1857
# Treron phayrei(Blyth, 1862)
# Treronphayrei
# Hylophilus pectoralisPL Sclater, 1866
# Hylophilus pectoralisPL Sclater, 1866
# Argya cinereifrons(Blyth, 1847)
# Argyacinereifrons
# Phyllomyias cinereiceps(Sclater, 1860)
# Phyllomyiascinereiceps
# Chlorospingus canigularis(Lafresnaye, 1848)
# Chlorospinguscanigularis
# Sinosuthora alphonsiana(J.Verreaux, 1870)
# Sinosuthoraalphonsiana
# Phylloscopus maculipennisBlyth, 1867
# Phylloscopus maculipennisBlyth, 1867
# Glaucidium cuculoides(Vigors, 1831)
# Glaucidiumcuculoides
# Muscicapa dauuricaPallas, 1811
# Muscicapa dauuricaPallas, 1811
# Rhodopechys sanguineus(Gould, 1838)
# Rhodopechyssanguineus
# Curruca nana(Hemprich & Ehrenberg, 1833, southern El Tor, Sinai Peninsula)
# Currucanana
# Limnodromus semipalmatus(Blyth, 1848)
# Limnodromussemipalmatus
# Chrysococcyx maculatus(Gmelin, 1788)
# Chrysococcyxmaculatus
# Irena puella(Latham, 1790)
# Irenapuella
# Aplonis panayensis(Scopoli, 1786)
# Aplonispanayensis
# Ploceus hypoxanthus(Sparrman, 1788)
# Ploceushypoxanthus
# Delichon dasypus(Bonaparte, 1850)
# Delichondasypus
# Eudynamys scolopaceus(Linnaeus, 1758)
# Eudynamysscolopaceus
# Anastomus oscitans(Boddaert, 1783)
# Anastomusoscitans
# Cypsiurus balasiensis(J.E. Gray, 1829)
# Cypsiurusbalasiensis
# Pycnonotus brunneusBlyth, 1845
# Pycnonotus brunneusBlyth, 1845
# Leucosticte arctoaPallas, 1811
# Leucosticte arctoaPallas, 1811
# Alaudala cheleensisR. Swinhoe, 1871
# Alaudala cheleensisR. Swinhoe, 1871
# Urosphena squameicepsR. Swinhoe, 1863
# Urosphena squameicepsR. Swinhoe, 1863
# Pica asirensisBates, 1936
# Pica asirensisBates, 1936
# Trochalopteron chrysopterum(Gould, 1835)
# Trochalopteronchrysopterum
# Sericornis keriMathews, 1920
# Sericornis keriMathews, 1920
# Alaudala athensis(Sharpe, 1900)
# Alaudalaathensis
# †Podilymbus gigasGriscom, 1929
# Podilymbus gigasGriscom, 1929
# Aerodramus sawtelliHolyoak, 1974
# Aerodramus sawtelliHolyoak, 1974
# Serinus canaria(Linnaeus, 1758)
# Serinuscanaria
# Pterodroma incerta(Schlegel, 1863)
# Pterodromaincerta
# Fratercula arctica(Linnaeus, 1758)
# Fraterculaarctica
# Onychorhynchus swainsoni(Pelzeln,1858)
# Onychorhynchusswainsoni
# Thalassarche chlororhynchosGmelin, 1789[2]
# Thalassarche chlororhynchosGmelin, 1789[2]
# Ficedula speculigera(Bonaparte, 1850)
# Ficedulaspeculigera
# Ptilinopus coralensisPeale, 1848
# Ptilinopus coralensisPeale, 1848
# Aplonis feadensis(Ramsay, 1882)
# Aplonisfeadensis
# Lewinia muelleri(Rothschild, 1893)
# Lewiniamuelleri
# Leucocarbo colensoiBuller, 1888
# Leucocarbo colensoiBuller, 1888
# Anas aucklandica(G. R. Gray, 1844)
# Anasaucklandica
# Ichthyaetus audouinii(Payraudeau, 1826, Sardinia and Corsica)
# Ichthyaetusaudouinii
# Icterus graduacaudaLesson, 1839
# Icterus graduacaudaLesson, 1839
# Puffinus lherminieriLesson, 1839
# Puffinus lherminieriLesson, 1839
# nan
# Failed : Audubons warbler
# Buteo augur(Rüppell, 1836)
# Buteoaugur
# Anorrhinus austeniJerdon, 1872
# Anorrhinus austeniJerdon, 1872
# Curaeus curaeus(Molina, 1782)
# Curaeuscuraeus
# Asthenes anthoides(King, 1831)
# Asthenesanthoides
# Lessonia rufa(Gmelin, 1789)
# Lessoniarufa
# Enicognathus ferrugineus(Müller, 1776)
# Enicognathusferrugineus
# Glaucidium nana(King, 1828)
# Glaucidiumnana
# Rallus antarcticusKing, 1828
# Rallus antarcticusKing, 1828
# Turdus falcklandiiQuoy & Gaimard, 1824
# Turdus falcklandiiQuoy & Gaimard, 1824
# Botaurus poiciloptilus(Wagler, 1827)
# Botauruspoiciloptilus
# Anhinga novaehollandiae(Gould, 1847)
# Anhinganovaehollandiae
# Sphecotheres vieillotiVigors & Horsfield, 1827
# Sphecotheres vieillotiVigors & Horsfield, 1827
# Morus serratorGray, 1843
# Morus serratorGray, 1843
# Tachybaptus novaehollandiaeStephens, 1826
# Tachybaptus novaehollandiaeStephens, 1826
# Anthus novaeseelandiae(Gmelin, 1789)
# Anthusnovaeseelandiae
# Spatula rhynchotis(Latham, 1801)
# Spatularhynchotis
# Porphyrio melanotus(Temminck, 1820)
# Porphyriomelanotus
# Ninox boobook(Latham, 1801)
# Ninoxboobook
# Alectura lathamiGray, 1831
# Alectura lathamiGray, 1831
# Ardeotis australis(Gray, 1829)
# Ardeotisaustralis
# Failed : Australian crake
# Pachycephala pectoralis(Latham, 1801)
# Pachycephalapectoralis
# Falco longipennisSwainson, 1838
# Falco longipennisSwainson, 1838
# Alisterus scapularis(Lichtenstein, 1818)
# Alisterusscapularis
# Orthonyx temminckiiRanzani, 1822
# Orthonyx temminckiiRanzani, 1822
# Gymnorhina tibicen(Latham, 1801)
# Gymnorhinatibicen
# Tyto novaehollandiae(Stephens, 1826)
# Tytonovaehollandiae
# Aegotheles cristatus(Shaw, 1790)
# Aegothelescristatus
# Rostratula australis(Gould, 1838)
# Rostratulaaustralis
# Pelecanus conspicillatusTemminck, 1824
# Pelecanus conspicillatusTemminck, 1824
# Phalacrocorax varius(Gmelin, 1789)
# Phalacrocoraxvarius
# Stiltia isabella(Vieillot, 1816)
# Stiltiaisabella
# Corvus coronoidesVigors & Horsfield, 1827
# Corvus coronoidesVigors & Horsfield, 1827
# Acrocephalus australis(Gould, 1838)
# Acrocephalusaustralis
# Barnardius zonarius(Shaw, 1805)
# Barnardiuszonarius
# Tadorna tadornoides(Jardine & Selby, 1828)
# Tadornatadornoides
# Aerodramus terraereginae(Ramsay, 1875)
# Aerodramusterraereginae
# Gelochelidon macrotarsa(Gould, 1837)
# Gelochelidonmacrotarsa
# Threskiornis moluccaCuvier, 1829
# Threskiornis moluccaCuvier, 1829
# Chenonetta jubata(Latham, 1801)
# Chenonettajubata
# Asthenes ayacuchensisVaurie, Weske & Terborgh, 1972
# Asthenes ayacuchensisVaurie, Weske & Terborgh, 1972
# Pycnonotus blanfordiJerdon, 1862
# Pycnonotus blanfordiJerdon, 1862
# Hieraaetus ayresiiGurney, 1862
# Hieraaetus ayresiiGurney, 1862
# Failed : Ayress hawkeagle
# Synallaxis azaraeD'Orbigny, 1835
# Synallaxis azaraeD'Orbigny, 1835
# Pyrrhula murinaGodman, 1866
# Pyrrhula murinaGodman, 1866
# Rallus tenuirostrisRidgway, 1874
# Rallus tenuirostrisRidgway, 1874
# Ridgwayia pinicola(PL Sclater, 1859)
# Ridgwayiapinicola
# Leptotila battyiRothschild, 1901
# Leptotila battyiRothschild, 1901
# Eurystomus azureusGray, G.R., 1860
# Eurystomus azureusGray, G.R., 1860
# Porphyrio flavirostris(Gmelin, 1789)
# Porphyrioflavirostris
# Cyanocorax caeruleusVieillot, 1818
# Cyanocorax caeruleusVieillot, 1818
# Ceyx azureusLatham, 1801
# Ceyx azureusLatham, 1801
# Failed : Azure tit
# Pitta steerii(Sharpe, 1876)
# Pittasteerii
# Myiagra azureocapillaLayard, 1875
# Myiagra azureocapillaLayard, 1875
# Saucerottia cyanocephala(Lesson, 1829)
# Saucerottiacyanocephala
# Cyanolyca cucullata(Ridgway, 1885)
# Cyanolycacucullata
# Cyanocorax heilpriniA. F. Gentry, 1885
# Cyanocorax heilpriniA. F. Gentry, 1885
# Poecilostreptus cabanisi(PL Sclater, 1868)
# Poecilostreptuscabanisi
# Thraupis cyanoptera(Vieillot, 1817)
# Thraupiscyanoptera
# Cyanopica cyanusPallas, 1776
# Cyanopica cyanusPallas, 1776
# Neocichla gutturalis(Barboza du Bocage, 1871)
# Neocichlagutturalis
# Peucaea aestivalis(Lichtenstein, 1823)
# Peucaeaaestivalis
# Vermivora bachmaniiAudubon, 1833
# Vermivora bachmaniiAudubon, 1833
# Aythya baeri(Radde, 1863)
# Aythyabaeri
# Ploceus baglafecht(Daudin, 1802)
# Ploceusbaglafecht
# Leonardina woodi(Mearns, 1905)
# Leonardinawoodi
# Mimus gundlachiiCabanis, 1855
# Mimus gundlachiiCabanis, 1855
# Icterus northropi(J. A. Allen, 1890)
# Icterusnorthropi
# Tachycineta cyaneoviridis(Bryant, 1859)
# Tachycinetacyaneoviridis
# Setophaga flavescens(Todd, 1909)
# Setophagaflavescens
# Nesophlox evelynae(Bourcier, 1847)
# Nesophloxevelynae
# Geothlypis rostrata(Bryant, 1867)
# Geothlypisrostrata
# Herpsilochmus pileatus(Lichtenstein, 1823)
# Herpsilochmuspileatus
# Synallaxis cinereaWied, 1831
# Synallaxis cinereaWied, 1831
# Eleoscytalopus psychopompus(Teixeira & Carnevalli, 1989)
# Eleoscytalopuspsychopompus
# Phylloscartes beckeriGonzaga & Pacheco, 1995[2]
# Phylloscartes beckeriGonzaga & Pacheco, 1995[2]
# Scytalopus gonzagaiMaurício, Belmonte-Lopes, Pacheco, Silveira, Whitney & Bornschein, 2014
# Scytalopus gonzagaiMaurício, Belmonte-Lopes, Pacheco, Silveira, Whitney & Bornschein, 2014
# Locustella davidi(La Touche, 1923)
# Locustelladavidi
# Sibirionetta formosa(Georgi, 1775)
# Sibirionettaformosa
# Zapornia pusilla(Pallas, 1776)
# Zaporniapusilla
# Myiodynastes bairdii(Gambel, 1847)
# Myiodynastesbairdii
# Junco bairdi(Ridgway, 1883)
# Juncobairdi
# Calidris bairdiiCoues, 1861
# Calidris bairdiiCoues, 1861
# Centronyx bairdii(Audubon, 1844)
# Centronyxbairdii
# Trogon bairdiiLawrence, 1868
# Trogon bairdiiLawrence, 1868
# Glaucidium hoskinsiBrewster, 1888
# Glaucidium hoskinsiBrewster, 1888
# Failed : Bald eagle
# Pyrilia aurantiocephala(Gaban-Lima, Raposo, M & Hofling, 2002)
# Pyriliaaurantiocephala
# Puffinus mauretanicusP.R. Lowe, 1921
# Puffinus mauretanicusP.R. Lowe, 1921
# Curruca balearicavon Jordans, 1913
# Curruca balearicavon Jordans, 1913
# Leucopsar rothschildiStresemann, 1912
# Leucopsar rothschildiStresemann, 1912
# Dicrurus balicassius(Linnaeus, 1766)
# Dicrurusbalicassius
# Pachycephala balimRand, 1940
# Pachycephala balimRand, 1940
# Failed : Baliem whistler
# Megascops seductus(Moore, RT, 1941)
# Megascopsseductus
# Icterus galbula(Linnaeus, 1758)
# Icterusgalbula
# Cymbilaimus sanctaemariaeGyldenstolpe, 1941
# Cymbilaimus sanctaemariaeGyldenstolpe, 1941
# Anabazenops dorsalisSclater & Salvin, 1880
# Anabazenops dorsalisSclater & Salvin, 1880
# Locustella alfrediHartlaub, 1890
# Locustella alfrediHartlaub, 1890
# Gecinulus viridisBlyth, 1862
# Gecinulus viridisBlyth, 1862
# Apalis bamendaeBannerman, 1922
# Apalis bamendaeBannerman, 1922
# Cercomacra ferdinandiSnethlage, 1928
# Cercomacra ferdinandiSnethlage, 1928
# Coereba flaveola(Linnaeus, 1758)
# Coerebaflaveola
# Montecincla jerdoni(Blyth, 1851)
# Montecinclajerdoni
# Myzomela boiei(Müller, 1843)
# Myzomelaboiei
# Campylorhynchus zonatus(Lesson, 1832)
# Campylorhynchuszonatus
# Zapornia paykullii(Ljungh, 1813)
# Zaporniapaykullii
# Pulsatrix melanota(Tschudi, 1844)
# Pulsatrixmelanota
# Dichrozona cincta(Pelzeln, 1868)
# Dichrozonacincta
# Lybius undatus(Rüppell, 1837)
# Lybiusundatus
# Cacomantis sonneratii(Latham, 1790)
# Cacomantissonneratii
# Eurylaimus javanicusHorsfield, 1821
# Eurylaimus javanicusHorsfield, 1821
# Cotinga maculata(Müller, 1776)
# Cotingamaculata
# Ptilinopus cinctusTemminck, 1810
# Ptilinopus cinctusTemminck, 1810
# Anthreptes rubritorquesReichenow, 1905
# Anthreptes rubritorquesReichenow, 1905
# Neomorphus radiolosusSclater & Salvin, 1878
# Neomorphus radiolosusSclater & Salvin, 1878
# Cissomela pectoralis(Gould, 1841)
# Cissomelapectoralis
# Falco zoniventrisPeters, 1854
# Falco zoniventrisPeters, 1854
# Lacedo pulchella(Horsfield, 1821)
# Lacedopulchella
# Vanellus tricolor(Vieillot, 1818)
# Vanellustricolor
# Neophedina cincta(Boddaert, 1783)
# Neophedinacincta
# Curruca boehmi(Reichenow, 1882)
# Currucaboehmi
# Prinia bairdii(Cassin, 1855)
# Priniabairdii
# Philortyx fasciatus(Gould, 1844)
# Philortyxfasciatus
# Cladorhynchus leucocephalus(Vieillot, 1816)
# Cladorhynchusleucocephalus
# Platysteira laticinctaBates, 1926
# Platysteira laticinctaBates, 1926
# Aphelocephala nigricincta(North, 1895)
# Aphelocephalanigricincta
# Chrysophlegma miniaceumPennant, 1769
# Chrysophlegma miniaceumPennant, 1769
# Thryophilus pleurostictus(PL Sclater, 1860)
# Thryophiluspleurostictus
# Gennaeodryas placens(Ramsay, E.P., 1879)
# Gennaeodryasplacens
# Hydrobates castro(Harcourt, 1851)
# Hydrobatescastro
# Chaetura spinicaudus(Temminck, 1839)
# Chaeturaspinicaudus
# Hypocnemoides maculicauda(Pelzeln, 1868)
# Hypocnemoidesmaculicauda
# Thamnophilus melanothoraxSclater, 1857
# Thamnophilus melanothoraxSclater, 1857
# Myrmotherula urosticta(Sclater, 1857)
# Myrmotherulaurosticta
# Threnetes ruckeri(Bourcier, 1847)
# Threnetesruckeri
# Ochetorhynchus phoenicurus(Gould, 1839)
# Ochetorhynchusphoenicurus
# Pipreola intermediaTaczanowski, 1884
# Pipreola intermediaTaczanowski, 1884
# Penelope argyrotisBonaparte, 1856
# Penelope argyrotisBonaparte, 1856
# Furnarius figulus(Lichtenstein, 1823)
# Furnariusfigulus
# Pipra fasciicaudaHellmayr, 1906
# Pipra fasciicaudaHellmayr, 1906
# Nyctiprogne leucopyga(Spix, 1825)
# Nyctiprogneleucopyga
# Cacicus latirostris(Swainson, 1838)
# Cacicuslatirostris
# Patagioenas fasciata(Say, 1823)
# Patagioenasfasciata
# Catamenia analis(d'Orbigny & Lafresnaye, 1837)
# Catameniaanalis
# Porphyrospiza alaudina(Kittlitz, 1833)
# Porphyrospizaalaudina
# Systellura longirostris(Bonaparte, 1825)
# Systelluralongirostris
# Corvus unicolor(Rothschild & Hartert, 1900)
# Corvusunicolor
# Ptilinopus subgularis(Meyer & Wiglesworth, 1896)
# Ptilinopussubgularis
# Cyornis pelingensis(Vaurie, 1952)
# Cyornispelingensis
# Failed : Banggai jungle flycatcher
# Bradypterus bangwaensisDelacour, 1943
# Bradypterus bangwaensisDelacour, 1943
# Phalacrocorax neglectus(Wahlberg, 1855)
# Phalacrocoraxneglectus
# Acridotheres ginginianus(Latham, 1790)
# Acridotheresginginianus
# Puffinus bannermani(Mathews & Iredale, 1915)
# Puffinusbannermani
# Cyanomitra bannermaniC. H. B. Grant & Mackworth-Praed, 1943
# Cyanomitra bannermaniC. H. B. Grant & Mackworth-Praed, 1943
# Tauraco bannermani(Bates, 1923)
# Tauracobannermani
# Ploceus bannermaniChapin, 1932
# Ploceus bannermaniChapin, 1932
# Pterodroma barauiJouanin, 1964
# Pterodroma barauiJouanin, 1964
# Arborophila brunneopectusBlyth, 1855
# Arborophila brunneopectusBlyth, 1855
# Loxigilla barbadensisCory, 1886
# Loxigilla barbadensisCory, 1886
# Alectoris barbara(Bonnaterre, 1791)
# Alectorisbarbara
# Coracina striata(Boddaert, 1783)
# Coracinastriata
# Hydrornis elliotii(Oustalet, 1874)
# Hydrorniselliotii
# Hylexetastes stresemanniSnethlage, 1925
# Hylexetastes stresemanniSnethlage, 1925
# Veniliornis nigriceps(D'Orbigny, 1840)
# Veniliornisnigriceps
# Lagonosticta rufopicta(Fraser, 1843)[2]
# Lagonostictarufopicta
# Ramsayornis fasciatus(Gould, 1843)
# Ramsayornisfasciatus
# Picumnus aurifronsPelzeln, 1870
# Picumnus aurifronsPelzeln, 1870
# Setophaga subita(Riley, 1904)
# Setophagasubita
# Thamnophilus multistriatusLafresnaye, 1844
# Thamnophilus multistriatusLafresnaye, 1844
# Turdoides gymnogenys(Hartlaub, 1865)
# Turdoidesgymnogenys
# Apaloderma aequatorialeSharpe, 1901
# Apaloderma aequatorialeSharpe, 1901
# Gymnocichla nudiceps(Cassin, 1850)
# Gymnocichlanudiceps
# Rhegmatorhina gymnopsRidgway, 1888
# Rhegmatorhina gymnopsRidgway, 1888
# Streptocitta albertinae(Schlegel, 1866)
# Streptocittaalbertinae
# Patagioenas corensis(Jacquin, 1784)
# Patagioenascorensis
# Gymnocrex plumbeiventris(Gray, 1862)
# Gymnocrexplumbeiventris
# Turdus tephronotusCabanis, 1878
# Turdus tephronotusCabanis, 1878
# Zosterops superciliosusNorth, 1906
# Zosterops superciliosusNorth, 1906
# Nok hualonWoxvold, Duckworth, & Timmins, 2009
# Nok hualonWoxvold, Duckworth, & Timmins, 2009
# Crax fasciolataSpix, 1825
# Crax fasciolataSpix, 1825
# Crinifer personatus(Rüppell, 1842)
# Criniferpersonatus
# Metriopelia ceciliae(Lesson, 1845)
# Metriopeliaceciliae
# Phimosus infuscatus(Lichtenstein, 1823)
# Phimosusinfuscatus
# Melanocichla calva(Sharpe, 1888)
# Melanocichlacalva
# Margarobyas lawrenciiP.L. Sclater & Salvin, 1868
# Margarobyas lawrenciiP.L. Sclater & Salvin, 1868
# Aerodramus nuditarsus(Salomonsen, 1962)
# Aerodramusnuditarsus
# Gymnoderus foetidus(Linnaeus, 1758)
# Gymnoderusfoetidus
# Cephalopterus glabricollisGould, 1851
# Cephalopterus glabricollisGould, 1851
# Megascops clarkii(L.Kelso & E.H.Kelso, 1935)
# Megascopsclarkii
# Procnias nudicollis(Vieillot, 1817)
# Procniasnudicollis
# Tigrisoma mexicanumSwainson, 1834
# Tigrisoma mexicanumSwainson, 1834
# Pachycephala nudigulaHartert, 1897
# Pachycephala nudigulaHartert, 1897
# Anser indicus(Latham, 1790)
# Anserindicus
# Vidua larvaticolaPayne, 1982
# Vidua larvaticolaPayne, 1982
# Ducula latrans(Peale, 1848)
# Duculalatrans
# Ninox connivens(Latham, 1801)
# Ninoxconnivens
# Calendulauda barlowi(Roberts, 1937)
# Calendulaudabarlowi
# Hirundo rusticaLinnaeus, 1758
# Hirundo rusticaLinnaeus, 1758
# Branta leucopsis(Bechstein, 1803)
# Brantaleucopsis
# Puffinus baroliBonaparte, 1857[1]
# Puffinus baroliBonaparte, 1857[1]
# Bradypterus barrattiSharpe, 1876
# Bradypterus barrattiSharpe, 1876
# Thamnophilus doliatus(Linnaeus, 1764)
# Thamnophilusdoliatus
# Chamaeza mollissimaSclater, 1855
# Chamaeza mollissimaSclater, 1855
# Pachyramphus versicolor(Hartlaub, 1843)
# Pachyramphusversicolor
# Turnix suscitator(Gmelin, 1789)
# Turnixsuscitator
# Macropygia unchall(Wagler, 1827)
# Macropygiaunchall
# Coracina lineata(Swainson, 1825)
# Coracinalineata
# Geopelia maugeus(Temminck, 1809)
# Geopeliamaugeus
# Bubo sumatranus(Raffles, 1822)
# Bubosumatranus
# Micrastur ruficollis(Vieillot, 1817)
# Micrasturruficollis
# Pipreola arcuata(Lafresnaye, 1843)
# Pipreolaarcuata
# Morphnarchus princepsSclater, 1865
# Morphnarchus princepsSclater, 1865
# Pernis celebensisWallace, 1868
# Pernis celebensisWallace, 1868
# Glycifohia undulatus(Sparrman, 1787)
# Glycifohiaundulatus
# Ianthocincla lunulataVerreaux, 1871
# Ianthocincla lunulataVerreaux, 1871
# Cercococcyx montanusChapin, 1928
# Cercococcyx montanusChapin, 1928
# Strix variaBarton, 1799
# Strix variaBarton, 1799
# Aegotheles bennettiiSalvadori & D'Albertis, 1875
# Aegotheles bennettiiSalvadori & D'Albertis, 1875
# Bolborhynchus lineola(Cassin, 1853)
# Bolborhynchuslineola
# Nystalus radiatus(Sclater, 1854)
# Nystalusradiatus
# Hypotaenidia torquata(Linnaeus, 1766)
# Hypotaenidiatorquata
# Crypturellus casiquiareChapman 1929[2]
# Crypturellus casiquiareChapman 1929[2]
# Curruca nisoria(Bechstein, 1792, central and northern Germany)
# Currucanisoria
# Calamonastes fasciolatus(Smith, 1847)
# Calamonastesfasciolatus
# Bucephala islandica(Gmelin, 1789)
# Bucephalaislandica
# Geopelia humeralis(Temminck, 1821)
# Geopeliahumeralis
# Macropygia nigrirostrisSalvadori, 1875
# Macropygia nigrirostrisSalvadori, 1875
# Limosa lapponica(Linnaeus, 1758)
# Limosalapponica
# Ammomanes cinctura(Gould, 1839)
# Ammomanescinctura
# Certhia himalayanaVigors, 1832
# Certhia himalayanaVigors, 1832
# Apaloderma vittatumShelley, 1882
# Apaloderma vittatumShelley, 1882
# Apalis thoracicaShaw, 1811
# Apalis thoracicaShaw, 1811
# Actinodura strigula(Hodgson, 1837)
# Actinodurastrigula
# Crypturellus bartlettiSclater & Salvin 1873[2]
# Crypturellus bartlettiSclater & Salvin 1873[2]
# Macropygia modiglianiiSalvadori, 1887
# Macropygia modiglianiiSalvadori, 1887
# Hemipus picatus(Sykes, 1832)
# Hemipuspicatus
# Icterus maculialatusCassin, 1848
# Icterus maculialatusCassin, 1848
# Prinia familiarisHorsfield, 1821
# Prinia familiarisHorsfield, 1821
# Failed : Barwinged rail
# Ploceus angolensis(Barboza du Bocage, 1878)
# Ploceusangolensis
# Henicorhina leucopteraFitzpatrick, Terborgh & Willard, 1977
# Henicorhina leucopteraFitzpatrick, Terborgh & Willard, 1977
# Spelaeornis troglodytoides(Verreaux, 1870)
# Spelaeornistroglodytoides
# Acrocephalus griseldis(Hartlaub, 1891)
# Acrocephalusgriseldis
# Zoothera lunulata(Latham, 1801)
# Zootheralunulata
# Falco rufigularisDaudin, 1800
# Falco rufigularisDaudin, 1800
# Macheiramphus alcinusBonaparte, 1850
# Macheiramphus alcinusBonaparte, 1850
# Terathopius ecaudatus(Daudin, 1800)
# Terathopiusecaudatus
# Caprimulgus batesiSharpe, 1906
# Caprimulgus batesiSharpe, 1906
# Terpsiphone batesiChapin, 1921
# Terpsiphone batesiChapin, 1921
# Cinnyris batesi(Ogilvie-Grant, 1908)[2]
# Cinnyrisbatesi
# Apus batesi(Sharpe, 1904)[2]
# Apusbatesi
# Ploceus batesi(Sharpe, 1908)
# Ploceusbatesi
# Zanda baudinii(Lear, 1832)
# Zandabaudinii
# Failed : Baudo guan
# Penelope ortoniSalvin, 1874
# Penelope ortoniSalvin, 1874
# Psarocolius cassini(Richmond, 1898)
# Psarocoliuscassini
# Phyllastrephus baumanniReichenow, 1895
# Phyllastrephus baumanniReichenow, 1895
# Grallaria capitalisChapman, 1926
# Grallaria capitalisChapman, 1926
# Centropus celebensisQuoy & Gaimard, 1830
# Centropus celebensisQuoy & Gaimard, 1830
# Furnarius torridusSclater & Salvin, 1866
# Furnarius torridusSclater & Salvin, 1866
# Blythipicus pyrrhotis(Hodgson, 1837)
# Blythipicuspyrrhotis
# Cantorchilus nigricapillus(PL Sclater, 1860)
# Cantorchilusnigricapillus
# Ploceus philippinus(Linnaeus, 1766)
# Ploceusphilippinus
# Lanius vittatus(Valenciennes, 1826)
# Laniusvittatus
# Coccyzus rufigularis(Hartlaub, 1852)
# Coccyzusrufigularis
# Setophaga castanea(Wilson, 1810)
# Setophagacastanea
# Spartonoica maluroides(D'Orbigny & Lafresnaye, 1837)
# Spartonoicamaluroides
# Castanozoster thoracicus(Nordmann, 1835)
# Castanozosterthoracicus
# Atlapetes seebohmi(Taczanowski, 1883)
# Atlapetesseebohmi
# Tangara gyrola(Linnaeus, 1758)
# Tangaragyrola
# Phylloscartes sylviolus(Cabanis & Heine, 1857)
# Phylloscartessylviolus
# Doliornis sclateri(Taczanowski, 1874)
# Doliornissclateri
# Todiramphus saurophagus(Gould, 1843)
# Todiramphussaurophagus
# Esacus magnirostris(Vieillot, 1818)
# Esacusmagnirostris
# Lybius dubiusGmelin, 1788
# Lybius dubiusGmelin, 1788
# Procnias averano(Hermann, 1783)
# Procniasaverano
# Penelope barbataChapman, 1921
# Penelope barbataChapman, 1921
# Oreonympha nobilisGould, 1869
# Oreonympha nobilisGould, 1869
# Failed : Bearded reedling
# Megascops barbarus(Sclater & Salvin, 1868)
# Megascopsbarbarus
# Cercotrichas quadrivirgata(Reichenow, 1879)
# Cercotrichasquadrivirgata
# Polystictus pectoralis(Vieillot, 1817)
# Polystictuspectoralis
# Failed : Bearded vulture
# Dendrortyx barbatusGould, 1846
# Dendrortyx barbatusGould, 1846
# Chloropicus namaquus(Lichtenstein, 1793)
# Chloropicusnamaquus
# Circaetus beaudouiniVerreaux & Des Murs, 1862
# Circaetus beaudouiniVerreaux & Des Murs, 1862
# Stagonopleura bella(Latham, 1801)
# Stagonopleurabella
# Ptilinopus pulchellus(Temminck, 1835)
# Ptilinopuspulchellus
# Cyanolyca pulchra(Lawrence, 1876)
# Cyanolycapulchra
# Sitta formosaBlyth, 1843
# Sitta formosaBlyth, 1843
# Calothorax pulcherGould, 1859
# Calothorax pulcherGould, 1859
# Heterophasia pulchella(Godwin-Austen, 1874)
# Heterophasiapulchella
# Cinnyris pulchellus(Linnaeus, 1766)
# Cinnyrispulchellus
# Margarornis bellulusNelson, 1912
# Margarornis bellulusNelson, 1912
# Melanerpes pulcher(Sclater, 1870)
# Melanerpespulcher
# Pseudobulweria becki(Murphy, 1928)
# Pseudobulweriabecki
# Terpsiphone bedfordi(Ogilvie-Grant, 1907)
# Terpsiphonebedfordi
# Mellisuga helenae(Lembeye, 1850)
# Mellisugahelenae
# Chersomanes beesleyiBenson, 1966
# Chersomanes beesleyiBenson, 1966
# Rhopophilus pekinensis(R. Swinhoe, 1868)
# Rhopophiluspekinensis
# Larus belcheriVigors, 1829
# Larus belcheriVigors, 1829
# Geothlypis beldingi(Ridgway, 1883)
# Geothlypisbeldingi
# Melidectes belfordi(De Vis, 1890)
# Melidectesbelfordi
# Manorina melanophrys(Latham, 1801)
# Manorinamelanophrys
# Artemisiospiza belli(Cassin, 1850)
# Artemisiospizabelli
# Vireo belliiAudubon, 1844
# Vireo belliiAudubon, 1844
# Xenotriccus callizonusDwight & Griscom, 1927
# Xenotriccus callizonusDwight & Griscom, 1927
# Megaceryle alcyon(Linnaeus, 1758)
# Megacerylealcyon
# Toxostoma bendirei(Coues, 1873)
# Toxostomabendirei
# Mirafra assamicaHorsfield, 1840
# Mirafra assamicaHorsfield, 1840
# Houbaropsis bengalensis(Gmelin, 1789)
# Houbaropsisbengalensis
# Certhilauda benguelensis(Sharpe, 1904)
# Certhilaudabenguelensis
# Locustella seebohmi(Ogilvie-Grant, 1895)
# Locustellaseebohmi
# Campethera bennettii(Smith, 1836)
# Campetherabennettii
# Asthenes berlepschi(Hellmayr, 1917)
# Asthenesberlepschi
# Crypturellus berlepschiRothschild 1897[2]
# Crypturellus berlepschiRothschild 1897[2]
# Colaptes oceanicusOlson, 2013[2]
# Colaptes oceanicusOlson, 2013[2]
# †Bermuteo avivorusOlson, 2008
# Bermuteo avivorusOlson, 2008
# Nyctanassa carcinocatactesOlson & Wingate, 2006
# Nyctanassa carcinocatactesOlson & Wingate, 2006
# Pterodroma cahow(Nichols & Mowbray, 1916)
# Pterodromacahow
# Aegolius gradyiOlson, 2012
# Aegolius gradyiOlson, 2012
# Failed : Bermuda towhee
# Anas bernieri(Hartlaub, 1860)
# Anasbernieri
# Oriolia bernieriI. Geoffroy Saint-Hilaire, 1838
# Oriolia bernieriI. Geoffroy Saint-Hilaire, 1838
# Anthus berthelotiiBolle, 1862[2]
# Anthus berthelotiiBolle, 1862[2]
# Drymophila rubricollis(Bertoni, 1901)
# Drymophilarubricollis
# Ploceus bertrandi(Shelley, 1893)
# Ploceusbertrandi
# Saucerottia beryllina(Deppe, 1830)
# Saucerottiaberyllina
# Tangara nigroviridis(Lafresnaye, 1843)
# Tangaranigroviridis
# Failed : Besra
# Thryomanes bewickii(Audubon, 1829)
# Thryomanesbewickii
# Trochalopteron imbricatum(Blyth, 1843)
# Trochalopteronimbricatum
# Myiagra atraMeyer, 1874
# Myiagra atraMeyer, 1874
# Centropus chalybeus(Salvadori, 1875)
# Centropuschalybeus
# Gerygone hypoxanthaSalvadori, 1878
# Gerygone hypoxanthaSalvadori, 1878
# Phylloscopus misoriensisMeise, 1931
# Phylloscopus misoriensisMeise, 1931
# Trichoglossus rosenbergiiSchlegel, 1871
# Trichoglossus rosenbergiiSchlegel, 1871
# Symposiachrus brehmii(Schlegel, 1871)
# Symposiachrusbrehmii
# Tanysiptera riedeliiVerreaux, 1866
# Tanysiptera riedeliiVerreaux, 1866
# Otus beccarii(Salvadori, 1876)
# Otusbeccarii
# Megapodius geelvinkianusMeyer, 1874
# Megapodius geelvinkianusMeyer, 1874
# Pachycephala melanorhyncha(A. B. Meyer, 1874)
# Pachycephalamelanorhyncha
# Failed : Biak whistler
# Zosterops mysorensisMeyer, AB, 1874
# Zosterops mysorensisMeyer, AB, 1874
# Phylloscopus valentini(Hartert, 1907)
# Phylloscopusvalentini
# Catharus bicknelli(Ridgway, 1882)
# Catharusbicknelli
# Robsonius sorsogonensis(Rand & Rabor, 1967)
# Robsoniussorsogonensis
# Gymnopithys bicolor(Lawrence, 1863)
# Gymnopithysbicolor
# Failed : Bicolored antpitta
# Grallaria rufocinereaSclater & Salvin, 1879
# Grallaria rufocinereaSclater & Salvin, 1879
# Dysithamnus occidentalis(Chapman, 1923)
# Dysithamnusoccidentalis
# Conirostrum bicolor(Vieillot, 1809)
# Conirostrumbicolor
# Dicaeum bicolor(Bourns & Worcester, 1894)
# Dicaeumbicolor
# Accipiter bicolor(Vieillot, 1817)
# Accipiterbicolor
# Failed : Bicolored scrubwren
# Campylorhynchus griseus(Swainson, 1837)
# Campylorhynchusgriseus
# Podoces biddulphiHume, 1874
# Podoces biddulphiHume, 1874
# Melanocorypha bimaculata(Ménétrés, 1832)
# Melanocoryphabimaculata
# Streptoprocne biscutata(Sclater, 1865)
# Streptoprocnebiscutata
# †Moho bishopiRothschild, 1893
# Moho bishopiRothschild, 1893
# Failed : Bishops oo
# Myzomela pammelaenaSclater, 1877
# Myzomela pammelaenaSclater, 1877
# Corvus insularisHeinroth, 1903
# Corvus insularisHeinroth, 1903
# Rhipidura dahliReichenow, 1897
# Rhipidura dahliReichenow, 1897
# Loriculus tenerSclater, 1877
# Loriculus tenerSclater, 1877
# Ceyx websteri(Hartert, 1898)
# Ceyxwebsteri
# Erythropitta novaehibernicae(EP Ramsay, 1878)
# Erythropittanovaehibernicae
# Pachycephala citreogasterRamsay, 1876
# Pachycephala citreogasterRamsay, 1876
# Failed : Bismarck whistler
# Zosterops hypoxanthusSalvadori, 1881
# ...
# Loxipasser anoxanthus(Gosse, 1847)
# Loxipasseranoxanthus
# Parkerthraustes humeralis(Lawrence, 1867)
# Parkerthrausteshumeralis
# Dicaeum aureolimbatum(Wallace, 1865)
# Dicaeumaureolimbatum
# Gymnoris pyrgita(Heuglin, 1862)
# Gymnorispyrgita
# Meliphaga notata(Gould, 1867)
# Meliphaganotata
# Phyllastrephus flavostriatus(Sharpe, 1876)
# Phyllastrephusflavostriatus
# Phylloscopus armandiiMilne-Edwards, 1865
# Phylloscopus armandiiMilne-Edwards, 1865
# Atlapetes citrinellus(Cabanis, 1883)
# Atlapetescitrinellus
# Zanda funereaShaw, 1794
# Zanda funereaShaw, 1794
# Icterus mesomelas(Wagler, 1829)
# Icterusmesomelas
# Pionites xanthurus(Todd, 1925)
# Pionitesxanthurus
# Atlapetes tibialis(Lawrence, 1864)
# Atlapetestibialis
# Myrmotherula ambiguaZimmer, 1932
# Myrmotherula ambiguaZimmer, 1932
# Apalis flavigularisShelley, 1893
# Apalis flavigularisShelley, 1893
# Pycnonotus xantholaemus(Jerdon, 1845)
# Pycnonotusxantholaemus
# Emberiza elegansTemminck, 1835
# Emberiza elegansTemminck, 1835
# Gymnoris superciliarisBlyth, 1845
# Gymnoris superciliarisBlyth, 1845
# Chlorospingus flavigularis(Sclater, 1852)
# Chlorospingusflavigularis
# Chrysococcyx flavigularisShelley, 1880
# Chrysococcyx flavigularisShelley, 1880
# Euphonia hirundinaceaBonaparte, 1838
# Euphonia hirundinaceaBonaparte, 1838
# Conopias parvus(Pelzeln, 1868)
# Conopiasparvus
# Schoeniparus cinereusBlyth, 1847
# Schoeniparus cinereusBlyth, 1847
# Arizelocichla chlorigula(Reichenow, 1899)
# Arizelocichlachlorigula
# Loriculus pusillusGray, 1859
# Loriculus pusillusGray, 1859
# Nesoptilotis flavicollis(Vieillot, 1817)
# Nesoptilotisflavicollis
# Pterorhinus galbanus(Godwin-Austen, 1874)
# Pterorhinusgalbanus
# Chloropsis palawanensis(Sharpe, 1877)
# Chloropsispalawanensis
# Atimastillas flavicollis(Swainson, 1837)
# Atimastillasflavicollis
# Macronyx croceus(Vieillot, 1816)
# Macronyxcroceus
# Failed : Yellowthroated miner
# Nicator vireoCabanis, 1876
# Nicator vireoCabanis, 1876
# Pterocles gutturalisSmith, 1836
# Pterocles gutturalisSmith, 1836
# Neosericornis citreogularis(Gould, 1838)
# Neosericorniscitreogularis
# Crithagra flavigula(Salvadori, 1888)
# Crithagraflavigula
# Platyrinchus flavigularisSclater, 1862
# Platyrinchus flavigularisSclater, 1862
# Gymnoris xanthocollis(Burton, 1838)
# Gymnorisxanthocollis
# Iridosornis analis(Tschudi, 1844)
# Iridosornisanalis
# Pogoniulus subsulphureus(Fraser, 1843)
# Pogoniulussubsulphureus
# Ramphastos ambiguusSwainson, 1823
# Ramphastos ambiguusSwainson, 1823
# Failed : Yellowthroated vireo
# Setophaga dominica(Linnaeus, 1766)
# Setophagadominica
# Pachycephala macrorhynchaStrickland, 1849
# Pachycephala macrorhynchaStrickland, 1849
# Zosterops metcalfiiTristram, 1894
# Zosterops metcalfiiTristram, 1894
# Phylloscopus ruficapillaSundevall, 1850
# Phylloscopus ruficapillaSundevall, 1850
# Piculus flavigula(Boddaert, 1783)
# Piculusflavigula
# Ptilotula flavescens(Gould, 1840)
# Ptilotulaflavescens
# Failed : Yellowtufted dacnis
# Lichenostomus melanopsLatham, 1801
# Lichenostomus melanopsLatham, 1801
# Melanerpes cruentatus(Boddaert, 1783)
# Melanerpescruentatus
# Pycnonotus goiavier(Scopoli, 1786)
# Pycnonotusgoiavier
# Eremomela flavicrissalisSharpe, 1895
# Eremomela flavicrissalisSharpe, 1895
# Dicaeum chrysorrheumTemminck, 1829
# Dicaeum chrysorrheumTemminck, 1829
# Treron seimundi(Robinson, 1910)
# Treronseimundi
# Phylloscopus cantatorTickell, 1833
# Phylloscopus cantatorTickell, 1833
# Veniliornis dignus(Sclater & Salvin, 1877)
# Veniliornisdignus
# Poliolophus urostictus(Salvadori, 1870)
# Poliolophusurostictus
# Vanellus malabaricus(Boddaert, 1783)
# Vanellusmalabaricus
# Chlorospingus parvirostrisChapman, 1901
# Chlorospingus parvirostrisChapman, 1901
# Eurillas latirostris(Strickland, 1844)
# Eurillaslatirostris
# Agelasticus thilius(Molina, 1782)
# Agelasticusthilius
# Pytilia hypogrammicaSharpe, 1870
# Pytilia hypogrammicaSharpe, 1870
# Thraupis abbas(Deppe, 1830)
# Thraupisabbas
# Vireo carmioliBaird, 1866
# Vireo carmioliBaird, 1866
# Linaria yemenensis(Ogilvie-Grant, 1913)
# Linariayemenensis
# Crithagra menachensis(Ogilvie-Grant, 1913)
# Crithagramenachensis
# Turdus menachensisOgilvie-Grant, 1913
# Turdus menachensisOgilvie-Grant, 1913
# Curruca buryiOgilvie-Grant, 1913
# Curruca buryiOgilvie-Grant, 1913
# Amazona xantholora(Gray, 1859)
# Amazonaxantholora
# Colinus nigrogularis(Gould, 1843)
# Colinusnigrogularis
# Myiarchus yucatanensisLawrence, 1871
# Myiarchus yucatanensisLawrence, 1871
# Polioptila albiventrisLawrence, 1885
# Polioptila albiventrisLawrence, 1885
# Cyanocorax yucatanicus(Dubois, 1875)
# Cyanocoraxyucatanicus
# Antrostomus badius(Bangs & Peck, 1908)
# Antrostomusbadius
# Nyctiphrynus yucatanicus(Hartert, 1892)
# Nyctiphrynusyucatanicus
# Vireo magister(Baird, 1871)
# Vireomagister
# Melanerpes pygmaeus(Ridgway, 1885)
# Melanerpespygmaeus
# Campylorhynchus yucatanicus(Hellmayr, 1934)
# Campylorhynchusyucatanicus
# Myrmotherula griseaCarriker, 1935
# Myrmotherula griseaCarriker, 1935
# Leptotila megaluraSclater & Salvin, 1879
# Leptotila megaluraSclater & Salvin, 1879
# Penelope bridgesiG.R. Gray, 1860
# Penelope bridgesiG.R. Gray, 1860
# Chiroxiphia bolivianaAllen, 1889
# Chiroxiphia bolivianaAllen, 1889
# Glaucidium bolivianumKönig, 1991
# Glaucidium bolivianumKönig, 1991
# Megascops hoyiKönig & Straneck, 1989
# Megascops hoyiKönig & Straneck, 1989
# Rhynchospiza dabbenei(Hellmayr, 1912)
# Rhynchospizadabbenei
# Hemitriccus spodiops(Berlepsch, 1901)
# Hemitriccusspodiops
# Phyllomyias weedeniHerzog, Kessler & Balderrama, 2008
# Phyllomyias weedeniHerzog, Kessler & Balderrama, 2008
# Failed : Yungas warbler
# Alcippe fratercula(Rippon, 1900)[1]
# Alcippefratercula
# Sitta yunnanensisOgilvie-Grant, 1900
# Sitta yunnanensisOgilvie-Grant, 1900
# Vidua codringtoni(Neave, 1907)
# Viduacodringtoni
# Hypsipetes rufigularis(Sharpe, 1877)
# Hypsipetesrufigularis
# Euplectes nigroventrisCassin, 1848
# Euplectes nigroventrisCassin, 1848
# Cyanolimnas cerveraiBarbour & Peters, 1927
# Cyanolimnas cerveraiBarbour & Peters, 1927
# Torreornis inexpectataBarbour & Peters, 1927
# Torreornis inexpectataBarbour & Peters, 1927
# Ferminia cerveraiBarbour, 1926
# Ferminia cerveraiBarbour, 1926
# Cyanoptila cumatilis(Thayer & Bangs, 1909)
# Cyanoptilacumatilis
# Passer zarudnyiPleske, 1896
# Passer zarudnyiPleske, 1896
# Geopelia striata(Linnaeus, 1766)
# Geopeliastriata
# Taeniopygia guttata(Vieillot, 1817)
# Taeniopygiaguttata
# Percnostola zeledoni(Ridgway, 1909)
# Percnostolazeledoni
# Zenaida aurita(Temminck, 1809)
# Zenaidaaurita
# Melignomon zenkeriReichenow, 1898
# Melignomon zenkeriReichenow, 1898
# Zebrilus undulatus(Gmelin, 1789)
# Zebrilusundulatus
# Tolmomyias assimilis(Pelzeln, 1868)
# Tolmomyiasassimilis
# Scytalopus zimmeriBond & Meyer de Schauensee, 1940
# Scytalopus zimmeriBond & Meyer de Schauensee, 1940
# Hemitriccus minimus(Todd, 1925)
# Hemitriccusminimus
# Dendroplex kienerii(Zimmer, 1934)
# Dendroplexkienerii
# Pterodroma madeiraMathews, 1934
# Pterodroma madeiraMathews, 1934
# Cisticola juncidis(Rafinesque, 1810)
# Cisticolajuncidis
# Ducula zoeae(Lesson, 1826)
# Duculazoeae
#                                         Binomial Name  \
# Common Name
# Abyssinian crimsonwing         Cryptospiza salvadorii
# Abyssinian ground hornbill       Bucorvus abyssinicus
# Abyssinian ground thrush           Geokichla piaggiae
# Abyssinian longclaw              Macronyx flavicollis
# Abyssinian roller                Coracias abyssinicus
# Abyssinian scimitarbill           Rhinopomastus minor
# Abyssinian slaty flycatcher  Melaenornis chocolatinus
# Abyssinian thrush                Turdus abyssinicusJ.
# Abbotts babbler                  Malacocincla abbotti
# Abbotts booby                        Papasula abbotti
#
#                                                                     Categories  \
# Common Name
# Abyssinian crimsonwing       Articles with species microformats, Articles w...
# Abyssinian ground hornbill   Articles with species microformats, Articles w...
# Abyssinian ground thrush     Articles with species microformats, Articles w...
# Abyssinian longclaw          All stub articles, Articles with species micro...
# Abyssinian roller            Articles with species microformats, Articles w...
# Abyssinian scimitarbill      All stub articles, Articles with species micro...
# Abyssinian slaty flycatcher  Articles with species microformats, Articles w...
# Abyssinian thrush            Articles with species microformats, Articles w...
# Abbotts babbler              Articles with species microformats, Articles w...
# Abbotts booby                Articles with species microformats, Articles w...
#
#                             Class Conservation status           Country  \
# Common Name
# Abyssinian crimsonwing       Aves      Least Concern           Ethiopia
# Abyssinian ground hornbill   Aves         Vulnerable                NaN
# Abyssinian ground thrush     Aves      Least Concern                NaN
# Abyssinian longclaw          Aves    Near Threatened           Ethiopia
# Abyssinian roller            Aves      Least Concern            Senegal
# Abyssinian scimitarbill      Aves      Least Concern        South Sudan
# Abyssinian slaty flycatcher  Aves      Least Concern           Ethiopia
# Abyssinian thrush            Aves      Least Concern           Ethiopia
# Abbotts babbler              Aves      Least Concern                NaN
# Abbotts booby                Aves         Endangered   Christmas Island
#
#                                                                    Description  \
# Common Name
# Abyssinian crimsonwing       The Abyssinian crimsonwing (Cryptospiza salvad...
# Abyssinian ground hornbill   The Abyssinian ground hornbill or northern gro...
# Abyssinian ground thrush     The Abyssinian ground thrush (Geokichla piaggi...
# Abyssinian longclaw          The Abyssinian longclaw (Macronyx flavicollis)...
# Abyssinian roller            The Abyssinian roller (Coracias abyssinicus), ...
# Abyssinian scimitarbill      The Abyssinian scimitarbill (Rhinopomastus min...
# Abyssinian slaty flycatcher  The Abyssinian slaty flycatcher (Melaenornis c...
# Abyssinian thrush            The Abyssinian thrush (Turdus abyssinicus) is ...
# Abbotts babbler              Abbott's babbler (Malacocincla abbotti) is a s...
# Abbotts booby                Abbott's booby (Papasula abbotti) is an endang...
#
#                                     Family                          Genus  \
# Common Name
# Abyssinian crimsonwing         Estrildidae                    Cryptospiza
# Abyssinian ground hornbill      Bucorvidae                       Bucorvus
# Abyssinian ground thrush          Turdidae                      Geokichla
# Abyssinian longclaw           Motacillidae                       Macronyx
# Abyssinian roller               Coraciidae                       Coracias
# Abyssinian scimitarbill      Phoeniculidae                  Rhinopomastus
# Abyssinian slaty flycatcher   Muscicapidae                    Melaenornis
# Abyssinian thrush                 Turdidae                         Turdus
# Abbotts babbler               Pellorneidae                   Malacocincla
# Abbotts booby                      Sulidae  PapasulaOlson & Warheit, 1988
#
#                             Habitat  \
# Common Name
# Abyssinian crimsonwing       forest
# Abyssinian ground hornbill      NaN
# Abyssinian ground thrush     forest
# Abyssinian longclaw             NaN
# Abyssinian roller               NaN
# Abyssinian scimitarbill         NaN
# Abyssinian slaty flycatcher     NaN
# Abyssinian thrush               NaN
# Abbotts babbler              forest
# Abbotts booby                forest
#
#                                                                          Image  \
# Common Name
# Abyssinian crimsonwing       https://upload.wikimedia.org/wikipedia/commons...
# Abyssinian ground hornbill   https://upload.wikimedia.org/wikipedia/commons...
# Abyssinian ground thrush     https://upload.wikimedia.org/wikipedia/commons...
# Abyssinian longclaw          https://upload.wikimedia.org/wikipedia/commons...
# Abyssinian roller            https://upload.wikimedia.org/wikipedia/commons...
# Abyssinian scimitarbill      https://upload.wikimedia.org/wikipedia/commons...
# Abyssinian slaty flycatcher  https://upload.wikimedia.org/wikipedia/commons...
# Abyssinian thrush            https://upload.wikimedia.org/wikipedia/commons...
# Abbotts babbler              https://upload.wikimedia.org/wikipedia/commons...
# Abbotts booby                https://upload.wikimedia.org/wikipedia/commons...
#
#                               Kingdom           Order    Phylum  \
# Common Name
# Abyssinian crimsonwing       Animalia   Passeriformes  Chordata
# Abyssinian ground hornbill   Animalia  Bucerotiformes  Chordata
# Abyssinian ground thrush     Animalia   Passeriformes  Chordata
# Abyssinian longclaw          Animalia   Passeriformes  Chordata
# Abyssinian roller            Animalia   Coraciiformes  Chordata
# Abyssinian scimitarbill      Animalia  Bucerotiformes  Chordata
# Abyssinian slaty flycatcher  Animalia   Passeriformes  Chordata
# Abyssinian thrush            Animalia   Passeriformes  Chordata
# Abbotts babbler              Animalia   Passeriformes  Chordata
# Abbotts booby                Animalia      Suliformes  Chordata
#
#                                                                     References  \
# Common Name
# Abyssinian crimsonwing       http://www.hbw.com/species/ethiopian-crimsonwi...
# Abyssinian ground hornbill   http://www.hbw.com/species/northern-ground-hor...
# Abyssinian ground thrush     http://www.hbw.com/species/abyssinian-ground-t...
# Abyssinian longclaw          http://datazone.birdlife.org/species/factsheet...
# Abyssinian roller            http://www.hbw.com/node/55858, http://datazone...
# Abyssinian scimitarbill      http://datazone.birdlife.org/species/factsheet...
# Abyssinian slaty flycatcher  http://www.hbw.com/species/abyssinian-slaty-fl...
# Abyssinian thrush            http://www.birdforum.net/opus/Abyssinian_Thrus...
# Abbotts babbler              http://ibc.lynxeds.com/species/abbotts-babbler...
# Abbotts booby                http://www.environment.gov.au/biodiversity/thr...
#
#                                      Species  \
# Common Name
# Abyssinian crimsonwing         C. salvadorii
# Abyssinian ground hornbill    B. abyssinicus
# Abyssinian ground thrush         G. piaggiae
# Abyssinian longclaw           M. flavicollis
# Abyssinian roller             C. abyssinicus
# Abyssinian scimitarbill             R. minor
# Abyssinian slaty flycatcher  M. chocolatinus
# Abyssinian thrush             T. abyssinicus
# Abbotts babbler                   M. abbotti
# Abbotts booby                     P. abbotti
#
#                                                                       Wiki URL
# Common Name
# Abyssinian crimsonwing       https://en.wikipedia.org/wiki/Abyssinian_crims...
# Abyssinian ground hornbill   https://en.wikipedia.org/wiki/Abyssinian_groun...
# Abyssinian ground thrush     https://en.wikipedia.org/wiki/Abyssinian_groun...
# Abyssinian longclaw          https://en.wikipedia.org/wiki/Abyssinian_longclaw
# Abyssinian roller              https://en.wikipedia.org/wiki/Abyssinian_roller
# Abyssinian scimitarbill      https://en.wikipedia.org/wiki/Abyssinian_scimi...
# Abyssinian slaty flycatcher  https://en.wikipedia.org/wiki/Abyssinian_slaty...
# Abyssinian thrush              https://en.wikipedia.org/wiki/Abyssinian_thrush
# Abbotts babbler               https://en.wikipedia.org/wiki/Abbott%27s_babbler
# Abbotts booby                   https://en.wikipedia.org/wiki/Abbott%27s_booby

# %%
pd.merge(names,wiki,on=['Common Name'])
# Out:
#                          ID                Binomial Name  \
# Common Name
# Abbotts babbler           1         Malacocincla abbotti
# Abbotts booby             2             Papasula abbotti
# Abbotts starling          3          Poeoptera femoralis
# Abd alKuri sparrow        5            Passer hemileucus
# Abdims stork              6              Ciconia abdimii
# ...                     ...                          ...
# Zimmers woodcreeper   11121          Dendroplex kienerii
# Zinos petrel          11122           Pterodroma madeira
# Zitting cisticola     11123           Cisticola juncidis
# Zoes imperial pigeon  11124                 Ducula zoeae
# Zonetailed hawk       11125  Buteo albonotatusKaup, 1847
#
#                                                              Categories Class  \
# Common Name
# Abbotts babbler       Articles with species microformats, Articles w...  Aves
# Abbotts booby         Articles with species microformats, Articles w...  Aves
# Abbotts starling      All stub articles, Articles with species micro...  Aves
# Abd alKuri sparrow    Articles containing Arabic-language text, Arti...  Aves
# Abdims stork          Articles containing video clips, Articles with...  Aves
# ...                                                                 ...   ...
# Zimmers woodcreeper   All stub articles, Articles with species micro...  Aves
# Zinos petrel          Articles with species microformats, Articles w...  Aves
# Zitting cisticola     All articles with unsourced statements, Articl...  Aves
# Zoes imperial pigeon  All stub articles, Articles with species micro...  Aves
# Zonetailed hawk       Articles with species microformats, Articles w...  Aves
#
#                      Conservation status           Country  \
# Common Name
# Abbotts babbler           Least Concern                NaN
# Abbotts booby                Endangered   Christmas Island
# Abbotts starling             Vulnerable              Kenya
# Abd alKuri sparrow           Vulnerable            Somalia
# Abdims stork              Least Concern              Sudan
# ...                                  ...               ...
# Zimmers woodcreeper     Near Threatened           Colombia
# Zinos petrel                 Endangered               Cuba
# Zitting cisticola         Least Concern          Australia
# Zoes imperial pigeon      Least Concern             Guinea
# Zonetailed hawk           Least Concern             Turkey
#
#                                                             Description  \
# Common Name
# Abbotts babbler       Abbott's babbler (Malacocincla abbotti) is a s...
# Abbotts booby         Abbott's booby (Papasula abbotti) is an endang...
# Abbotts starling      The Abbott's starling (Poeoptera femoralis) is...
# Abd alKuri sparrow    Abd al Kuri (Arabic: عبد الكوري‎) is a rocky i...
# Abdims stork          Abdim's stork (Ciconia abdimii), also known as...
# ...                                                                 ...
# Zimmers woodcreeper   Zimmer's woodcreeper (Dendroplex kienerii) is ...
# Zinos petrel          Zino's petrel (Pterodroma madeira) or freira i...
# Zitting cisticola     The zitting cisticola or streaked fantail warb...
# Zoes imperial pigeon  Zoe's imperial pigeon (Ducula zoeae), also kno...
# Zonetailed hawk       The zone-tailed hawk (Buteo albonotatus) is a ...
#
#                                 Family                          Genus Habitat  \
# Common Name
# Abbotts babbler           Pellorneidae                   Malacocincla  forest
# Abbotts booby                  Sulidae  PapasulaOlson & Warheit, 1988  forest
# Abbotts starling             Sturnidae                      Poeoptera  forest
# Abd alKuri sparrow          Passeridae                         Passer     NaN
# Abdims stork                Ciconiidae                        Ciconia     NaN
# ...                                ...                            ...     ...
# Zimmers woodcreeper   Dendrocolaptidae                     Dendroplex     NaN
# Zinos petrel            Procellariidae                     Pterodroma     NaN
# Zitting cisticola         Cisticolidae                      Cisticola  forest
# Zoes imperial pigeon        Columbidae                         Ducula  forest
# Zonetailed hawk           Accipitridae                          Buteo     NaN
#
#                                                                   Image  \
# Common Name
# Abbotts babbler       https://upload.wikimedia.org/wikipedia/commons...
# Abbotts booby         https://upload.wikimedia.org/wikipedia/commons...
# Abbotts starling      https://upload.wikimedia.org/wikipedia/commons...
# Abd alKuri sparrow    https://upload.wikimedia.org/wikipedia/commons...
# Abdims stork          https://upload.wikimedia.org/wikipedia/commons...
# ...                                                                 ...
# Zimmers woodcreeper   https://upload.wikimedia.org/wikipedia/commons...
# Zinos petrel          https://upload.wikimedia.org/wikipedia/commons...
# Zitting cisticola     https://upload.wikimedia.org/wikipedia/commons...
# Zoes imperial pigeon  https://upload.wikimedia.org/wikipedia/commons...
# Zonetailed hawk       https://upload.wikimedia.org/wikipedia/commons...
#
#                        Kingdom              Order    Phylum  \
# Common Name
# Abbotts babbler       Animalia      Passeriformes  Chordata
# Abbotts booby         Animalia         Suliformes  Chordata
# Abbotts starling      Animalia      Passeriformes  Chordata
# Abd alKuri sparrow    Animalia      Passeriformes  Chordata
# Abdims stork          Animalia      Ciconiiformes  Chordata
# ...                        ...                ...       ...
# Zimmers woodcreeper   Animalia      Passeriformes  Chordata
# Zinos petrel          Animalia  Procellariiformes  Chordata
# Zitting cisticola     Animalia      Passeriformes  Chordata
# Zoes imperial pigeon  Animalia      Columbiformes  Chordata
# Zonetailed hawk       Animalia    Accipitriformes  Chordata
#
#                                                              References  \
# Common Name
# Abbotts babbler       http://ibc.lynxeds.com/species/abbotts-babbler...
# Abbotts booby         http://www.environment.gov.au/biodiversity/thr...
# Abbotts starling      http://datazone.birdlife.org/species/factsheet...
# Abd alKuri sparrow    http://www.britannica.com/EBchecked/topic/1564...
# Abdims stork          http://myfwc.com/wildlifehabitats/nonnatives/b...
# ...                                                                 ...
# Zimmers woodcreeper   http://datazone.birdlife.org/species/factsheet...
# Zinos petrel          http://avesdamadeira.com/, http://www.madeirab...
# Zitting cisticola     http://www.hbw.com/node/58640, http://sora.unm...
# Zoes imperial pigeon  http://datazone.birdlife.org/species/factsheet...
# Zonetailed hawk       http://datazone.birdlife.org/species/factsheet...
#
#                              Species  \
# Common Name
# Abbotts babbler           M. abbotti
# Abbotts booby             P. abbotti
# Abbotts starling        P. femoralis
# Abd alKuri sparrow     P. hemileucus
# Abdims stork              C. abdimii
# ...                              ...
# Zimmers woodcreeper      D. kienerii
# Zinos petrel              P. madeira
# Zitting cisticola        C. juncidis
# Zoes imperial pigeon        D. zoeae
# Zonetailed hawk       B. albonotatus
#
#                                                                Wiki URL
# Common Name
# Abbotts babbler        https://en.wikipedia.org/wiki/Abbott%27s_babbler
# Abbotts booby            https://en.wikipedia.org/wiki/Abbott%27s_booby
# Abbotts starling      https://en.wikipedia.org/wiki/Abbott%27s_starling
# Abd alKuri sparrow            https://en.wikipedia.org/wiki/Abd_al_Kuri
# Abdims stork              https://en.wikipedia.org/wiki/Abdim%27s_stork
# ...                                                                 ...
# Zimmers woodcreeper   https://en.wikipedia.org/wiki/Zimmer%27s_woodc...
# Zinos petrel              https://en.wikipedia.org/wiki/Zino%27s_petrel
# Zitting cisticola       https://en.wikipedia.org/wiki/Zitting_cisticola
# Zoes imperial pigeon  https://en.wikipedia.org/wiki/Zoe%27s_imperial...
# Zonetailed hawk          https://en.wikipedia.org/wiki/Zone-tailed_hawk
#
# [10527 rows x 17 columns]

# %%
wiki.to_pickle('../assets/rescrape_wiki/wiki_data_v3.pkl')
wiki.to_csv('../assets/rescrape_wiki/wiki_data_v3.csv')

# %%
pd.merge(names,wiki,on=['Common Name']).to_csv('../assets/Wiki_Merged.csv')

# %%
def count_col(wiki):
    wiki_total = wiki.shape[0]
    wiki_d = {}
    for i in wiki.columns:
        wiki_d[i] = wiki_total- wiki[i].isnull().sum()
    wiki_d = sorted(wiki_d.items(), key=lambda x:x[1],reverse=True)
    wiki_df = pd.DataFrame(wiki_d,columns=['Attribute','Occur'])
    wiki_df['Perc'] = (wiki_df['Occur']/wiki_total)*100  
    return wiki_df
count_col(wiki).to_csv('../assets/wiki_col_count.csv')

# %%
data_df = pd.merge(names,wiki,on=['Common Name'])
data_df.to_csv('../assets/data_v1.csv')
count_col(data_df).to_csv('../assets/data_v1_count.csv')

# %%
data_df.head(4)
# Out:
#                     ID         Binomial Name  \
# Common Name
# Abbotts babbler      1  Malacocincla abbotti
# Abbotts booby        2      Papasula abbotti
# Abbotts starling     3   Poeoptera femoralis
# Abd alKuri sparrow   5     Passer hemileucus
#
#                                                            Categories Class  \
# Common Name
# Abbotts babbler     Articles with species microformats, Articles w...  Aves
# Abbotts booby       Articles with species microformats, Articles w...  Aves
# Abbotts starling    All stub articles, Articles with species micro...  Aves
# Abd alKuri sparrow  Articles containing Arabic-language text, Arti...  Aves
#
#                    Conservation status           Country  \
# Common Name
# Abbotts babbler         Least Concern                NaN
# Abbotts booby              Endangered   Christmas Island
# Abbotts starling           Vulnerable              Kenya
# Abd alKuri sparrow         Vulnerable            Somalia
#
#                                                           Description  \
# Common Name
# Abbotts babbler     Abbott's babbler (Malacocincla abbotti) is a s...
# Abbotts booby       Abbott's booby (Papasula abbotti) is an endang...
# Abbotts starling    The Abbott's starling (Poeoptera femoralis) is...
# Abd alKuri sparrow  Abd al Kuri (Arabic: عبد الكوري‎) is a rocky i...
#
#                           Family                          Genus Habitat  \
# Common Name
# Abbotts babbler     Pellorneidae                   Malacocincla  forest
# Abbotts booby            Sulidae  PapasulaOlson & Warheit, 1988  forest
# Abbotts starling       Sturnidae                      Poeoptera  forest
# Abd alKuri sparrow    Passeridae                         Passer     NaN
#
#                                                                 Image  \
# Common Name
# Abbotts babbler     https://upload.wikimedia.org/wikipedia/commons...
# Abbotts booby       https://upload.wikimedia.org/wikipedia/commons...
# Abbotts starling    https://upload.wikimedia.org/wikipedia/commons...
# Abd alKuri sparrow  https://upload.wikimedia.org/wikipedia/commons...
#
#                      Kingdom          Order    Phylum  \
# Common Name
# Abbotts babbler     Animalia  Passeriformes  Chordata
# Abbotts booby       Animalia     Suliformes  Chordata
# Abbotts starling    Animalia  Passeriformes  Chordata
# Abd alKuri sparrow  Animalia  Passeriformes  Chordata
#
#                                                            References  \
# Common Name
# Abbotts babbler     http://ibc.lynxeds.com/species/abbotts-babbler...
# Abbotts booby       http://www.environment.gov.au/biodiversity/thr...
# Abbotts starling    http://datazone.birdlife.org/species/factsheet...
# Abd alKuri sparrow  http://www.britannica.com/EBchecked/topic/1564...
#
#                           Species  \
# Common Name
# Abbotts babbler        M. abbotti
# Abbotts booby          P. abbotti
# Abbotts starling     P. femoralis
# Abd alKuri sparrow  P. hemileucus
#
#                                                              Wiki URL
# Common Name
# Abbotts babbler      https://en.wikipedia.org/wiki/Abbott%27s_babbler
# Abbotts booby          https://en.wikipedia.org/wiki/Abbott%27s_booby
# Abbotts starling    https://en.wikipedia.org/wiki/Abbott%27s_starling
# Abd alKuri sparrow          https://en.wikipedia.org/wiki/Abd_al_Kuri

# %%
ebird.set_index('Common Name',inplace=True)
ebird.head(4)
# Out:
#                      Kingdom    Phylum Class          Order        Family  \
# Common Name
# Abbott's Booby      Animalia  Chordata  Aves     Suliformes       Sulidae
# Abbott's Starling   Animalia  Chordata  Aves  Passeriformes     Sturnidae
# Abdim's Stork       Animalia  Chordata  Aves  Ciconiiformes    Ciconiidae
# Aberdare Cisticola  Animalia  Chordata  Aves  Passeriformes  Cisticolidae
#
#                           Binomial Name                               Link  \
# Common Name
# Abbott's Booby         Papasula abbotti  https://ebird.org/species/abbboo2
# Abbott's Starling   Poeoptera femoralis  https://ebird.org/species/abbsta2
# Abdim's Stork           Ciconia abdimii  https://ebird.org/species/abdsto1
# Aberdare Cisticola   Cisticola aberdare  https://ebird.org/species/abecis1
#
#                                                           Description
# Common Name
# Abbott's Booby      Gangly, stretched-out-looking black-and-white ...
# Abbott's Starling   A small, distinctive starling with a tiny rang...
# Abdim's Stork       A medium-sized, dark stork with a white belly....
# Aberdare Cisticola  A large and relatively colorful cisticola ende...

# %%
ebird.rename(columns={"Link":"Ebird_Link","Description":"Ebird_Description"},inplace=True)

# %%
data_df.drop(['ID'],axis=1,inplace=True)

# %%
ebird.reset_index(inplace=True)

# %%
for i in range(0,ebird.shape[0]) :
    ebird.loc[i].at['Common Name'] = ebird.loc[i].at['Common Name'].replace("ʻ","")
    ebird.loc[i].at['Common Name'] = ebird.loc[i].at['Common Name'].replace("`","")
    ebird.loc[i].at['Common Name'] = ebird.loc[i].at['Common Name'].replace("'","")
    ebird.loc[i].at['Common Name'] = ebird.loc[i].at['Common Name'].replace("-","")
    ebird.loc[i].at['Common Name'] = ebird.loc[i].at['Common Name'].lower()

# %%
ebird.head(3)
# Out:
#         Common Name   Kingdom    Phylum Class          Order      Family  \
# 0     abbotts booby  Animalia  Chordata  Aves     Suliformes     Sulidae
# 1  abbotts starling  Animalia  Chordata  Aves  Passeriformes   Sturnidae
# 2      abdims stork  Animalia  Chordata  Aves  Ciconiiformes  Ciconiidae
#
#          Binomial Name                         Ebird_Link  \
# 0     Papasula abbotti  https://ebird.org/species/abbboo2
# 1  Poeoptera femoralis  https://ebird.org/species/abbsta2
# 2      Ciconia abdimii  https://ebird.org/species/abdsto1
#
#                                    Ebird_Description
# 0  Gangly, stretched-out-looking black-and-white ...
# 1  A small, distinctive starling with a tiny rang...
# 2  A medium-sized, dark stork with a white belly....

# %%
ebird.set_index('Common Name',inplace=True)

# %%
data_df.reset_index(inplace=True)
for i in range(0,data_df.shape[0]) :
    data_df.loc[i].at['Common Name'] = data_df.loc[i].at['Common Name'].replace("ʻ","")
    data_df.loc[i].at['Common Name'] = data_df.loc[i].at['Common Name'].replace("`","")
    data_df.loc[i].at['Common Name'] = data_df.loc[i].at['Common Name'].replace("'","")
    data_df.loc[i].at['Common Name'] = data_df.loc[i].at['Common Name'].replace("-","")
    data_df.loc[i].at['Common Name'] = data_df.loc[i].at['Common Name'].lower()
data_df.set_index('Common Name',inplace=True)

# %%
data_df_2 = pd.merge(data_df,ebird,on=['Common Name','Binomial Name','Kingdom','Phylum','Class','Order','Family'],how='outer', left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)

# %%
data_df_2.to_csv('../assets/data_v2.csv')
count_col(data_df_2).to_csv('../assets/data_v2_count.csv')

# %%
eol.reset_index(inplace=True)
print(eol.head(4))
for i in range(0,eol.shape[0]) :
    eol.loc[i].at['Common Name'] = eol.loc[i].at['Common Name'].replace("ʻ","")
    eol.loc[i].at['Common Name'] = eol.loc[i].at['Common Name'].replace("`","")
    eol.loc[i].at['Common Name'] = eol.loc[i].at['Common Name'].replace("'","")
    eol.loc[i].at['Common Name'] = eol.loc[i].at['Common Name'].replace("-","")
    eol.loc[i].at['Common Name'] = eol.loc[i].at['Common Name'].lower()
eol.set_index('Common Name',inplace=True)
eol.head(5)
# Out:
#         Common Name   Kingdom    Phylum Class                        Eol_Link  \
# 0     Abbotts booby  Animalia  Chordata  Aves  https://eol.org/pages/45513856
# 1  Abbotts starling  Animalia  Chordata  Aves  https://eol.org/pages/45515541
# 2   Abbotts sunbird  Animalia  Chordata  Aves  https://eol.org/pages/45514925
# 3      Abdims stork  Animalia  Chordata  Aves  https://eol.org/pages/45515774
#
#                                      Eol_Description      auditory system  \
# 0  Papasula (Abbott's Booby) is a genus of birds ...  tympanic middle ear
# 1  Poeoptera femoralis (Abbott's Starling) is a s...  tympanic middle ear
# 2  Cinnyris abbotti (Abbott's Sunbird) is a speci...  tympanic middle ear
# 3  Ciconia abdimii (Abdim's Stork) is a species o...  tympanic middle ear
#
#   conservation status ecomorphological guild hearing range  ...  \
# 0          endangered               nectonic       5000 Hz  ...
# 1          vulnerable                    NaN       5000 Hz  ...
# 2                 NaN                    NaN       5000 Hz  ...
# 3                 NaN                    NaN           NaN  ...
#
#   vegetative plant height leaf arrangement developmental mode wing morphology  \
# 0                     NaN              NaN                NaN             NaN
# 1                     NaN              NaN                NaN             NaN
# 2                     NaN              NaN                NaN             NaN
# 3                     NaN              NaN                NaN             NaN
#
#   supporting structures and enclosures diet breadth  \
# 0                                  NaN          NaN
# 1                                  NaN          NaN
# 2                                  NaN          NaN
# 3                                  NaN          NaN
#
#   geographic range (size of area) habitat breadth social group size  \
# 0                             NaN             NaN               NaN
# 1                             NaN             NaN               NaN
# 2                             NaN             NaN               NaN
# 3                             NaN             NaN               NaN
#
#   territorial
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
#
# [4 rows x 113 columns]
#                      Kingdom    Phylum Class                        Eol_Link  \
# Common Name
# abbotts booby       Animalia  Chordata  Aves  https://eol.org/pages/45513856
# abbotts starling    Animalia  Chordata  Aves  https://eol.org/pages/45515541
# abbotts sunbird     Animalia  Chordata  Aves  https://eol.org/pages/45514925
# abdims stork        Animalia  Chordata  Aves  https://eol.org/pages/45515774
# aberdare cisticola  Animalia  Chordata  Aves  https://eol.org/pages/45514495
#
#                                                       Eol_Description  \
# Common Name
# abbotts booby       Papasula (Abbott's Booby) is a genus of birds ...
# abbotts starling    Poeoptera femoralis (Abbott's Starling) is a s...
# abbotts sunbird     Cinnyris abbotti (Abbott's Sunbird) is a speci...
# abdims stork        Ciconia abdimii (Abdim's Stork) is a species o...
# aberdare cisticola  Cisticola aberdare (Aberdare Cisticola) is a s...
#
#                         auditory system conservation status  \
# Common Name
# abbotts booby       tympanic middle ear          endangered
# abbotts starling    tympanic middle ear          vulnerable
# abbotts sunbird     tympanic middle ear                 NaN
# abdims stork        tympanic middle ear                 NaN
# aberdare cisticola  tympanic middle ear          vulnerable
#
#                    ecomorphological guild hearing range hearing threshold  \
# Common Name
# abbotts booby                    nectonic       5000 Hz             20 dB
# abbotts starling                      NaN       5000 Hz             10 dB
# abbotts sunbird                       NaN       5000 Hz             10 dB
# abdims stork                          NaN           NaN               NaN
# aberdare cisticola                    NaN           NaN             10 dB
#
#                     ... vegetative plant height leaf arrangement  \
# Common Name         ...
# abbotts booby       ...                     NaN              NaN
# abbotts starling    ...                     NaN              NaN
# abbotts sunbird     ...                     NaN              NaN
# abdims stork        ...                     NaN              NaN
# aberdare cisticola  ...                     NaN              NaN
#
#                    developmental mode wing morphology  \
# Common Name
# abbotts booby                     NaN             NaN
# abbotts starling                  NaN             NaN
# abbotts sunbird                   NaN             NaN
# abdims stork                      NaN             NaN
# aberdare cisticola                NaN             NaN
#
#                    supporting structures and enclosures diet breadth  \
# Common Name
# abbotts booby                                       NaN          NaN
# abbotts starling                                    NaN          NaN
# abbotts sunbird                                     NaN          NaN
# abdims stork                                        NaN          NaN
# aberdare cisticola                                  NaN          NaN
#
#                    geographic range (size of area) habitat breadth  \
# Common Name
# abbotts booby                                  NaN             NaN
# abbotts starling                               NaN             NaN
# abbotts sunbird                                NaN             NaN
# abdims stork                                   NaN             NaN
# aberdare cisticola                             NaN             NaN
#
#                    social group size territorial
# Common Name
# abbotts booby                    NaN         NaN
# abbotts starling                 NaN         NaN
# abbotts sunbird                  NaN         NaN
# abdims stork                     NaN         NaN
# aberdare cisticola               NaN         NaN
#
# [5 rows x 112 columns]

# %%
eol.drop(['index'],axis=1,inplace=True)

# %%
eol.head(5)
# Out:
#                      Kingdom    Phylum Class                            Link  \
# Common Name
# Abbotts booby       Animalia  Chordata  Aves  https://eol.org/pages/45513856
# Abbotts starling    Animalia  Chordata  Aves  https://eol.org/pages/45515541
# Abbotts sunbird     Animalia  Chordata  Aves  https://eol.org/pages/45514925
# Abdims stork        Animalia  Chordata  Aves  https://eol.org/pages/45515774
# Aberdare cisticola  Animalia  Chordata  Aves  https://eol.org/pages/45514495
#
#                                                           Description  \
# Common Name
# Abbotts booby       Papasula (Abbott's Booby) is a genus of birds ...
# Abbotts starling    Poeoptera femoralis (Abbott's Starling) is a s...
# Abbotts sunbird     Cinnyris abbotti (Abbott's Sunbird) is a speci...
# Abdims stork        Ciconia abdimii (Abdim's Stork) is a species o...
# Aberdare cisticola  Cisticola aberdare (Aberdare Cisticola) is a s...
#
#                         auditory system conservation status  \
# Common Name
# Abbotts booby       tympanic middle ear          endangered
# Abbotts starling    tympanic middle ear          vulnerable
# Abbotts sunbird     tympanic middle ear                 NaN
# Abdims stork        tympanic middle ear                 NaN
# Aberdare cisticola  tympanic middle ear          vulnerable
#
#                    ecomorphological guild hearing range hearing threshold  \
# Common Name
# Abbotts booby                    nectonic       5000 Hz             20 dB
# Abbotts starling                      NaN       5000 Hz             10 dB
# Abbotts sunbird                       NaN       5000 Hz             10 dB
# Abdims stork                          NaN           NaN               NaN
# Aberdare cisticola                    NaN           NaN             10 dB
#
#                     ... vegetative plant height leaf arrangement  \
# Common Name         ...
# Abbotts booby       ...                     NaN              NaN
# Abbotts starling    ...                     NaN              NaN
# Abbotts sunbird     ...                     NaN              NaN
# Abdims stork        ...                     NaN              NaN
# Aberdare cisticola  ...                     NaN              NaN
#
#                    developmental mode wing morphology  \
# Common Name
# Abbotts booby                     NaN             NaN
# Abbotts starling                  NaN             NaN
# Abbotts sunbird                   NaN             NaN
# Abdims stork                      NaN             NaN
# Aberdare cisticola                NaN             NaN
#
#                    supporting structures and enclosures diet breadth  \
# Common Name
# Abbotts booby                                       NaN          NaN
# Abbotts starling                                    NaN          NaN
# Abbotts sunbird                                     NaN          NaN
# Abdims stork                                        NaN          NaN
# Aberdare cisticola                                  NaN          NaN
#
#                    geographic range (size of area) habitat breadth  \
# Common Name
# Abbotts booby                                  NaN             NaN
# Abbotts starling                               NaN             NaN
# Abbotts sunbird                                NaN             NaN
# Abdims stork                                   NaN             NaN
# Aberdare cisticola                             NaN             NaN
#
#                    social group size territorial
# Common Name
# Abbotts booby                    NaN         NaN
# Abbotts starling                 NaN         NaN
# Abbotts sunbird                  NaN         NaN
# Abdims stork                     NaN         NaN
# Aberdare cisticola               NaN         NaN
#
# [5 rows x 112 columns]

# %%
eol.rename(columns={"Link":"Eol_Link","Description":"Eol_Description"},inplace=True)
eol.loc['abdims stork']
# Out:
# Kingdom                                                                     Animalia
# Phylum                                                                      Chordata
# Class                                                                           Aves
# Eol_Link                                              https://eol.org/pages/45515774
# Eol_Description                    Ciconia abdimii (Abdim's Stork) is a species o...
#                                                          ...
# diet breadth                                                                     NaN
# geographic range (size of area)                                                  NaN
# habitat breadth                                                                  NaN
# social group size                                                                NaN
# territorial                                                                      NaN
# Name: abdims stork, Length: 112, dtype: object

# %%
data_df_3 = pd.merge(data_df_2,eol,on=['Common Name'],how='outer', left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
data_df_3.shape
# Out:
# (12218, 130)

# %%
data_df_3.to_csv('../assets/data_v3.csv')
count_col(data_df_3).to_csv('../assets/data_v3_count.csv')

# %%
print(data_df_3.columns)
# Out:
# Index(['Binomial Name', 'Categories', 'Class_x', 'Conservation status',
#        'Country', 'Description', 'Family', 'Genus', 'Habitat', 'Image',
#        ...
#        'vegetative plant height', 'leaf arrangement', 'developmental mode',
#        'wing morphology', 'supporting structures and enclosures',
#        'diet breadth', 'geographic range (size of area)', 'habitat breadth',
#        'social group size', 'territorial'],
#       dtype='object', length=130)

# %%
data_df_3.drop(['Class_x','Class_y'],axis=1,inplace=True)
data_df_3['Class'] = 'Aves'

# %%
data_df_3.drop(['Kingdom_x','Kingdom_y'],axis=1,inplace=True)
data_df_3['Kingdom'] = 'Animalia'

# %%
data_df_3.drop(['Phylum_x','Phylum_y'],axis=1,inplace=True)
data_df_3['Phylum'] = 'Chordata'

# %%
data_df_3.to_csv('../assets/data_v4.csv')
count_col(data_df_3).to_csv('../assets/data_v4_count.csv')
