# %% [markdown]
# # One Single Data Set
# ### TASKS
#
# > merge birds.csv and birds.xlxs --> BIRD
#
# > merge all eol csv s  --> ESV
#
# > get all attributes from ESV
#
# > merge BIRD and ESV --> MAIN
#
# > sort MAIN according to attribute weights

# %%
# using pandas to manage all attributes
import pandas as pd
import numpy as np

# %% [markdown]
# #### Opening All Data sets

# %%
birds_csv = pd.read_csv('../assets/birds.csv',index_col='ID')
birds_csv.head(2)
# Out:
#    Common Bird Names
# ID
# 1   Abbott's babbler
# 2     Abbott's booby

# %%
birds_dataset_excel = pd.read_excel('../assets/DCPP_Group_Assignment/Birds_Dataset.xlsx',index_col='Serial No')
birds_dataset_excel.head(2)
# Out:
#                           Common Name Conservation status   Kingdom    Phylum  \
# Serial No
# 1              Abyssinian crimsonwing      Least Concern   Animalia  Chordata
# 2          Abyssinian ground hornbill         Vulnerable   Animalia  Chordata
#
#           Class           Order       Family        Genus         Species  \
# Serial No
# 1          Aves   Passeriformes  Estrildidae  Cryptospiza   C. salvadorii
# 2          Aves  Bucerotiformes   Bucorvidae     Bucorvus  B. abyssinicus
#
#                                       Binomial Name  \
# Serial No
# 1          Cryptospiza salvadoriiReichenow, 1892[2]
# 2              Bucorvus abyssinicus(Boddaert, 1783)
#
#                                                  Description  \
# Serial No
# 1          The Abyssinian crimsonwing (Cryptospiza salvad...
# 2          The Abyssinian ground hornbill or northern gro...
#
#                                                   Categories  \
# Serial No
# 1          Articles with species microformats, Articles w...
# 2          Articles with species microformats, Articles w...
#
#                                                   References  \
# Serial No
# 1          http://www.hbw.com/species/ethiopian-crimsonwi...
# 2          http://www.hbw.com/species/northern-ground-hor...
#
#                                                     Wiki URL  \
# Serial No
# 1          https://en.wikipedia.org/wiki/Abyssinian_crims...
# 2          https://en.wikipedia.org/wiki/Abyssinian_groun...
#
#                                                        Image   Country Habitat
# Serial No
# 1          https://upload.wikimedia.org/wikipedia/commons...  Ethiopia  forest
# 2          https://upload.wikimedia.org/wikipedia/commons...       NaN     NaN

# %%
for i in range(1,birds_dataset_excel.shape[0]) :
    birds_dataset_excel.loc[i].at['Common Name'] = birds_dataset_excel.loc[i].at['Common Name'].replace("'","")
    birds_dataset_excel.loc[i].at['Common Name'] = birds_dataset_excel.loc[i].at['Common Name'].replace("ʻ","")
    birds_dataset_excel.loc[i].at['Common Name'] = birds_dataset_excel.loc[i].at['Common Name'].replace("`","")
    birds_dataset_excel.loc[i].at['Common Name'] = birds_dataset_excel.loc[i].at['Common Name'].replace("-","")
birds_dataset_excel.tail(3)
# Out:
#                             Common Name Conservation status   Kingdom  \
# Serial No
# 6865       Sapphirethroated hummingbird      Least Concern   Animalia
# 6866             Sapphirevented puffleg      Least Concern   Animalia
# 6867                  Sardinian warbler      Least Concern   Animalia
#
#              Phylum Class          Order       Family        Genus  \
# Serial No
# 6865       Chordata  Aves    Apodiformes  Trochilidae  Chrysuronia
# 6866       Chordata  Aves    Apodiformes  Trochilidae   Eriocnemis
# 6867       Chordata  Aves  Passeriformes    Sylviidae      Curruca
#
#                       Species                             Binomial Name  \
# Serial No
# 6865       C. coeruleogularis  Chrysuronia coeruleogularis(Gould, 1851)
# 6866               E. luciani          Eriocnemis lucianiBourcier, 1847
# 6867         C. melanocephala    Curruca melanocephala(Gmelin, 1789[2])
#
#                                                  Description  \
# Serial No
# 6865       The sapphire-throated hummingbird (Chrysuronia...
# 6866       The sapphire-vented puffleg (Eriocnemis lucian...
# 6867       The Sardinian warbler (Curruca melanocephala) ...
#
#                                                   Categories  \
# Serial No
# 6865       Articles with species microformats, Articles w...
# 6866       All stub articles, Articles with species micro...
# 6867       Articles with species microformats, Articles w...
#
#                                                   References  \
# Serial No
# 6865       http://beautyofbirds.com/sapphirethroatedhummi...
# 6866       http://datazone.birdlife.org/species/factsheet...
# 6867       http://www.ornithos.de/Ornithos/Feather_Collec...
#
#                                                     Wiki URL  \
# Serial No
# 6865       https://en.wikipedia.org/wiki/Sapphire-throate...
# 6866       https://en.wikipedia.org/wiki/Sapphire-vented_...
# 6867         https://en.wikipedia.org/wiki/Sardinian_warbler
#
#                                                        Image     Country  \
# Serial No
# 6865       https://upload.wikimedia.org/wikipedia/commons...  Costa Rica
# 6866       https://upload.wikimedia.org/wikipedia/commons...    Colombia
# 6867       https://upload.wikimedia.org/wikipedia/commons...         NaN
#
#           Habitat
# Serial No
# 6865       forest
# 6866       forest
# 6867          NaN

# %%
for i in range(1,birds_csv.shape[0]) :
    birds_csv.loc[i].at['Common Bird Names'] = birds_csv.loc[i].at['Common Bird Names'].replace("'","")
    birds_csv.loc[i].at['Common Bird Names'] = birds_csv.loc[i].at['Common Bird Names'].replace("ʻ","")
    birds_csv.loc[i].at['Common Bird Names'] = birds_csv.loc[i].at['Common Bird Names'].replace("`","")
    birds_csv.loc[i].at['Common Bird Names'] = birds_csv.loc[i].at['Common Bird Names'].replace("-","")
    

birds_csv.to_csv('../assets/names.csv',columns=['Common Bird Names'])

# %%
birds_csv.to_csv('../assets/names_in_excel.csv',columns=['Common Bird Names'])

# %%
birds_csv = pd.read_csv('../assets/names.csv',index_col='ID')
birds_csv.head(2)
# Out:
#    Common Bird Names
# ID
# 1    Abbotts babbler
# 2      Abbotts booby

# %%
birds_csv.rename(columns={'Common Bird Names':'Common Name'},inplace=True)

# %%
# birds_csv.merge(birds_dataset_excel, how='outer', on=['Common Name'], left_on=None, right_on=None, left_index=False, right_index=False, sort=True, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
new_birds_csv = pd.merge(birds_csv,birds_dataset_excel,how='outer',on=['Common Name'],sort=True)
new_birds_csv.tail(4)
# print(birds_csv.head(2))
# print(birds_dataset_excel.head(2))
# birds_csv.head(2)
# Out:
#       Common Name                       Conservation status   Kingdom  \
# 11185   Ākohekohe                    Critically Endangered   Animalia
# 11186        Ōmao                               Vulnerable   Animalia
# 11187          Ōū  Critically endangered, possibly extinct   Animalia
# 11188        ʻŌʻū                                       NaN       NaN
#
#          Phylum Class          Order        Family  \
# 11185  Chordata  Aves  Passeriformes  Fringillidae
# 11186  Chordata  Aves  Passeriformes      Turdidae
# 11187  Chordata  Aves  Passeriformes  Fringillidae
# 11188       NaN   NaN            NaN           NaN
#
#                             Genus       Species  \
# 11185    PalmeriaRothschild, 1893      P. dolei
# 11186                   Myadestes   M. obscurus
# 11187  PsittirostraTemminck, 1820  P. psittacea
# 11188                         NaN           NaN
#
#                                 Binomial Name  \
# 11185            Palmeria dolei(Wilson, 1891)
# 11186  Myadestes obscurus(J. F. Gmelin, 1789)
# 11187    Psittirostra psittacea(Gmelin, 1789)
# 11188                                     NaN
#
#                                              Description  \
# 11185  The ʻākohekohe (Palmeria dolei), or crested ho...
# 11186  The ʻōmaʻo (Myadestes obscurus, also called th...
# 11187  The  ʻōʻū (pronounced [ˈʔoːʔuː]) (Psittirostra...
# 11188                                                NaN
#
#                                               Categories  \
# 11185  Articles with species microformats, Articles w...
# 11186  All articles needing additional references, Ar...
# 11187  Articles with species microformats, Articles w...
# 11188                                                NaN
#
#                                               References  \
# 11185  http://ibc.lynxeds.com/species/akohekohe-palme...
# 11186  http://scholar.google.com/scholar?q=%22%CA%BB%...
# 11187  http://www.uatuahine.hawaii.edu/hana/NaManu/ou...
# 11188                                                NaN
#
#                                                 Wiki URL  \
# 11185      https://en.wikipedia.org/wiki/%CA%BBAkohekohe
# 11186  https://en.wikipedia.org/wiki/%CA%BB%C5%8Cma%C...
# 11187  https://en.wikipedia.org/wiki/%CA%BB%C5%8C%CA%...
# 11188                                                NaN
#
#                                                    Image Country Habitat
# 11185  https://upload.wikimedia.org/wikipedia/commons...     NaN  forest
# 11186  https://upload.wikimedia.org/wikipedia/commons...     NaN  forest
# 11187  https://upload.wikimedia.org/wikipedia/commons...     NaN     NaN
# 11188                                                NaN     NaN     NaN

# %%
new_birds_csv.to_csv('../assets/temp.csv')

# %%
new_birds_csv.shape
# Out:
# (11189, 17)

# %%
birds_csv.to_csv('../assets/final_names.csv',columns=['Common Name'])

# %%
type(new_birds_csv.loc[2].at['Binomial Name'])
# Out:
# str

# %%
# if new_birds_csv.loc['Kingdom'].isna():
# new_birds_csv[new_birds_csv.columns[new_birds_csv.isna().any()]]
check_for_nan = new_birds_csv['Binomial Name'].isnull()
df_wiki = new_birds_csv[ check_for_nan]

# %%
new_birds_csv.head(10)
# Out:
#              Common Name Conservation status   Kingdom    Phylum Class  \
# 0        Abbotts babbler      Least Concern   Animalia  Chordata  Aves
# 1          Abbotts booby         Endangered   Animalia  Chordata  Aves
# 2       Abbotts starling         Vulnerable   Animalia  Chordata  Aves
# 3        Abbotts sunbird                 NaN       NaN       NaN   NaN
# 4     Abd alKuri sparrow         Vulnerable   Animalia  Chordata  Aves
# 5           Abdims stork      Least Concern   Animalia  Chordata  Aves
# 6     Aberdare cisticola                 NaN       NaN       NaN   NaN
# 7  Aberrant bush warbler      Least Concern   Animalia  Chordata  Aves
# 8          Aberts towhee      Least Concern   Animalia  Chordata  Aves
# 9     Abyssinian catbird                 NaN       NaN       NaN   NaN
#
#            Order         Family                          Genus  \
# 0  Passeriformes   Pellorneidae                   Malacocincla
# 1     Suliformes        Sulidae  PapasulaOlson & Warheit, 1988
# 2  Passeriformes      Sturnidae                      Poeoptera
# 3            NaN            NaN                            NaN
# 4  Passeriformes     Passeridae                         Passer
# 5  Ciconiiformes     Ciconiidae                        Ciconia
# 6            NaN            NaN                            NaN
# 7  Passeriformes      Cettiidae                       Horornis
# 8  Passeriformes  Passerellidae                       Melozone
# 9            NaN            NaN                            NaN
#
#             Species                                  Binomial Name  \
# 0        M. abbotti                Malacocincla abbottiBlyth, 1845
# 1        P. abbotti                               Papasula abbotti
# 2      P. femoralis                            Poeoptera femoralis
# 3               NaN                                            NaN
# 4     P. hemileucus  Passer hemileucusOgilvie-Grant & Forbes, 1900
# 5        C. abdimii              Ciconia abdimiiLichtenstein, 1823
# 6               NaN                                            NaN
# 7  H. flavolivaceus                         Horornis flavolivaceus
# 8         M. aberti                                Melozone aberti
# 9               NaN                                            NaN
#
#                                          Description  \
# 0  Abbott's babbler (Malacocincla abbotti) is a s...
# 1  Abbott's booby (Papasula abbotti) is an endang...
# 2  The Abbott's starling (Poeoptera femoralis) is...
# 3                                                NaN
# 4  Abd al Kuri (Arabic: عبد الكوري‎) is a rocky i...
# 5  Abdim's stork (Ciconia abdimii), also known as...
# 6                                                NaN
# 7  The aberrant bush warbler (Horornis flavolivac...
# 8  Abert's towhee (Melozone aberti) is a bird of ...
# 9                                                NaN
#
#                                           Categories  \
# 0  Articles with species microformats, Articles w...
# 1  Articles with species microformats, Articles w...
# 2  All stub articles, Articles with species micro...
# 3                                                NaN
# 4  Articles containing Arabic-language text, Arti...
# 5  Articles containing video clips, Articles with...
# 6                                                NaN
# 7  All stub articles, Articles with species micro...
# 8  Articles with species microformats, Articles w...
# 9                                                NaN
#
#                                           References  \
# 0  http://ibc.lynxeds.com/species/abbotts-babbler...
# 1  http://www.environment.gov.au/biodiversity/thr...
# 2  http://datazone.birdlife.org/species/factsheet...
# 3                                                NaN
# 4  http://www.britannica.com/EBchecked/topic/1564...
# 5  http://myfwc.com/wildlifehabitats/nonnatives/b...
# 6                                                NaN
# 7  http://www.oiseaux.net/birds/aberrant.bush.war...
# 8  http://vireo.acnatsci.org/search.html?Form=Sea...
# 9                                                NaN
#
#                                             Wiki URL  \
# 0   https://en.wikipedia.org/wiki/Abbott%27s_babbler
# 1     https://en.wikipedia.org/wiki/Abbott%27s_booby
# 2  https://en.wikipedia.org/wiki/Abbott%27s_starling
# 3                                                NaN
# 4          https://en.wikipedia.org/wiki/Abd_al_Kuri
# 5      https://en.wikipedia.org/wiki/Abdim%27s_stork
# 6                                                NaN
# 7  https://en.wikipedia.org/wiki/Aberrant_bush_wa...
# 8     https://en.wikipedia.org/wiki/Abert%27s_towhee
# 9                                                NaN
#
#                                                Image           Country Habitat
# 0  https://upload.wikimedia.org/wikipedia/commons...               NaN  forest
# 1  https://upload.wikimedia.org/wikipedia/commons...  Christmas Island  forest
# 2  https://upload.wikimedia.org/wikipedia/commons...             Kenya  forest
# 3                                                NaN               NaN     NaN
# 4  https://upload.wikimedia.org/wikipedia/commons...           Somalia     NaN
# 5  https://upload.wikimedia.org/wikipedia/commons...             Sudan     NaN
# 6                                                NaN               NaN     NaN
# 7  https://upload.wikimedia.org/wikipedia/commons...       Philippines     NaN
# 8  https://upload.wikimedia.org/wikipedia/commons...            Mexico     NaN
# 9                                                NaN               NaN     NaN

# %%
# df_wiki.set_index('Common Name',inplace=True)
df_wiki.to_csv('../assets/wiki_list_to.csv',columns=[])
df_wiki.head(2)
# Out:
#                    Conservation status Kingdom Phylum Class Order Family  \
# Common Name
# Abbotts sunbird                    NaN     NaN    NaN   NaN   NaN    NaN
# Aberdare cisticola                 NaN     NaN    NaN   NaN   NaN    NaN
#
#                    Genus Species Binomial Name Description Categories  \
# Common Name
# Abbotts sunbird      NaN     NaN           NaN         NaN        NaN
# Aberdare cisticola   NaN     NaN           NaN         NaN        NaN
#
#                    References Wiki URL Image Country Habitat
# Common Name
# Abbotts sunbird           NaN      NaN   NaN     NaN     NaN
# Aberdare cisticola        NaN      NaN   NaN     NaN     NaN

# %%
# len(Wiki_list_to)
# Out:
# 6741

# %% [markdown]
# ## Merging all CSVs of eol

# %%
# e2 = pd.read_csv('../assets/eol_9000_10000_8.csv',header=None,names=['Common Name','eol_dict'])
# e2.head(5)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# c:\Users\LEGION\Documents\birds\Week1_Strucured_Data_Gen\merge_eol.ipynb Cell 16' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/LEGION/Documents/birds/Week1_Strucured_Data_Gen/merge_eol.ipynb#ch0000022?line=0'>1</a> e2 = pd.read_csv('../assets/eol_9000_10000_8.csv',header=None,names=['Common Name','eol_dict'])
#       <a href='vscode-notebook-cell:/c%3A/Users/LEGION/Documents/birds/Week1_Strucured_Data_Gen/merge_eol.ipynb#ch0000022?line=1'>2</a> e2.head(5)
#
# File ~\anaconda3\envs\indicwiki\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File ~\anaconda3\envs\indicwiki\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=664'>665</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=665'>666</a>     dialect,
#     <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=666'>667</a>     delimiter,
#    (...)
#     <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=675'>676</a>     defaults={"delimiter": ","},
#     <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=676'>677</a> )
#     <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=677'>678</a> kwds.update(kwds_defaults)
# --> <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=679'>680</a> return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\envs\indicwiki\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=571'>572</a> _validate_names(kwds.get("names", None))
#     <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=573'>574</a> # Create the parser.
# --> <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=574'>575</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=576'>577</a> if chunksize or iterator:
#     <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=577'>578</a>     return parser
#
# File ~\anaconda3\envs\indicwiki\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=929'>930</a>     self.options["has_index_names"] = kwds["has_index_names"]
#     <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=931'>932</a> self.handles: IOHandles | None = None
# --> <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=932'>933</a> self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\envs\indicwiki\lib\site-packages\pandas\io\parsers\readers.py:1231, in TextFileReader._make_engine(self, f, engine)
#    <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=1227'>1228</a>     f = self.handles.handle
#    <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=1229'>1230</a> try:
# -> <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=1230'>1231</a>     return mapping[engine](f, **self.options)
#    <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=1231'>1232</a> except Exception:
#    <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/readers.py?line=1232'>1233</a>     if self.handles is not None:
#
# File ~\anaconda3\envs\indicwiki\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:75, in CParserWrapper.__init__(self, src, **kwds)
#      <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=71'>72</a>     kwds.pop(key, None)
#      <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=73'>74</a> kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=74'>75</a> self._reader = parsers.TextReader(src, **kwds)
#      <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=76'>77</a> self.unnamed_cols = self._reader.unnamed_cols
#      <a href='file:///c%3A/Users/LEGION/anaconda3/envs/indicwiki/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=78'>79</a> # error: Cannot determine type of 'names'
#
# File ~\anaconda3\envs\indicwiki\lib\site-packages\pandas\_libs\parsers.pyx:544, in pandas._libs.parsers.TextReader.__cinit__()
#
# File ~\anaconda3\envs\indicwiki\lib\site-packages\pandas\_libs\parsers.pyx:734, in pandas._libs.parsers.TextReader._get_header()
#
# File ~\anaconda3\envs\indicwiki\lib\site-packages\pandas\_libs\parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~\anaconda3\envs\indicwiki\lib\site-packages\pandas\_libs\parsers.pyx:1952, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf3 in position 27298: invalid continuation byte

# %%
# import csv
# import json
# import ast
# files = ['','../assets/eol_9000_10000.csv']
# Data = {}
# with open('../assets/eol_9000_10000.csv', 'r') as f:
#     csv_reader = csv.reader(f)
#     for line in csv_reader:
#         try:
#             Data[line[0]] = ast.literal_eval(line[1])
#             # print(line)
#         except Exception:
#             print(line[0])
        
# Data
# Out:
# Stripe-crowned sparrow
# Sulphur-bearded reedhaunter
# Sumatran blue robin
# Sunda owlet
# Swierstra's spurfowl
# Swinhoe's prinia
# Tabar pitta
# Tagula shrikethrush
# Taliabu grasshopper warbler
# Taliabu leaf warbler
# Taliabu myzomela
# Tapajos fire-eye
# Turkestan short-toed lark
# Variable shrikethrush
# Visayan fantail
# Vogelkop superb bird-of-paradise
# Waigeo shrikethrush
# Wakatobi white-eye
# Wayanad laughingthrush
# West African batis
# Western fire-eye
# Western subalpine warbler
# Western yellow-spotted barbet
# Whenua Hou diving petrel
# {'Streaked weaver': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the indo-malayan realm',
#   'body mass': '18.4 g',
#   'ecoregion': 'Tonle Sap-Mekong Peat Swamp Forests',
#   'geographic distribution includes': 'Indian Ocean',
#   'habitat': 'freshwater,freshwater habitat',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Streaked wren-babbler': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the palearctic',
#   'body mass': '22 g',
#   'ecoregion': 'Chin Hills-Arakan Yoma Montane Forests',
#   'geographic distribution includes': 'Cambodia',
#   'habitat': 'tropical',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'type specimen repository': 'NHMUK',
#   'visual system': 'corneal eyes'},
#  'Streaked xenops': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '12.2 g',
#   'ecoregion': 'Santa Marta Montane Forests',
#   'geographic distribution includes': 'South Pacific',
#   'habitat': 'tropical',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'type specimen repository': 'Harvard UNiversity, Museum of Comparative Zoology',
#   'visual system': 'corneal eyes'},
#  'Streaky seedeater': {'auditory system': 'tympanic middle ear',
#   'geographic distribution includes': 'Kenya',
#   'habitat': 'scrubland,freshwater habitat',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Streaky-breasted flufftail': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'Afrotropics',
#   'body mass': '42 g',
#   'ecoregion': 'South Malawi Montane Forest-Grassland Mosaic',
#   'geographic distribution includes': 'Zimbabwe',
#   'habitat': 'freshwater habitat',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '20 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Streaky-breasted spiderhunter': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the indo-malayan realm',
#   'body mass': '29.2 g',
#   'ecoregion': 'Southwest Borneo Freshwater Swamp Forests',
#   'geographic distribution includes': 'Malaysia',
#   'habitat': 'tropical',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'visual system': 'corneal eyes'},
#  'Streaky-headed seedeater': {'geographic distribution includes': 'Angola'},
#  'Streamer-tailed tyrant': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '71.40000000000001 g',
#   'geographic distribution includes': 'Bolivia',
#   'habitat': 'tropical,terrestrial',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'preys on': 'University Museum of Zoology, Cambridge',
#   'type specimen repository': 'corneal eyes'},
#  "Stresemann's bristlefront": {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'conservation status': 'critically endangered',
#   'ecoregion': 'Bahia Coastal Forests',
#   'geographic distribution includes': 'Brazil',
#   'habitat': 'forest,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  "Stresemann's bushcrow": {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'Afrotropics',
#   'conservation status': 'endangered',
#   'ecoregion': 'Somali Acacia-Commiphora Bushlands And Thickets',
#   'geographic distribution includes': 'Ethiopia',
#   'habitat': 'savanna,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Striated antbird': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '10.3 g',
#   'ecoregion': 'Southwest Amazon Moist Forests',
#   'geographic distribution includes': 'Bolivia',
#   'habitat': 'headwater,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Striated antthrush': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '123 g',
#   'geographic distribution includes': 'Bolivia',
#   'habitat': 'tropical,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'type specimen repository': 'NHMUK',
#   'visual system': 'corneal eyes'},
#  'Striated babbler': {'auditory system': 'tympanic middle ear',
#   'habitat': 'terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Striated bulbul': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the indo-malayan realm',
#   'body mass': '60 g',
#   'ecoregion': 'Himalayan Subtropical Broadleaf Forests',
#   'geographic distribution includes': 'Bhutan',
#   'habitat': 'subtropical',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'visual system': 'corneal eyes'},
#  'Striated caracara': {'auditory system': 'tympanic middle ear',
#   'body mass': '1187 g',
#   'conservation status': 'near threatened',
#   'geographic distribution includes': 'Falkland Islands',
#   'habitat': 'cliff,terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Striated earthcreeper': {'auditory system': 'otoliths',
#   'geographic distribution includes': 'Peru',
#   'habitat': 'terrestrial',
#   'hearing range': '1000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Striated fieldwren': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'body mass': '26 g',
#   'ecoregion': 'Tasmanian Temperate Rain Forests',
#   'geographic distribution includes': 'Australia',
#   'habitat': 'terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'type specimen repository': 'University Museum of Zoology, Cambridge',
#   'visual system': 'corneal eyes'},
#  'Striated grassbird': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the indo-malayan realm',
#   'body mass': '41.8 g',
#   'ecoregion': 'Mizoram-Manipur-Kachin Rain Forests',
#   'geographic distribution includes': 'Indian Ocean',
#   'habitat': 'freshwater habitat',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Unknown',
#   'type specimen repository': 'Harvard UNiversity, Museum of Comparative Zoology',
#   'visual system': 'corneal eyes'},
#  'Striated grasswren': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'body mass': '22 g',
#   'ecoregion': 'Central Ranges Xeric Scrub',
#   'geographic distribution includes': 'Australia',
#   'habitat': 'arid,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Striated heron': {},
#  'Striated laughingthrush': {'auditory system': 'tympanic middle ear',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'visual system': 'corneal eyes'},
#  'Striated lorikeet': {'auditory system': 'otoliths',
#   'biogeographic realm': 'australasia',
#   'conservation status': 'near threatened',
#   'ecoregion': 'Southern New Guinea Lowland Rain Forests',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'mountain,terrestrial',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Striated pardalote': {'auditory system': 'tympanic middle ear',
#   'behavioral circadian rhythm': 'diurnal',
#   'biogeographic realm': 'australasia',
#   'ecoregion': 'Southwest Australia Woodlands',
#   'geographic distribution includes': 'Indian Ocean',
#   'habitat': 'mountain,freshwater habitat',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Striated softtail': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'conservation status': 'vulnerable',
#   'ecoregion': 'Bahia Coastal Forests',
#   'geographic distribution includes': 'Brazil',
#   'habitat': 'subtropical,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Striated starling': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'body mass': '60 g',
#   'ecoregion': 'New Caledonia Rain Forests',
#   'geographic distribution includes': 'New Caledonia',
#   'habitat': 'terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Unknown',
#   'visual system': 'corneal eyes'},
#  'Striated swallow': {'auditory system': 'tympanic middle ear',
#   'geographic distribution includes': 'Cambodia',
#   'habitat': 'cliff',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'type specimen repository': 'NHMUK',
#   'visual system': 'corneal eyes'},
#  'Striated thornbill': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'ecoregion': 'Eyre And York Mallee',
#   'geographic distribution includes': 'Australia',
#   'habitat': 'subtropical,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'type specimen repository': 'NHMUK',
#   'visual system': 'corneal eyes'},
#  'Striated wren-babbler': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the indo-malayan realm',
#   'body mass': '31 g',
#   'ecoregion': 'Mindanao-Eastern Visayas Rain Forests',
#   'geographic distribution includes': 'The Philippines',
#   'habitat': 'montane forest,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Striated yuhina': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the indo-malayan realm',
#   'body mass': '12 g',
#   'ecoregion': 'Qionglai-Minshan Conifer Forests',
#   'geographic distribution includes': 'Bhutan',
#   'habitat': 'tropical,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  "Strickland's woodpecker": {'auditory system': 'otoliths',
#   'habitat': 'terrestrial',
#   'hearing range': '1000 Hz',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Striolated bunting': {'auditory system': 'tympanic middle ear',
#   'behavioral circadian rhythm': 'diurnal',
#   'biogeographic realm': 'Afrotropics',
#   'body mass': '18 g',
#   'ecoregion': 'Northwestern Thorn Scrub Forests',
#   'geographic distribution includes': 'Yemen',
#   'habitat': 'river',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'visual system': 'corneal eyes'},
#  'Striolated manakin': {'auditory system': 'tympanic middle ear',
#   'geographic distribution includes': 'Peru',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'visual system': 'corneal eyes'},
#  'Striolated tit-spinetail': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Nearctic',
#   'body mass': '10.5 g',
#   'ecoregion': 'Tamaulipan Mezquital',
#   'geographic distribution includes': 'Brazil',
#   'habitat': 'subtropical,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Stripe-backed antbird': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '23 g',
#   'ecoregion': 'Chiquitano Dry Forests',
#   'geographic distribution includes': 'Bolivia',
#   'habitat': 'subtropical,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Stripe-backed bittern': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '104 g',
#   'ecoregion': 'Chilean Matorral',
#   'geographic distribution includes': 'South Pacific',
#   'habitat': 'freshwater habitat',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '20 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Stripe-backed wren': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '25.5 g',
#   'ecoregion': 'Araya And Paria Xeric Scrub',
#   'geographic distribution includes': 'Venezuela',
#   'habitat': 'terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Stripe-billed aracari': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '275 g',
#   'ecoregion': 'Western Ecuador Moist Forests',
#   'geographic distribution includes': 'Colombia',
#   'habitat': 'terrestrial',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'type specimen repository': 'NHMUK',
#   'visual system': 'corneal eyes'},
#  'Stripe-breasted rhabdornis': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the indo-malayan realm',
#   'body mass': '47.2 g',
#   'ecoregion': 'Greater Negros-Panay Rain Forests',
#   'geographic distribution includes': 'The Philippines',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'type specimen repository': 'NHMUK',
#   'visual system': 'corneal eyes'},
#  'Stripe-breasted spinetail': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'ecoregion': 'Venezuelan Andes Montane Forests',
#   'geographic distribution includes': 'Brazil',
#   'habitat': 'tropical,terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Stripe-breasted starthroat': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '5.9 g',
#   'conservation status': 'cites appendix ii',
#   'geographic distribution includes': 'Brazil',
#   'habitat': 'subtropical,terrestrial',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visits flowers of': 'corneal eyes'},
#  'Stripe-breasted tit': {'auditory system': 'tympanic middle ear',
#   'body mass': '17.6 g',
#   'geographic distribution includes': 'Burundi',
#   'habitat': 'subtropical,terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Stripe-breasted woodpecker': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the palearctic',
#   'body mass': '52 g',
#   'ecoregion': 'Nujiang Langcang Gorge Alpine Conifer And Mixed Forests',
#   'geographic distribution includes': 'China',
#   'habitat': 'tropical,terrestrial',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Stripe-breasted wren': {'auditory system': 'tympanic middle ear',
#   'geographic distribution includes': 'Colombia',
#   'habitat': 'river,freshwater habitat',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Unknown',
#   'type specimen repository': 'NHMUK',
#   'visual system': 'corneal eyes'},
#  'Stripe-capped sparrow': {'auditory system': 'tympanic middle ear',
#   'geographic distribution includes': 'Bolivia',
#   'habitat': 'tropical,terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Stripe-cheeked greenbul': {'auditory system': 'tympanic middle ear',
#   'eats': 'Mozambique',
#   'geographic distribution includes': 'subtropical',
#   'habitat': '5000 Hz',
#   'hearing range': '10 dB',
#   'hearing threshold': 'flight',
#   'locomotion': 'apatite',
#   'mineralized skeleton contains': 'NHMUK',
#   'type specimen repository': 'corneal eyes'},
#  'Stripe-cheeked woodpecker': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'ecoregion': 'Isthmian-Atlantic Moist Forests',
#   'geographic distribution includes': 'Panama',
#   'habitat': 'terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Stripe-chested antwren': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '8.300000000000001 g',
#   'genome size': '1.362 pg',
#   'geographic distribution includes': 'Bolivia',
#   'habitat': 'tropical,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Stripe-crowned spinetail': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '17 g',
#   'ecoregion': 'Uruguayan Savanna',
#   'geographic distribution includes': 'Argentina',
#   'habitat': 'subtropical,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Stripe-faced greenbul': {'auditory system': 'tympanic middle ear',
#   'eats': 'Tanzania',
#   'geographic distribution includes': '5000 Hz',
#   'hearing range': '10 dB',
#   'hearing threshold': 'flight',
#   'locomotion': 'apatite',
#   'mineralized skeleton contains': 'corneal eyes'},
#  'Stripe-faced wood quail': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '324 g',
#   'geographic distribution includes': 'Bolivia',
#   'habitat': 'grassland,terrestrial',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'type specimen repository': 'NHMUK',
#   'visual system': 'corneal eyes'},
#  'Stripe-headed antpitta': {'auditory system': 'tympanic middle ear',
#   'genome size': '1.284 pg',
#   'geographic distribution includes': 'Bolivia',
#   'habitat': 'montane forest,terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Stripe-headed rhabdornis': {'auditory system': 'tympanic middle ear',
#   'eats': 'The Philippines',
#   'geographic distribution includes': 'terrestrial',
#   'habitat': '5000 Hz',
#   'hearing range': '10 dB',
#   'hearing threshold': 'flight',
#   'locomotion': 'apatite',
#   'mineralized skeleton contains': 'Decreasing',
#   'population trend': 'corneal eyes'},
#  'Stripe-headed sparrow': {'auditory system': 'otoliths',
#   'geographic distribution includes': 'Costa Rica',
#   'habitat': 'terrestrial',
#   'hearing range': '1000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Stripe-necked tody-tyrant': {'auditory system': 'otoliths',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '10.1 g',
#   'ecoregion': 'Purus-Madeira Moist Forests',
#   'geographic distribution includes': 'Bolivia',
#   'habitat': 'tropical,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Stripe-tailed hummingbird': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '4.3 g',
#   'conservation status': 'cites appendix ii',
#   'eats': 'Panama',
#   'geographic distribution includes': 'subtropical',
#   'habitat': 'terrestrial,bipedal movement',
#   'locomotion': 'Unknown',
#   'population trend': 'corneal eyes'},
#  'Stripe-tailed yellow finch': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '12.9 g',
#   'geographic distribution includes': 'Bolivia',
#   'habitat': 'savanna,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'type specimen repository': 'Harvard UNiversity, Museum of Comparative Zoology',
#   'visual system': 'corneal eyes'},
#  'Stripe-throated bulbul': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the indo-malayan realm',
#   'body mass': '26.3 g',
#   'eats': 'Irrawaddy Moist Deciduous Forests',
#   'ecoregion': 'Vietnam',
#   'geographic distribution includes': 'montane forest',
#   'habitat': '5000 Hz',
#   'hearing range': '10 dB',
#   'hearing threshold': 'flight',
#   'locomotion': 'apatite',
#   'mineralized skeleton contains': 'corneal eyes'},
#  'Stripe-throated hermit': {'auditory system': 'tympanic middle ear',
#   'body mass': '3 g',
#   'conservation status': 'cites appendix ii',
#   'geographic distribution includes': 'Nicaragua',
#   'habitat': 'valley,terrestrial',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Unknown',
#   'type specimen repository': 'NHMUK',
#   'visits flowers of': 'corneal eyes'},
#  'Stripe-throated jery': {'parasitized by': 'tympanic middle ear',
#   'auditory system': 'Afrotropics',
#   'biogeographic realm': 'Madagascar Spiny Thickets',
#   'ecoregion': 'Madagascar',
#   'geographic distribution includes': 'subtropical',
#   'habitat': '5000 Hz',
#   'hearing range': '10 dB',
#   'hearing threshold': 'bipedal movement',
#   'locomotion': 'apatite',
#   'mineralized skeleton contains': 'NHMUK',
#   'type specimen repository': 'corneal eyes'},
#  'Stripe-throated wren': {'auditory system': 'tympanic middle ear',
#   'geographic distribution includes': 'Colombia',
#   'habitat': 'terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Unknown',
#   'visual system': 'corneal eyes'},
#  'Stripe-throated yuhina': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the palearctic',
#   'body mass': '24 g',
#   'geographic distribution includes': 'Bhutan',
#   'habitat': 'subtropical,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'type specimen repository': 'NHMUK',
#   'visual system': 'corneal eyes'},
#  'Striped crake': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'Afrotropics',
#   'body mass': '61 g',
#   'ecoregion': 'Southern Africa Mangroves',
#   'geographic distribution includes': 'Indian Ocean',
#   'habitat': 'coastal',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '20 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'visual system': 'corneal eyes'},
#  'Striped cuckoo': {'biogeographic realm': 'The Neotropics',
#   'body shape': 'bilaterally symmetric',
#   'diet includes': 'insects',
#   'geographic distribution includes': 'South Pacific',
#   'habitat': 'tropical',
#   'locomotion': 'flight',
#   'mating system': 'promiscuous',
#   'native range includes': 'The Nearctic',
#   'parental care': 'protection',
#   'population trend': 'Stable',
#   'social system': 'solitary',
#   'trophic guild': 'insectivore'},
#  'Striped flowerpecker': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the indo-malayan realm',
#   'ecoregion': 'Mindoro Rain Forests',
#   'geographic distribution includes': 'The Philippines',
#   'habitat': 'tropical',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'visual system': 'corneal eyes'},
#  'Striped flufftail': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'Afrotropics',
#   'body mass': '30 g',
#   'ecoregion': 'Kwazulu-Cape Coastal Forest Mosaic',
#   'geographic distribution includes': 'Swaziland',
#   'habitat': 'alpine,freshwater habitat',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Striped honeyeater': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'body mass': '45 g',
#   'ecoregion': 'Mitchell Grass Downs',
#   'geographic distribution includes': 'Australia',
#   'habitat': 'scrubland,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Striped kingfisher': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'Afrotropics',
#   'body mass': '55 g',
#   'geographic distribution includes': 'Mozambique',
#   'habitat': 'savanna,terrestrial',
#   'hearing threshold': '20 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'type specimen repository': 'University Museum of Zoology, Cambridge',
#   'visual system': 'corneal eyes'},
#  'Striped laughingthrush': {'auditory system': 'tympanic middle ear',
#   'geographic distribution includes': 'India',
#   'habitat': 'subtropical,terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'type specimen repository': 'NHMUK',
#   'visual system': 'corneal eyes'},
#  'Striped owl': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '485 g',
#   'conservation status': 'cites appendix ii',
#   'eats': 'Lara-FalcóN Dry Forests',
#   'ecoregion': 'Honduras',
#   'geographic distribution includes': '5000 Hz',
#   'hearing range': '-15 dB',
#   'hearing threshold': 'flight',
#   'locomotion': 'apatite',
#   'mineralized skeleton contains': 'corneal eyes'},
#  'Striped pipit': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'Afrotropics',
#   'body mass': '38 g',
#   'ecoregion': 'Angolan Scarp Savanna And Woodlands',
#   'geographic distribution includes': 'Mozambique',
#   'habitat': 'savanna,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Striped sparrow': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Nearctic',
#   'body mass': '53.7 g',
#   'ecoregion': 'Trans-Mexican Volcanic Belt Pine-Oak Forests',
#   'geographic distribution includes': 'United States',
#   'habitat': 'montane forest,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Striped treehunter': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '45.6 g',
#   'ecoregion': 'Eastern Cordillera Real Montane Forests',
#   'geographic distribution includes': 'Bolivia',
#   'habitat': 'temperate,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Striped woodcreeper': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '37 g',
#   'ecoregion': 'Xingu-Tocantins-Araguaia Moist Forests',
#   'geographic distribution includes': 'South Atlantic',
#   'habitat': 'subtropical,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Striped woodpecker': {'auditory system': 'otoliths',
#   'geographic distribution includes': 'Bolivia',
#   'habitat': 'terrestrial',
#   'hearing range': '1000 Hz',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Striped wren-babbler': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the indo-malayan realm',
#   'body mass': '21.1 g',
#   'conservation status': 'near threatened',
#   'geographic distribution includes': 'Malaysia',
#   'habitat': 'subtropical,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Strong-billed honeyeater': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'body mass': '28.5 g',
#   'ecoregion': 'Tasmanian Temperate Forests',
#   'geographic distribution includes': 'Australia',
#   'habitat': 'temperate,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Strong-billed woodcreeper': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '126 g',
#   'ecoregion': 'Cauca Valley Dry Forests',
#   'geographic distribution includes': 'South Pacific',
#   'habitat': 'subtropical,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Stub-tailed antbird': {'auditory system': 'otoliths',
#   'habitat': 'subtropical,terrestrial',
#   'hearing range': '1000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Stub-tailed spadebill': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '10.8 g',
#   'geographic distribution includes': 'Belize',
#   'habitat': 'subtropical,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'type specimen repository': 'NHMUK',
#   'visual system': 'corneal eyes'},
#  'Stubble quail': {'biogeographic realm': 'australasia',
#   'body shape': 'bilaterally symmetric',
#   'diet includes': 'insects',
#   'geographic distribution includes': 'Indian Ocean',
#   'habitat': 'grassland',
#   'locomotion': 'flight',
#   'native range includes': 'Australia',
#   'parental care': 'no parental care',
#   'population trend': 'Increasing',
#   'social system': 'group living',
#   'trophic guild': 'granivore',
#   'type specimen repository': 'NHMUK'},
#  "Stuhlmann's starling": {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'Afrotropics',
#   'body mass': '39 g',
#   'eats': 'Ethiopian Montane Grasslands And Woodlands',
#   'ecoregion': 'Uganda',
#   'geographic distribution includes': 'terrestrial',
#   'habitat': '10 dB',
#   'hearing threshold': 'flight',
#   'locomotion': 'apatite',
#   'mineralized skeleton contains': 'Decreasing',
#   'population trend': 'corneal eyes'},
#  "Styan's bulbul": {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the indo-malayan realm',
#   'body mass': '31 g',
#   'conservation status': 'vulnerable',
#   'eats': 'China',
#   'geographic distribution includes': 'coastal',
#   'habitat': 'terrestrial,bipedal movement',
#   'locomotion': 'Decreasing',
#   'population trend': 'NHMUK',
#   'type specimen repository': 'corneal eyes'},
#  "Styan's grasshopper warbler": {'auditory system': 'tympanic middle ear',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'visual system': 'corneal eyes'},
#  'Stygian owl': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '675 g',
#   'conservation status': 'cites appendix ii',
#   'eats': 'Honduras',
#   'geographic distribution includes': 'terrestrial',
#   'habitat': 'flight',
#   'locomotion': 'apatite',
#   'mineralized skeleton contains': 'Decreasing',
#   'population trend': '(MLZ) - MLZ Bird Collection (Arctos) {http://www.oxy.edu/moore-lab-zoology}',
#   'type specimen repository': 'corneal eyes'},
#  'Subantarctic shearwater': {'auditory system': 'tympanic middle ear',
#   'ecomorphological guild': 'nectonic',
#   'habitat': 'marine,marine',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '20 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Subantarctic snipe': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'body mass': '118 g',
#   'conservation status': 'near threatened',
#   'ecoregion': 'Northland Temperate Kauri Forests',
#   'geographic distribution includes': 'New Zealand',
#   'habitat': 'terrestrial',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Increasing',
#   'visual system': 'corneal eyes'},
#  'Subdesert brush warbler': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'Afrotropics',
#   'body mass': '20 g',
#   'ecoregion': 'Madagascar Spiny Thickets',
#   'geographic distribution includes': 'Madagascar',
#   'habitat': 'terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Subdesert mesite': {'auditory system': 'tympanic middle ear',
#   'behavioral circadian rhythm': 'diurnal',
#   'biogeographic realm': 'Afrotropics',
#   'body shape': 'bilaterally symmetric',
#   'conservation status': 'vulnerable',
#   'geographic distribution includes': 'Indian Ocean',
#   'habitat': 'desert,terrestrial',
#   'locomotion': 'flight',
#   'native range includes': 'Ethiopia',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Subtropical cacique': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '71.7 g',
#   'eats': 'Northwestern Andean Montane Forests',
#   'ecoregion': 'Bolivia',
#   'geographic distribution includes': 'subtropical',
#   'habitat': '5000 Hz',
#   'hearing range': '10 dB',
#   'hearing threshold': 'bipedal movement',
#   'locomotion': 'apatite',
#   'mineralized skeleton contains': 'corneal eyes'},
#  'Subtropical doradito': {'auditory system': 'tympanic middle ear',
#   'behavioral circadian rhythm': 'diurnal',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '8.300000000000001 g',
#   'geographic distribution includes': 'Bolivia',
#   'habitat': 'tropical,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Subtropical pygmy owl': {'auditory system': 'otoliths',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '63.1 g',
#   'conservation status': 'cites appendix ii',
#   'geographic distribution includes': 'Bolivia',
#   'habitat': 'tropical,terrestrial',
#   'hearing threshold': '-15 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Sucre antpitta': {'auditory system': 'otoliths',
#   'conservation status': 'vulnerable',
#   'geographic distribution includes': 'Venezuela',
#   'habitat': 'subtropical,terrestrial',
#   'hearing range': '1000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Sudan golden sparrow': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the palearctic',
#   'body mass': '15 g',
#   'geographic distribution includes': 'Cameroon',
#   'habitat': 'savanna,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'prenatal development duration': '14 days',
#   'visual system': 'corneal eyes'},
#  'Suiriri flycatcher': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '15.7 g',
#   'eats': 'Argentina',
#   'geographic distribution includes': 'woodland',
#   'habitat': 'terrestrial,flight',
#   'locomotion': 'apatite',
#   'mineralized skeleton contains': 'Decreasing',
#   'population trend': 'Museu Paraense Emilio Goeldi',
#   'type specimen repository': 'corneal eyes'},
#  'Sula cicadabird': {'auditory system': 'tympanic middle ear',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Sula cuckoo-dove': {'auditory system': 'tympanic middle ear',
#   'habitat': 'terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '20 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Sula dwarf kingfisher': {'auditory system': 'tympanic middle ear',
#   'conservation status': 'near threatened',
#   'habitat': 'subtropical,terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '20 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'type specimen repository': 'NHMUK',
#   'visual system': 'corneal eyes'},
#  'Sula fruit dove': {'auditory system': 'tympanic middle ear',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'tropical',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '20 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'visual system': 'corneal eyes'},
#  'Sula hanging parrot': {'auditory system': 'otoliths',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'terrestrial',
#   'hearing range': '1000 Hz',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'type specimen repository': 'NHMUK',
#   'visual system': 'corneal eyes'},
#  'Sula jungle flycatcher': {'auditory system': 'tympanic middle ear',
#   'conservation status': 'near threatened',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'tropical,terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Sula megapode': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'conservation status': 'vulnerable',
#   'ecoregion': 'Sulawesi Lowland Rain Forests',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'tropical,terrestrial',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Sula pitta': {'auditory system': 'tympanic middle ear',
#   'conservation status': 'near threatened',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'subtropical,freshwater habitat',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Sula scops owl': {'auditory system': 'tympanic middle ear',
#   'conservation status': 'near threatened',
#   'habitat': 'terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '-15 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Sulawesi babbler': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'body mass': '29 g',
#   'ecoregion': 'Sulawesi Lowland Rain Forests',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Sulawesi blue flycatcher': {'auditory system': 'tympanic middle ear',
#   'body mass': '21 g',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'tropical,terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Sulawesi bush warbler': {'auditory system': 'tympanic middle ear',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'mountain,terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Sulawesi cicadabird': {'auditory system': 'tympanic middle ear',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Sulawesi cuckoo': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'ecoregion': 'Sulawesi Lowland Rain Forests',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'tropical,terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '20 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Sulawesi drongo': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'body mass': '61 g',
#   'ecoregion': 'Sulawesi Montane Rain Forests',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'subtropical,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Unknown',
#   'visual system': 'corneal eyes'},
#  'Sulawesi dwarf kingfisher': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'body mass': '20.5 g',
#   'conservation status': 'near threatened',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'tropical,terrestrial',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Sulawesi fantail': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'body mass': '14 g',
#   'ecoregion': 'Sulawesi Lowland Rain Forests',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'tropical,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Sulawesi goshawk': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'body mass': '299 g',
#   'conservation status': 'cites appendix ii',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'montane forest,terrestrial',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Sulawesi ground dove': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'body mass': '275 g',
#   'ecoregion': 'Sulawesi Montane Rain Forests',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Sulawesi hawk-eagle': {'auditory system': 'otoliths',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'terrestrial',
#   'hearing range': '1000 Hz',
#   'hearing threshold': '20 dB',
# ...
#   'hearing threshold': 'flight',
#   'locomotion': 'apatite',
#   'mineralized skeleton contains': 'Stable',
#   'population trend': 'University Museum of Zoology, Cambridge',
#   'type specimen repository': 'corneal eyes'},
#  'Western spinebill': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'body mass': '11 g',
#   'ecoregion': 'Southwest Australia Savanna',
#   'geographic distribution includes': 'Australia',
#   'habitat': 'heath,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Western square-tailed drongo': {'auditory system': 'tympanic middle ear',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'visual system': 'corneal eyes'},
#  'Western striolated puffbird': {'auditory system': 'otoliths',
#   'geographic distribution includes': 'Bolivia',
#   'habitat': 'tropical',
#   'hearing range': '1000 Hz',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'type specimen repository': 'Museu Paraense Emilio Goeldi',
#   'visual system': 'corneal eyes'},
#  'Western swamphen': {'biogeographic realm': 'the palearctic',
#   'body shape': 'bilaterally symmetric',
#   'diet includes': 'insects',
#   'foraging habitat': 'freshwater',
#   'geographic distribution includes': 'United States',
#   'locomotion': 'running',
#   'mating system': 'polygynous',
#   'native range includes': 'Ethiopia',
#   'parental care': 'protection',
#   'population trend': 'Unknown',
#   'social system': 'group living',
#   'type specimen repository': 'Museum of Zoology Senckenberg Dresden'},
#  'Western tanager': {'biogeographic realm': 'The Neotropics',
#   'body shape': 'bilaterally symmetric',
#   'diet includes': 'insects',
#   'geographic distribution includes': 'California',
#   'litters per year': '1 /year',
#   'locomotion': 'flight',
#   'mating system': 'monogamous',
#   'native range includes': 'United States',
#   'parental care': 'provisioning',
#   'population trend': 'Increasing',
#   'prenatal development duration': '13 days',
#   'trophic guild': 'insectivore'},
#  'Western thornbill': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'body mass': '8 g',
#   'ecoregion': 'Swan Coastal Plain Scrub And Woodlands',
#   'geographic distribution includes': 'Australia',
#   'habitat': 'terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'type specimen repository': 'NHMUK',
#   'visual system': 'corneal eyes'},
#  'Western tinkerbird': {'auditory system': 'otoliths',
#   'geographic distribution includes': 'Cameroon',
#   'habitat': 'terrestrial',
#   'hearing range': '1000 Hz',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Western tragopan': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the indo-malayan realm',
#   'body mass': '2150 g',
#   'conservation status': 'vulnerable',
#   'geographic distribution includes': 'Pakistan',
#   'habitat': 'temperate,terrestrial',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Western violet-backed sunbird': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'Afrotropics',
#   'geographic distribution includes': 'Mozambique',
#   'habitat': 'tropical,freshwater habitat',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'type specimen repository': 'NHMUK',
#   'visits flowers of': 'corneal eyes'},
#  'Western wattlebird': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'body mass': '78 g',
#   'ecoregion': 'Esperance Mallee',
#   'geographic distribution includes': 'Australia',
#   'habitat': 'coastal,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Increasing',
#   'visual system': 'corneal eyes'},
#  'Western wattled cuckooshrike': {'auditory system': 'tympanic middle ear',
#   'conservation status': 'vulnerable',
#   'geographic distribution includes': 'Guinea',
#   'habitat': 'subtropical,terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Western whistler': {'auditory system': 'tympanic middle ear',
#   'geographic distribution includes': 'Indian Ocean',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'visual system': 'corneal eyes'},
#  'Western wood pewee': {'biogeographic realm': 'The Neotropics',
#   'body shape': 'bilaterally symmetric',
#   'diet includes': 'arthropods',
#   'geographic distribution includes': 'California',
#   'life span': '8.1 years',
#   'litters per year': '1 /year',
#   'locomotion': 'flight',
#   'mating system': 'monogamous',
#   'parental care': 'protection',
#   'population trend': 'Decreasing',
#   'prenatal development duration': '14 days',
#   'trophic guild': 'insectivore'},
#  'Western woodhaunter': {'auditory system': 'tympanic middle ear',
#   'habitat': 'subtropical',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'visual system': 'corneal eyes'},
#  'Western yellow robin': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'ecoregion': 'Murray-Darling Woodlands And Mallee',
#   'geographic distribution includes': 'Australia',
#   'habitat': 'arid,terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Western yellow wagtail': {'basal metabolic rate': '0.257 watts',
#   'biogeographic realm': 'the palearctic',
#   'foraging habitat': 'terrestrial',
#   'geographic distribution includes': 'United States',
#   'habitat': 'mountain',
#   'life span': '8.8 years',
#   'litters per year': '1 /year',
#   'locomotion': 'flight',
#   'prenatal development duration': '11 days',
#   'trophic guild': 'invertivore',
#   'type specimen repository': 'Zoologisches Forschungsmuseum Alexander Koenig',
#   'weight': '17.7 g'},
#  'Westland petrel': {'auditory system': 'tympanic middle ear',
#   'body mass': '1199 g',
#   'eats': 'nectonic',
#   'ecomorphological guild': 'marine pelagic',
#   'foraging habitat': 'New Zealand',
#   'geographic distribution includes': 'coastal',
#   'habitat': 'terrestrial,flight',
#   'locomotion': 'Unknown',
#   'population trend': 'invertivore',
#   'trophic guild': 'corneal eyes'},
#  'Wetar figbird': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'ecoregion': 'Timor And Wetar Deciduous Forests',
#   'geographic distribution includes': 'Indonesia',
#   'habitat': 'terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Wetar ground dove': {'auditory system': 'tympanic middle ear',
#   'conservation status': 'endangered',
#   'habitat': 'terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '20 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  "Weyns's weaver": {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'Afrotropics',
#   'body mass': '33.5 g',
#   'ecoregion': 'Eastern Congolian Swamp Forests',
#   'geographic distribution includes': 'Uganda',
#   'habitat': 'freshwater habitat',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Whinchat': {'biogeographic realm': 'Afrotropics',
#   'foraging habitat': 'terrestrial',
#   'geographic distribution includes': 'Mozambique',
#   'growth rate': '0.433 /day',
#   'habitat': 'grassland',
#   'life span': '6.9 years',
#   'locomotion': 'flight',
#   'population trend': 'Decreasing',
#   'preys on': 'invertivore',
#   'trophic guild': 'Zoologisches Forschungsmuseum Alexander Koenig',
#   'type specimen repository': '16.6 g'},
#  'Whiskered auklet': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Nearctic',
#   'body mass': '132 g',
#   'clutch/brood/litter size': '1',
#   'eats': 'nectonic',
#   'ecomorphological guild': 'North Pacific',
#   'geographic distribution includes': '15 years',
#   'life span': 'flight',
#   'locomotion': 'Decreasing',
#   'population trend': 'corneal eyes',
#   'visual system': '120 g'},
#  'Whiskered flowerpecker': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the indo-malayan realm',
#   'body mass': '10.2 g',
#   'ecoregion': 'Mindanao Montane Rain Forests',
#   'geographic distribution includes': 'The Philippines',
#   'habitat': 'montane forest,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'Whiskered myiobius': {'parasitized by': 'tympanic middle ear',
#   'auditory system': '13.5 g',
#   'body mass': 'Belize',
#   'geographic distribution includes': 'subtropical',
#   'habitat': 'terrestrial,5000 Hz',
#   'hearing range': '10 dB',
#   'hearing threshold': 'bipedal movement',
#   'locomotion': 'apatite',
#   'mineralized skeleton contains': 'Stable',
#   'population trend': 'corneal eyes'},
#  'Whiskered pitta': {'biogeographic realm': 'the indo-malayan realm',
#   'conservation status': 'cites appendix i',
#   'ecoregion': 'Luzon Montane Rain Forests',
#   'geographic distribution includes': 'The Philippines'},
#  'Whiskered screech owl': {'auditory system': 'tympanic middle ear',
#   'behavioral circadian rhythm': 'nocturnal',
#   'body mass': '121 g',
#   'conservation status': 'cites appendix ii',
#   'geographic distribution includes': 'United States',
#   'habitat': 'terrestrial',
#   'hearing threshold': '-15 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Increasing',
#   'type specimen repository': '(MLZ) - MLZ Bird Collection (Arctos) {http://www.oxy.edu/moore-lab-zoology}',
#   'visual system': 'corneal eyes'},
#  'Whiskered tern': {},
#  'Whiskered treeswift': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the indo-malayan realm',
#   'ecoregion': 'Peninsular Malaysian Peat Swamp Forests',
#   'geographic distribution includes': 'Indian Ocean',
#   'habitat': 'subtropical,terrestrial',
#   'hearing threshold': '20 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'type specimen repository': 'Harvard UNiversity, Museum of Comparative Zoology',
#   'visual system': 'corneal eyes'},
#  'Whiskered wren': {'auditory system': 'tympanic middle ear',
#   'geographic distribution includes': 'Bolivia',
#   'habitat': 'terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Unknown',
#   'visual system': 'corneal eyes'},
#  'Whiskered yuhina': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the palearctic',
#   'body mass': '22 g',
#   'geographic distribution includes': 'Vietnam',
#   'habitat': 'subtropical,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Unknown',
#   'type specimen repository': 'NHMUK',
#   'visual system': 'corneal eyes'},
#  "Whistler's warbler": {'auditory system': 'tympanic middle ear',
#   'habitat': 'terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Whistling cisticola': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'Afrotropics',
#   'body mass': '19 g',
#   'ecoregion': 'Western Guinean Lowland Forests',
#   'geographic distribution includes': 'North Atlantic',
#   'habitat': 'coastal,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Stable',
#   'visual system': 'corneal eyes'},
#  'Whistling fruit dove': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'Oceania continent (Australia, NZ and islands)',
#   'ecoregion': 'fiji tropical moist forests',
#   'geographic distribution includes': 'Fiji',
#   'habitat': 'tropical',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '20 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'visual system': 'corneal eyes'},
#  'Whistling green pigeon': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'the indo-malayan realm',
#   'body mass': '140 g',
#   'conservation status': 'near threatened',
#   'eats': 'Japan',
#   'geographic distribution includes': 'tropical',
#   'habitat': 'terrestrial,flight',
#   'locomotion': 'Decreasing',
#   'population trend': 'NHMUK',
#   'type specimen repository': 'corneal eyes'},
#  'Whistling heron': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '555 g',
#   'ecoregion': 'Uruguayan Savanna',
#   'geographic distribution includes': 'United States',
#   'habitat': 'tropical,terrestrial',
#   'hearing threshold': '20 dB',
#   'locomotion': 'flight',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Unknown',
#   'visual system': 'corneal eyes'},
#  'Whistling kite': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'australasia',
#   'body mass': '753 g',
#   'conservation status': 'cites appendix ii',
#   'foraging habitat': 'terrestrial',
#   'geographic distribution includes': 'New Caledonia',
#   'habitat': 'mountain,freshwater habitat',
#   'locomotion': 'flight',
#   'population trend': 'Decreasing',
#   'trophic guild': 'vertivore',
#   'visual system': 'corneal eyes'},
#  'Whistling warbler': {'auditory system': 'tympanic middle ear',
#   'biogeographic realm': 'The Neotropics',
#   'body mass': '17.5 g',
#   'conservation status': 'endangered',
#   'geographic distribution includes': 'Saint Vincent And The Grenadines',
#   'habitat': 'river,terrestrial',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'White bellbird': {'auditory system': 'tympanic middle ear',
#   'body mass': '210 g',
#   'geographic distribution includes': 'Brazil',
#   'habitat': 'terrestrial',
#   'hearing range': '5000 Hz',
#   'hearing threshold': '10 dB',
#   'locomotion': 'bipedal movement',
#   'mineralized skeleton contains': 'apatite',
#   'population trend': 'Decreasing',
#   'visual system': 'corneal eyes'},
#  'White cockatoo': {'biogeographic realm': 'australasia',
#   'body shape': 'bilaterally symmetric',
#   'diet includes': 'fruit',
#   'geographic distribution includes': 'United States',
#   'growth rate': '0.13 /day',
#   'locomotion': 'flight',
#   'mating system': 'monogamous',
#   'native range includes': 'Australia',
#   'population trend': 'Decreasing',
#   'prenatal development duration': '30 days',
#   'social system': 'group living',
#   'trophic guild': 'frugivore'}}
