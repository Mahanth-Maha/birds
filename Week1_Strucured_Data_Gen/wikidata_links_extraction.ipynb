# %%
import pandas as pd

# %%
data = pd.read_pickle('Dataset_v1_03.pkl')
data.head(4)
# Out:
#      name_to_merge                         Ebird_Link  \
# 0   abbottsbabbler                                NaN
# 1     abbottsbooby  https://ebird.org/species/abbboo2
# 2  abbottsstarling  https://ebird.org/species/abbsta2
# 3   abbottssunbird                                NaN
#
#                                    Ebird_Description  \
# 0                                                NaN
# 1  Gangly, stretched-out-looking black-and-white ...
# 2  A small, distinctive starling with a tiny rang...
# 3                                                NaN
#
#                                           Categories           Country  \
# 0  Articles with species microformats, Articles w...               NaN
# 1  Articles with species microformats, Articles w...  Christmas Island
# 2  All stub articles, Articles with species micro...             Kenya
# 3                                                NaN               NaN
#
# ...

# %%
links = data.loc[:,['name_to_merge',"Image"]]
links.head(4)
# Out:
#      name_to_merge                                              Image
# 0   abbottsbabbler  https://upload.wikimedia.org/wikipedia/commons...
# 1     abbottsbooby  https://upload.wikimedia.org/wikipedia/commons...
# 2  abbottsstarling  https://upload.wikimedia.org/wikipedia/commons...
# 3   abbottssunbird                                                NaN

# %%
lis = list(links.loc[:,'Image'] )
lis[0]
# Out:
# 'https://upload.wikimedia.org/wikipedia/commons/7/7c/Abbott%27s_babbler_%28Malacocincla_abbotti%29.jpg'

# %%
list(links.loc[:,["Image"]])
# Out:
# ['Image']
