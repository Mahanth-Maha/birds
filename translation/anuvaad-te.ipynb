# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install -U deep-translator

# %%
# import pandas as pd
# import numpy as np
# from tqdm import tqdm
# from anuvaad import Anuvaad
# anu = Anuvaad("english-telugu")
# se = "/kaggle/input/birds-data/data_v2_1_geographic_distribution_includes_anuvaad.xlsx"
# # data = pd.read_pickle("/content/data_v5_habitat_anuvaad.pkl")
# def create_telugu_col_new_optim(col,data):
#     di = {}
#     data[col+ ' Telugu'] = np.nan
#     for i in tqdm(range(data.shape[0])):
#         # print(i)
#         if type(data[col][i]) == float:
#             data[col + ' Telugu'][i] = np.nan
#         else:
#             if data[col][i] in di:
#                 data[col + ' Telugu'][i] = di[data[col][i]]
#             else:
#                 data[col + ' Telugu'][i] = anu.anuvaad(data[col][i])
#                 di[data[col][i]] = data[col + ' Telugu'][i]
#     return data

# %%
# !pip install

# %%
# data = pd.read_excel(se)

# %%
# data = create_telugu_col_new_optim('Synonyms',data)
# data.to_pickle('data_v2_2_Synonyms_region_anuvaad.pkl')
# data.to_csv('data_v2_2_Synonyms_region_anuvaad.csv')
# data.to_excel('data_v2_2_Synonyms_region_anuvaad.xlsx')

# %%
# print('Done')

# %%
# data = create_telugu_col_new_optim('Family',data)
# data.to_pickle('data_v2_5_Family_region_anuvaad.pkl')
# data.to_csv('data_v2_5_Family_region_anuvaad.csv')
# data.to_excel('data_v2_5_Family_region_anuvaad.xlsx')

# %%
# data.head(4)

# %%
# data = create_telugu_col_new_optim('locomotion',data)
# data.to_pickle('data_v2_6_loco_region_anuvaad.pkl')
# data.to_csv('data_v2_6_loco_region_anuvaad.csv')
# data.to_excel('data_v2_6_loco_region_anuvaad.xlsx')

# %%
# load_pkl = '../input/birdsdata/Kaggle_birds_out.pkl'

# data_2  = pd.read_pickle(load_pkl)
# data_2.head(3)

# %%
# import pandas as pd
# import numpy as np
# from tqdm import tqdm
# from anuvaad import Anuvaad
# anu = Anuvaad("english-telugu")
# # se = "/kaggle/input/birdsdata/Kaggle_birds_out.pkl"
# # data = pd.read_pickle(se)
# # # sec = 'data_v3_1_des_anuvaad.'
# # # data = pd.read_pickle(sec)
# # def anu_vaad_onebyone(para):
# #     if len(para) != 0:
# #         lis_para = [i.strip() for i in para.strip().split('.') if i != '']
# #         anu_lis_para =  anu.anuvaad(lis_para)
# #         trans_para = '.'.join(anu_lis_para) + '.'
# #         return trans_para
# #     return np.nan

# # def create_telugu_col_new_optim(col,data):
# #     di = {}
# #     data[col+ ' Telugu'] = np.nan
# #     for i in tqdm(range(data.shape[0])):
# #         # print(i)
# #         if type(data[col][i]) == float:
# #             data[col + ' Telugu'][i] = np.nan
# #         else:
# #             if data[col][i] in di:
# #                 data[col + ' Telugu'][i] = di[data[col][i]]
# #             else:
# #                 data[col + ' Telugu'][i] = anu_vaad_onebyone(data[col][i])
# #                 di[data[col][i]] = data[col + ' Telugu'][i]
# #     return data

# %%
# data_2 = create_telugu_col_new_optim('Ebird_Des_Short',data_2)
# data_2.to_pickle('data_v3_1_des_anuvaad.pkl')
# data_2.to_csv('data_v3_1_des_anuvaad.csv')
# data_2.to_excel('data_v3_1_des_anuvaad.xlsx')

# %%
# data = create_telugu_col_new_optim('Eol_Description',data)
# data.to_pickle('data_v3_2_eol_des_anuvaad.pkl')
# data.to_csv('data_v3_2_eol_des_anuvaad.csv')
# data.to_excel('data_v3_2_eol_des_anuvaad.xlsx')

# %%
# data.head(5)

# %%
# d = {'n':'north','s':'south','e':'east','w':'west','c':'centre','ne':'north east','nw':'north west','nc':'north centre','se':'south east','sw':'south west','sc':'south centre','ec':'east centre','wc':'west centre','n,':'north','s,':'south','e,':'east','w,':'west','c,':'centre','ne,':'north east','nw,':'north west','nc,':'north centre','se,':'south east','sw,':'south west','sc,':'south centre','ec,':'east centre','wc,':'west centre'}
# for i in range(data.shape[0]):
#   K = data.loc[i,'Breeding subregion']
#   if type(K) == str:
#     lis_words = K.strip().split(' ')
#     for j in lis_words:
#       if j in d:
#         lis_words[lis_words.index(j)] = d[j]
#     data.loc[i,'Breeding subregion'] = ' '.join(lis_words)

# data.loc[2:12,'Breeding subregion']

# %%
# data = create_telugu_col_new_optim('Breeding subregion',data)
# data.to_pickle('data_v2_7_breedingsubregion_anuvaad.pkl')
# data.to_csv('data_v2_7_breedingsubregion_anuvaad.csv')
# data.to_excel('data_v2_7_breedingsubregion_anuvaad.xlsx')

# %%
# prnit('Finally Done 😌')

# %%
# !pip install sweetviz

# %% [markdown]
# ## Final Data Set Translation

# %%
# old_file = '/kaggle/input/finaldataset/translated_transliterated_data.xlsx'
# new_file = '/kaggle/input/finaldataset/Dataset_final_v3_2.xlsx'
# import pandas as pd
# import numpy as np
# from tqdm import tqdm
# from anuvaad import Anuvaad
# import sweetviz as sv

# anu = Anuvaad("english-telugu")

# old = pd.read_excel(old_file)
# new = pd.read_excel(new_file)


# pd.set_option('display.max_rows', 500)
# pd.set_option('display.max_columns', 500)
# pd.set_option('display.width', 1000)

# def out(data,ver,rep=False):
#     data.to_pickle('Dataset_final_v'+ver+'.pkl')
#     data.to_csv('Dataset_final_v'+ver+'.csv')
#     data.to_excel('Dataset_final_v'+ver+'.xlsx')
#     if rep :
#         sv.analyze(data).show_html('report_final_data_v'+ver+'.html')

# %%
# old.head(4)

# %%
# new.head(4)

# %%
# def telugu_normal(col,data):
#     di = {}
# #     data[col+ ' Telugu'] = np.nan
#     for i in tqdm(range(data.shape[0])):
#         # print(i)
#         if type(data[col][i]) == float:
#             data[col + ' Telugu'][i] = np.nan
#         else:
#             if data[col][i] in di:
#                 data[col + ' Telugu'][i] = di[data[col][i]]
#             else:
#                 data[col + ' Telugu'][i] = anu.anuvaad(data[col][i])
#                 di[data[col][i]] = data[col + ' Telugu'][i]
#     return data

# %%
# def telugu_use_old(col,data,di={}):
#     for i in tqdm(range(data.shape[0])):
#         if type(data[col][i]) == float:
#             data[col + ' Telugu'][i] = np.nan
#         else:
#             if data[col][i] in di:
#                 data[col + ' Telugu'][i] = di[data[col][i]]
#             else:
#                 data[col + ' Telugu'][i] = anu.anuvaad(data[col][i])
#                 di[data[col][i]] = data[col + ' Telugu'][i]
#     return data

# %%
# def get_all_data_into_dict(col='Binomial Name',data=old):
#     try:
#         temp = data[[col,col+' Telugu']].copy()
#         return temp.set_index(col).to_dict()[col+' Telugu']
#     except Exception:
#         temp = data[[col,col+'.1']].copy()
#         return temp.set_index(col).to_dict()[col+'.1']
        
    
# sciname_dict = get_all_data_into_dict()  
# syn_dict = get_all_data_into_dict('Synonyms')
# latinname_dict = get_all_data_into_dict('Old latin name for bird')
# order_dict = get_all_data_into_dict('Order')
# family_dict = get_all_data_into_dict('Family')
# genus_dict = get_all_data_into_dict('Genus')
# species_dict = get_all_data_into_dict('Species')
# habitat_dict = get_all_data_into_dict('Habitat')
# country_dict = get_all_data_into_dict('Country')
# cons_dict = get_all_data_into_dict('Conservation status')
# geograph_dict = get_all_data_into_dict('geographic distribution includes')
# biorealm_dict = get_all_data_into_dict('biogeographic realm')
# populate_dict = get_all_data_into_dict('population trend')
# breedreg_dict = get_all_data_into_dict('Breeding region')
# breedsubreg_dict = get_all_data_into_dict('Breeding subregion')
# vis_dict = get_all_data_into_dict('visual system')
# audi_dict = get_all_data_into_dict('auditory system')
# hearrange_dict = get_all_data_into_dict('hearing range')
# hearthres_dict = get_all_data_into_dict('hearing threshold')
# loco_dict = get_all_data_into_dict('locomotion')
# skele_dict = get_all_data_into_dict('mineralized skeleton contains')
# bodymass_dict = get_all_data_into_dict('body mass')

# %%
# new = telugu_use_old('Scientific Name',new,sciname_dict)
# # new.head(5)
# print('='*25+'SCINAME'+'='*25)

# %%
# new = telugu_use_old('Old latin name for bird',new,latinname_dict)
# # new.head(5)
# print('='*25+'LATIN NAME'+'='*25)

# %%
# new = telugu_use_old('Order',new,order_dict)
# new = telugu_use_old('Family',new,family_dict)
# new = telugu_use_old('Species',new,species_dict)
# print('='*25+'FAMILY'+'='*25)
# # new.head(5)

# %%
# new = telugu_use_old('Country',new,country_dict)
# new = telugu_use_old('geographic distribution includes',new,geograph_dict)
# new = telugu_use_old('biogeographic realm',new,biorealm_dict)
# new = telugu_use_old('Population Growth',new,populate_dict)
# # new.head(5)
# print('='*25+'POPULATION'+'='*25)

# %%
# d = {'n':'north','s':'south','e':'east','w':'west','c':'centre','ne':'northeast','nw':'northwest','nc':'northcentre','se':'southeast','sw':'southwest','sc':'southcentre','ec':'eastcentre','wc':'westcentre','n,':'north','s,':'south','e,':'east','w,':'west','c,':'centre','ne,':'north east','nw,':'north west','nc,':'north centre','se,':'south east','sw,':'south west','sc,':'south centre','ec,':'east centre','wc,':'west centre'}
# for i in range(new.shape[0]):
#   K = new.loc[i,'Breeding subregion']
#   if type(K) == str:
#     lis_words = K.strip().split(' ')
#     for j in lis_words:
#       if j in d:
#         lis_words[lis_words.index(j)] = d[j]
#     new.loc[i,'Breeding subregion'] = ' '.join(lis_words)

# new.loc[2:12,'Breeding subregion']

# %%
# new = telugu_use_old('Breeding region',new,breedreg_dict)
# new = telugu_use_old('Breeding subregion',new,breedsubreg_dict)
# new = telugu_use_old('visual system',new,vis_dict)
# new = telugu_use_old('auditory system',new,audi_dict)
# new = telugu_use_old('hearing range',new,hearrange_dict)
# new = telugu_use_old('hearing threshold',new,hearthres_dict)
# # new.head(5)
# print('='*25+'AUDIO VIDEO'+'='*25)

# %%
# new = telugu_use_old('locomotion',new,loco_dict)
# new = telugu_use_old('mineralized skeleton contains',new,skele_dict)
# new = telugu_use_old('body mass',new,bodymass_dict)
# # new.head(5)
# print('='*25+'LOCO'+'='*25)

# %% [markdown]
# ## Special Treatment 4 💥

# %%
# new = telugu_use_old('Life Span',new)
# new = telugu_use_old('altitude',new)
# new.head(10)
# print('='*25+'LIFE SPAN'+'='*25)

# %%
# new.head(6)

# %%
# out(new,'3_3')

# %%
# def telugu_genus(col='Genus',data=new,di={}):
#     for i in tqdm(range(data.shape[0])):
#         if type(data['Scientific Name Telugu'][i]) == np.float:
#             data[col + ' Telugu'][i] = np.nan
#         else:
#             if data[col][i] in di:
#                 data[col + ' Telugu'][i] = di[data[col][i]]
#             elif type(data['Scientific Name Telugu'][i]) != float:
#                 data[col + ' Telugu'][i] = data['Scientific Name Telugu'][i].split(' ')[0]
#                 di[data[col][i]] = data[col + ' Telugu'][i]
#     return data
# new = telugu_genus()
# new.head(5)

# %%
    # import re
    # import numpy as np
    # import string
    # def clean_cs(text):
    #     '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    #     if type(text) == str and text.lower().strip() not in ('Not evaluated'.lower(),'Data Deficient'.lower(),'',' ','cites appendix ii','data deficient','range restricted'):
    #         text = text.lower()
    #         text = re.sub("[\(\[].*?[\)\]]", "", text)
    #         text = re.sub('\n', '', text)
    #         # text = re.sub('\[.*?\]', '', text)
    #         # text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    #         text = re.sub('[-‘’“”…]', '', text)
    #         # text = re.sub(' ', '', text)
    #         text = re.sub('[0-9]', '', text)
    #         if 'least concern' in text or 'lc' in text:
    #             return 'least concern'
    #         if 'extinct' in text:
    #             return 'extinct'
    #         return text.strip()
    #     return np.nan
    # clean_c = lambda x: clean_cs(x)
    # new.rename({'Conservation status':'cs'},axis=1,inplace=True)
    # new['Conservation status'] = new.cs.apply(clean_c)
    # new['Conservation status'] = new.cs.apply(clean_c)
    # new.drop(['cs'],axis=1,inplace=True)
    # new.head(5)

# %%
# new = telugu_use_old('Conservation status',new,cons_dict)
# print('='*25+'CONSER STAT'+'='*25)
# new.head(4)

# %%
# new = telugu_use_old('Synonyms',new,syn_dict)
# print('='*25+'SYN'+'='*25)

# %%
# len(habitat_dict)

# %%
# for i in sciname_dict:
#     habitat_dict[i] = sciname_dict[i]

# for i in latinname_dict:
#     habitat_dict[i] = latinname_dict[i]
# len(habitat_dict)
# print('='*25+'HABITAT START'+'='*25)

# %%
# new = telugu_use_old('Habitat',new,habitat_dict)

# %%
# out(new,'3_4',rep=True)
# print('='*25+'V3.4'+'='*25)

# %%
# new['Kingdom'+' Telugu'] = 'జంతువులు'
# new['Subkingdom'+' Telugu'] = 'బిలేటేరియా'
# new['Infrakingdom'+' Telugu'] = 'డ్యూటెరోస్టోమియా'
# new['Phylum'+' Telugu'] = 'చోర్డేటా'
# new['Subphylum'+' Telugu'] = 'వెన్నుపూస'
# new['Infraphylum'+' Telugu'] = 'గ్నాథోస్టోమాటా'
# new['Superclass'+' Telugu'] = 'టెట్రాపోడా'
# new['Class'+' Telugu'] = 'ఏవ్స్ (పక్షులు)'
# new['founded Telugu'] = new['founded']
# col_t = ['Bird Original Name', 'Bird Original Name Telugu', 'Scientific Name', 'Scientific Name Telugu', 'Synonyms', 'Synonyms Telugu', 'Old latin name for bird', 'Old latin name for bird Telugu', 'Scientist', 'Scientist Telugu', 'founded', 'founded Telugu', 'Kingdom', 'Kingdom Telugu', 'Subkingdom', 'Subkingdom Telugu', 'Infrakingdom', 'Infrakingdom Telugu', 'Phylum', 'Phylum Telugu', 'Subphylum', 'Subphylum Telugu', 'Infraphylum', 'Infraphylum Telugu', 'Superclass', 'Superclass Telugu', 'Class', 'Class Telugu', 'Order', 'Order Telugu', 'Family', 'Family Telugu', 'Genus', 'Genus Telugu', 'Species', 'Species Telugu', 'Conservation status', 'Conservation status Telugu', 'Habitat', 'Habitat Telugu', 'Country', 'Country Telugu', 'geographic distribution includes', 'geographic distribution includes Telugu', 'biogeographic realm', 'biogeographic realm Telugu', 'Population Growth', 'Population Growth Telugu', 'Breeding region', 'Breeding region Telugu', 'Breeding subregion', 'Breeding subregion Telugu', 'Life Span', 'Life Span Telugu', 'altitude', 'altitude Telugu', 'visual system', 'visual system Telugu', 'auditory system', 'auditory system Telugu', 'hearing range', 'hearing range Telugu', 'hearing threshold', 'hearing threshold Telugu', 'locomotion', 'locomotion Telugu', 'mineralized skeleton contains', 'mineralized skeleton contains Telugu', 'body mass', 'body mass Telugu', 'Wiki_Link', 'Image', 'References', 'Wiki_Description', 'Wiki_Description Telugu', 'Ebird_Link', 'Ebird_Description', 'Ebird_Description Telugu', 'Eol_Link', 'Eol_Description', 'Eol_Description Telugu', 'Dibird_Link', 'IUCN_link']
# new = new[col_t]
# out(new,'4_1',rep=True)
# new.head(5)

# %%
# from deep_translator import GoogleTranslator
# # l=[]
# # for i in new['']:
# #     try:
# #         translated = GoogleTranslator(source='auto', target='te').translate(i)
# #         l.append(translated)
# #         print(i,translated)
# #     except:
# #         l.append(np.nan)
# i = new['Ebird_Description'][66]
# print(i)
# translated = GoogleTranslator(source='auto', target='te').translate(i)
# translated

# %%
# def telugu_use_des(col='Ebird_Description',data=new):
#     for i in tqdm(range(data.shape[0])):
#         if type(data[col][i]) == float:
#             data[col + ' Telugu'][i] = np.nan
#         else:
#             try:
#                 data[col + ' Telugu'][i] = GoogleTranslator(source='auto', target='te').translate(data[col][i])
#             except Exception:
#                 try:
#                     data[col + ' Telugu'][i] = anu.anuvaad(data[col][i])
#                 except Exception:
#                     data[col + ' Telugu'][i] = np.nan
#     return data
# new = telugu_use_des()
# print('#'*50+'EBIRD DES'+'#'*50)
# new = new[col_t]
# out(new,'4_2',rep=True)

# %%
# new = telugu_use_des('Wiki_Description')
# print('#'*50+'WIKI DES'+'#'*50)
# new = new[col_t]
# out(new,'4_3',rep=True)

# %%
# new = telugu_use_des('Eol_Description')
# print('#'*50+'EOL DES'+'#'*50)
# new = new[col_t]
# out(new,'4_4',rep=True)

# %%
# new = new[col_t]
# out(new,'5',rep=True)

# %%
# '''DONE'''
# print('%'*100+'AUDIO VIDEO'+'%'*100)

# %%
# !pip install pandas numpy Beautifulsoup4 requests wikidata openpyxl

# %%
# from bs4 import BeautifulSoup
# import pandas as pd
# import csv
# import requests
# import numpy as np
# from wikidata.client import Client


# def get_img(link):
#     if not pd.isna(link):
#         try:
#             client = Client()
#             entity = client.get(link.split('/')[-1], load=True)
#             image_prop = client.get('P18')
#             image = entity[image_prop]
#             t = image.title
#             if 'File:' in t:
#                 imagename = t.strip().split(':')[-1]
#                 return imagename
#             return np.nan
#         except:
#             return np.nan
#     return np.nan

# wikilink = pd.read_csv('/kaggle/input/wikilinks/links.csv')
# from tqdm import tqdm
# wikilink.reset_index(inplace=True)

# %%
# get_img('https://www.wikidata.org/wiki/Q839854')

# %%
# client = Client()
# client.get('https://www.wikidata.org/wiki/Q8061335'.split('/')[-1], load=True)

# %%
# for i in tqdm(range(wikilink.shape[0])):
#     wikilink.loc[i,'image'] = get_img(wikilink.loc[i,'Wikidata_link'])

# %%
# wikilink.to_pickle('assets\Wikidata_Ultimate_Source\link_image.pkl')
# wikilink.to_csv('assets\Wikidata_Ultimate_Source\link_image.csv')
# wikilink.to_excel('assets\Wikidata_Ultimate_Source\link_image.excel')

# %%
# !pip install indic_transliteration -U

# %%
# data = 'idam adbhutam'
# from indic_transliteration import sanscript
# from indic_transliteration.sanscript import SchemeMap, SCHEMES, transliterate

# %%
# print(transliterate(data, sanscript.HK, sanscript.TELUGU))

# %%
# data_link = '/kaggle/input/wikilinks/Birds.csv'

# %%
# import pandas as pd
# import csv
# import numpy as np
# data = pd.read_csv(data_link)
# #

# %%
# data.head(4)

# %%
# data.loc[4,'Bird Original Name']

# %%
# from tqdm import tqdm

# %%
# for i in tqdm(range(data.shape[0])):
#     if not pd.isna(data.loc[i,'Bird Original Name']): 
#         data.loc[i,'Bird Original Name'] = transliterate(data.loc[i,'Bird Original Name'], sanscript.HK, sanscript.TELUGU)

# %%
# data.head(10)

# %%
# scheme_map = SchemeMap(SCHEMES[sanscript.VELTHUIS], SCHEMES[sanscript.TELUGU])
# transliterate("Abbott's Booby", scheme_map=scheme_map)

# %%
# !pip install transly

# %%
# import transly.transliteration as tl

# %%
# QUERY = 'NIKHIL'
# a = tl.load_model(model_path='en2te')
# a.infer(QUERY)

# %%
# from deep_translator import GoogleTranslator

# %%
# ko = GoogleTranslator(source='auto', target='te').translate("Yucatan Rough-winged Swallow")

# %%
# ko

# %%
# data.loc[4,'Bird Original Name']

# %%
# for i in tqdm(range(data.shape[0])):
#     if not pd.isna(data.loc[i,'Bird Original Name']): 
#         data.loc[i,'Name Translate'] = GoogleTranslator(source='auto', target='te').translate(data.loc[i,'Bird Original Name'])

# %%
# data.head(4)

# %%
# data.to_csv('Bird_Names.csv')
# data.to_pickle('Bird_Names.pkl')

# %%
# for i in tqdm(range(data.shape[0])):
#     if not pd.isna(data.loc[i,'Bird Original Name']): 
#         data.loc[i,'Name Translate'] = GoogleTranslator(source='auto', target='te').translate(data.loc[i,'Bird Original Name'])

# %%
# import pandas as pd
# import numpy as np
# from tqdm import tqdm
# from anuvaad import Anuvaad
# from deep_translator import GoogleTranslator
# anu = Anuvaad("english-telugu")
# se = "/kaggle/input/finaldataset/Dataset_final_v3_2.pkl"
# se2 = "/kaggle/input/finaldataset/Dataset_final_v3_2.csv"
# # data = pd.read_pickle(se)
# data = pd.read_csv(se2)
# def anu_vaad_onebyone(para):
#     if len(para) != 0:
#         lis_para = [i.strip() for i in para.strip().split('.') if i != '']
#         anu_lis_para =  anu.anuvaad(lis_para)
#         trans_para = '.'.join(anu_lis_para) + '.'
#         return trans_para
#     return np.nan

# def create_telugu_anuvaad_by_split(col,data):
#     di = {}
#     data[col+' Anuvaad Split Telugu'] = np.nan
#     for i in tqdm(range(0,50)):
#         # print(i)
#         if type(data[col][i]) == float:
#             data[col + ' Anuvaad Split Telugu'][i] = np.nan
#         else:
#             if data[col][i] in di:
#                 data[col + ' Anuvaad Split Telugu'][i] = di[data[col][i]]
#             else:
#                 data[col + ' Anuvaad Split Telugu'][i] = anu_vaad_onebyone(data[col][i])
#                 di[data[col][i]] = data[col + ' Anuvaad Split Telugu'][i]
#     return data

# def google_onebyone(para):
#     if len(para) != 0:
#         try:
#             lis_para = [i.strip() for i in para.strip().split('.') if i != '']
#             gle_lis_para = []
#             for lis_para_line in lis_para:
#                 if lis_para_line:
#                     gle_lis_para.append(GoogleTranslator(source='auto', target='te').translate(lis_para_line))    
#             if len(gle_lis_para) != 0 or not gle_lis_para: 
#                 trans_para = '.'.join(gle_lis_para) + '.'
#                 return trans_para
#         except Exception:
#             return np.nan
#     return np.nan

# def create_telugu_google_by_split(col,data):
#     di = {}
#     data[col+' google Split Telugu'] = np.nan
#     for i in tqdm(range(0,50)):
#         # print(i)
#         if type(data[col][i]) == float:
#             data[col + ' google Split Telugu'][i] = np.nan
#         else:
#             if data[col][i] in di:
#                 data[col + ' google Split Telugu'][i] = di[data[col][i]]
#             else:
#                 data[col + ' google Split Telugu'][i] = google_onebyone(data[col][i])
#                 di[data[col][i]] = data[col + ' google Split Telugu'][i]
#     return data

# # create_telugu_anuvaad_by_split('Ebird_Description',data)
# data.head(5)

# %%
# def create_telugu_google(col,data):
#     di = {}
#     data[col+' google Telugu'] = np.nan
#     for i in tqdm(range(0,50)):
#         # print(i)
#         if type(data[col][i]) == float:
#             data[col + ' google Telugu'][i] = np.nan
#         else:
#             if data[col][i] in di:
#                 data[col + ' google Telugu'][i] = di[data[col][i]]
#             else:
#                 data[col + ' google Telugu'][i] = GoogleTranslator(source='auto', target='te').translate(data[col][i])
#                 di[data[col][i]] = data[col + ' google Telugu'][i]
#     return data

# %%
# def create_telugu_anuvaad(col,data):
#     di = {}
#     data[col+' Anuvaad Telugu'] = np.nan
#     for i in tqdm(range(0,50)):
#         # print(i)
#         if type(data[col][i]) == float:
#             data[col + ' Anuvaad Telugu'][i] = np.nan
#         else:
#             if data[col][i] in di:
#                 data[col + ' Anuvaad Telugu'][i] = di[data[col][i]]
#             else:
#                 data[col + ' Anuvaad Telugu'][i] = anu.anuvaad(data[col][i])
#                 di[data[col][i]] = data[col + ' Anuvaad Telugu'][i]
#     return data

# %%
# text = 'i like me better when i am with you'
# MyMemoryTranslator(source='en', target='te').translate(text)

# %%
# def create_telugu_Memory(col,data):
#     di = {}
#     data[col+' Memory Telugu'] = np.nan
#     for i in tqdm(range(0,50)):
#         # print(i)
#         if type(data[col][i]) == float:
#             data[col + ' Memory Telugu'][i] = np.nan
#         else:
#             if data[col][i] in di:
#                 data[col + ' Memory Telugu'][i] = di[data[col][i]]
#             else:
#                 data[col + ' Memory Telugu'][i] = MyMemoryTranslator(source='en', target='te').translate(data[col][i])
#                 di[data[col][i]] = data[col + ' Memory Telugu'][i]
#     return data

# def memory_onebyone(para):
#     if len(para) != 0:
#         lis_para = [i.strip() for i in para.strip().split('.') if i != '']
#         mem_lis_para = []
#         for lis_para_line in lis_para:
#             if lis_para_line:
#                 mem_lis_para.append(MyMemoryTranslator(source='en', target='te').translate(lis_para_line))
#         if len(mem_lis_para) != 0:
#             trans_para = '.'.join(mem_lis_para) + '.'
#             return trans_para
#     return np.nan

# def create_telugu_memory_by_split(col,data):
#     di = {}
#     data[col+' memory Split Telugu'] = np.nan
#     for i in tqdm(range(0,50)):
#         # print(i)
#         if type(data[col][i]) == float:
#             data[col + ' memory Split Telugu'][i] = np.nan
#         else:
#             if data[col][i] in di:
#                 data[col + ' memory Split Telugu'][i] = di[data[col][i]]
#             else:
#                 data[col + ' memory Split Telugu'][i] = memory_onebyone(data[col][i])
#                 di[data[col][i]] = data[col + ' memory Split Telugu'][i]
#     return data

# %%
# PonsTranslator(source='en', target='te').translate(text)

# %%
# # Ebird_Description
# # Eol_Description
# # Wiki_Description

# # create_telugu_anuvaad_by_split('Ebird_Description',data)
# # create_telugu_anuvaad_by_split('Eol_Description',data)
# # create_telugu_anuvaad_by_split('Wiki_Description',data)

# # create_telugu_google_by_split('Ebird_Description',data)
# # create_telugu_google_by_split('Eol_Description',data)
# # create_telugu_google_by_split('Wiki_Description',data)

# create_telugu_memory_by_split('Ebird_Description',data)
# create_telugu_memory_by_split('Eol_Description',data)
# create_telugu_memory_by_split('Wiki_Description',data)

# create_telugu_google('Ebird_Description',data)
# create_telugu_google('Eol_Description',data)
# create_telugu_google('Wiki_Description',data)


# create_telugu_anuvaad('Ebird_Description',data)
# create_telugu_anuvaad('Eol_Description',data)
# create_telugu_anuvaad('Wiki_Description',data)

# create_telugu_Memory('Ebird_Description',data)
# create_telugu_Memory('Eol_Description',data)
# create_telugu_Memory('Wiki_Description',data)

# %%
# data.head(5)

# %%
# data.to_csv('50des.csv')
# data.to_pickle('50des.pickle')
# data.to_excel('50des.xlsx')

# %% [markdown]
# ## PadmaAwards Wikipedia :p

# %%
print('#'*100 +' PRE PROCESSING '+'#'*100)
# !pip install tqdm pandas numpy openpyxl sweetviz requests anuvaad
# !pip install -U deep-translator
# !pip install wikipedia
print('#'*100 +' GOT ALL REQUIREMENTS '+'#'*100)

# %%
padmaAwards = '/kaggle/input/d2sdgafgh/awards_v3_01_new.xlsx'

import sweetviz as sv
import wikipedia
import requests
import pandas as pd
import numpy as np
from tqdm import tqdm
from time import sleep
from anuvaad import Anuvaad
import random
anu = Anuvaad("english-telugu")

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

awards = pd.read_excel(padmaAwards)
# persons = pd.DataFrame(columns=['Recipients','Summary','awards & honors','career','references','early life'])
# awards['Page Id'] = np.nan

# %%
from deep_translator import (GoogleTranslator,
                             MicrosoftTranslator,
                             PonsTranslator,
                             LingueeTranslator,
                             MyMemoryTranslator,
                             YandexTranslator,
                             PapagoTranslator,
                             DeeplTranslator,
                             QcriTranslator,
                             single_detection,
                             batch_detection)

# %%
def out(ver,data=awards):
    data.to_csv('renders_awards_v4_'+ver+'_Kaggle_out.csv')
    data.to_pickle('renders_awards_v4_'+ver+'_Kaggle_out.pickle')
    data.to_excel('renders_awards_v4_'+ver+'_Kaggle_out.xlsx')


# def get_page_id(link):
#     if not pd.isna(link):
#         k = requests.get(link)
#         st = k.content.decode()
#         lis_s = st.split(',')
#         for i in lis_s:
#             if 'wgArticleId' in i:
#                 l = i.strip().split(':')
#                 return str(l[-1].strip())     
#         return np.nan
#     return np.nan

# def parse_text(text,summ,per_name):
#     d = {}
#     d['Recipients'] = per_name
#     d['Summary'] = summ
#     text = text.replace("===","'''")
#     t = text.split("==")
#     flag  = True
#     ke = []
#     va = []
#     for i in t:
#         i = i.strip()
#         if i != '' and i not in summ :
#             if flag:
#                 ke.append(i)
#                 flag = False
#             else:
#                 va.append(i)
#                 flag = True
#     for i in range(len(va)):
#         d[ke[i].lower()] = va[i]
#     for k,v in zip(d.keys(),d.values()):
#         d[k] = [v]
#     return d

# %%
# print('*'*50+'GETTING PAGE IDs'+'*'*50)

# for i in tqdm(range(awards.shape[0])):
# # for i in tqdm(range(0,5)):
#     per_link = awards['WikiLink'][i]
#     if not pd.isna(per_link):
#         id_of_page = get_page_id(per_link)
# #         print(id_of_page)
#         awards['Page Id'][i] = id_of_page
        
# print('$'*50+'FINISHED :: GETTING PAGE IDs'+'$'*50)

# out('1_03_01_awards_',awards,sw=True)
# awards.head(10)

# %%
# per_name = awards['Recipients'][0]
# person = wikipedia.page(pageid=int(float(awards['Page Id'][0])))
# if awards['WikiLink'][0] == person.url:
#     print('s')
#     wiki_dict = parse_text(person.content,person.summary,per_name)
#     person_df = pd.DataFrame(wiki_dict)
#     persons = pd.concat([persons,person_df])
# persons

# %%
# print('*'*50+'GETTING WIKI CONTENT '+'*'*50)

# for i in tqdm(range(awards.shape[0])):
# # for i in tqdm(range(0,5)):

#     per_name = awards['Recipients'][i]
#     try:
#         if not pd.isna(awards['WikiLink'][i]) and not pd.isna(awards['Page Id'][i]) :
#             person = wikipedia.page(pageid=int(float(awards['Page Id'][i])))
#             if awards['WikiLink'][i] == person.url:
#                 wiki_dict = parse_text(person.content,person.summary,per_name)
#                 person_df = pd.DataFrame(wiki_dict)
#                 persons = pd.concat([persons,person_df])
#             else:
#                 person = wikipedia.page(per_name)
#                 if awards['WikiLink'][i] == person.url:
#                     wiki_dict = parse_text(person.content,person.summary,per_name)
#                     person_df = pd.DataFrame(wiki_dict)
#                     persons = pd.concat([persons,person_df])
#                 else:
#                     person_df = pd.DataFrame({'Recipients':[per_name]})
#                     persons = pd.concat([persons,person_df])
#         else:
#             person_df = pd.DataFrame({'Recipients':[per_name]})
#             persons = pd.concat([persons,person_df])
#     except Exception :
#         person_df = pd.DataFrame({'Recipients':[per_name]})
#         persons = pd.concat([persons,person_df])

# print('$'*50+'FINNISHED :: GETTING WIKI CONTENT '+'$'*50)
# out('1_03_02_persons_',persons,sw=True)
# persons.head(10)

# %%
# l = awards.columns
# new_l = []
# for i in l:
#     if i != 'Recipients' and i!= 'Recipients Telugu' and i!= 'Unnames: 0':
#         new_l.append(i)
#         awards[i+' Telugu'] = np.nan
#         new_l.append(i+' Telugu')
# awards = awards[new_l]
try:
    awards.reset_index(inplace = True)
except Exception:
    pass

# %%
# persons.reset_index(inplace=True)

# print('*'*50+'Translate ANUVAAD '+'*'*50)
# di ={}
# def create_telugu_anuvaad(col,data):
#     data[col+' Telugu'] = np.nan
#     for i in tqdm(range(data.shape[0])):
#         try:
#             if pd.isna(data[col][i]):
#                 data[col + ' Telugu'][i] = np.nan
#             else:
#                 if data[col][i] in di:
#                     data[col + ' Telugu'][i] = di[data[col][i]]
#                 else:
#                     data[col + ' Telugu'][i] = anu.anuvaad(data[col][i])
#                     di[data[col][i]] = data[col + ' Telugu'][i]
#         except Exception:
#             try:
#                 data[col + ' Telugu'][i] = GoogleTranslator(source='auto', target='te').translate(data[col][i])
#             except Exception:
#                 data[col + ' Telugu'][i] = np.nan
#     return data
# awards = create_telugu_anuvaad('Padma Shri Awarded By',data=awards)
# awards = create_telugu_anuvaad('Padma Bhushan Awarded By',data=awards)
# awards = create_telugu_anuvaad('Padma Vibhushan Awarded By',data=awards)
# awards = create_telugu_anuvaad('Nationality',data=awards)
# awards = create_telugu_anuvaad('Spouse',data=awards)

# out('TOP100_01')

# print('$'*50+'Translate ANUVAAD Done'+'$'*50)
# awards.head(10)

# %%
def google_onebyone(para):
    try:
        if pd.isna(para) or type(para) == np.int64:
            return np.nan
        else:
            if len(para) != 0:
                para = para.replace('\n','')
                para = para.replace('\t','')
                para = para.replace('\u200c','')
                lis_para = [i.strip() for i in para.strip().split('.') if i != '']
                gle_lis_para = []
                for lis_para_line in lis_para:
                    if lis_para_line:
                        gle_lis_para.append(GoogleTranslator(source='auto', target='te').translate(lis_para_line))
                if len(gle_lis_para) != 0: 
                    trans_para = '.'.join(gle_lis_para) + '.'
                trans_para = trans_para.replace('\u200c','')
                return trans_para
    except Exception:
        return -1
    return np.nan

def anu_vaad_onebyone(para):
    if len(para) != 0:
        lis_para = [i.strip() for i in para.strip().split('.') if i != '']
        anu_lis_para =  anu.anuvaad(lis_para)
        trans_para = '.'.join(anu_lis_para) + '.'
        return trans_para
    return np.nan
# di = {}

# def create_telugu_google_by_split(col,data=awards):
# #     data[col+' Telugu'] = np.nan
# #     for i in tqdm(range(data.shape[0])):
#     for i in tqdm(range(0,10)):
#         try:
#             sleep(random.randint(0,3))
#             if pd.isna(data[col][i]):
# #                 data[col + ' Telugu'][i] = np.nan
#                 pass
#             else:
# #                 if data[col][i] in di:
# #                     data[col + ' Telugu'][i] = di[data[col][i]]
# #                     pass
# #                 else:
#                 wer = google_onebyone(data[col][i])
#                 if wer != -1:
#                     data[col + ' Telugu'][i] = wer
# #                         di[data[col][i]] = data[col + ' Telugu'][i]
#                 else:
# #                         if data[col][i] in di:
# #                             data[col + ' Telugu'][i] = di[data[col][i]]
# #                         else:
#                     data[col + ' Telugu'][i] = anu_vaad_onebyone(data[col][i])
# #                         di[data[col][i]] = data[col + ' Telugu'][i]
                        
#         except Exception as e:
#             print('!'+'-'*20+'ERR')
#             print(e)
# #             return np.nan
#     return data

# %%
def clean_format(text):
    text  =text.replace('..','.')
    text = text.replace('మరియు',",")
    text = text.replace('యొక్క',",")
    text = text.replace('అతను',"ఇతను")
    text = text.replace('ఆమె',"ఈమె")
    text = text.replace(',',", ")
    text = text.replace('.',". ")
    text = text.replace('..',".")
    text = text.replace('..',".")
    text = text.replace(',.',".")
    text = text.replace('.,',".")
    text = text.replace('..','.')
    text = text.replace(',.',".")
    text = text.replace('.,',".")
    text = text.replace(' . ',". ")
    text = text.replace(' , ',", ")
    text = text.replace(' . ',". ")
    text = text.replace(' , ',", ")
    text = text.replace('  '," ")
    return text

def create_telugu_google_by_split(col,data,f,t):
    data[col+' Telugu'] = np.nan
    for i in tqdm(range(f,t)):
        try:
            sleep(random.randint(0,3))
            if not pd.isna(data[col][i]):
                wer = google_onebyone(data[col][i])
                if wer != -1:
                    data[col + ' Telugu'][i] = clean_format(wer)
                else:
                    data[col + ' Telugu'][i] = anu_vaad_onebyone(data[col][i])
        except Exception as e:
            print('!'+'-'*20+'ERR')
            print(e)
    return data

# %%
# para = '''Avtar Kishan Hangal (1 February 1914 – 26 August 2012; Sialkot, Punjab) was an Indian freedom fighter from 1929 to 1947 and also stage actor from 1936 to 1965 and later became a character actor in Hindi language films from 1966 to 2005. His most notable roles are as Ram Shastri in Aaina (1977), as the Inder Sen in Shaukeen, as Bipinlal Pandey in Namak Haraam, as Imaam Saa'b in Sholay, as Anokhelal in Manzil and the antagonist in Prem Bandhan and the 16 films he did with Rajesh Khanna. He has acted in around 225 Hindi films in a career spanning from 1966 to 2005.'''

# para = para.replace('\n','')
# para = para.replace('\t','')
# para = para.replace('\u200c','')
# lis_para = [i.strip() for i in para.strip().split('.') if i != '']
# gle_lis_para = []
# for lis_para_line in lis_para:
#     if lis_para_line:
#         gle_lis_para.append(GoogleTranslator(source='auto', target='te').translate(lis_para_line))
# if len(gle_lis_para) != 0: 
#     trans_para = '.'.join(gle_lis_para) + '.'
# trans_para = trans_para.replace('\u200c','')


# clean_format(trans_para)

# %%
awards.head(10)

# %%
# print('*'*50+'Translate Google Summary '+'*'*50)
# step = 50
# ci = 0 
# try:
#     while ci + step < awards.shape[0] :
#         awards = create_telugu_google_by_split('Summary',awards,ci,ci+step)
#         ci += step
#     awards = create_telugu_google_by_split('Summary',awards,ci,awards.shape[0])
# except Exception as e:
#     print(e)
# print('$'*50+'FIN :: Translate Google Summary '+'$'*50)

# out('TOP10_02')
# awards.head(10)

# %%
awards['Summary Telugu'][9]

# %%
print('*'*50+'Translate Google career '+'*'*50)
step = 40
ci = 0 
try:
    while ci + step < awards.shape[0] :
        awards = create_telugu_google_by_split('career',awards,ci,ci+step)
        ci += step
    awards = create_telugu_google_by_split('career',awards,ci,awards.shape[0])
except Exception as e:
    print(e)
print('$'*50+'FIN :: Translate Google career '+'$'*50)

out('_03_career')
awards.head(10)

# %%
print('*'*50+'Translate Google awards & honors'+'*'*50)
step = 50
ci = 0 
try:
    while ci + step < awards.shape[0] :
        awards = create_telugu_google_by_split('awards & honors',awards,ci,ci+step)
        ci += step
    awards = create_telugu_google_by_split('awards & honors',awards,ci,awards.shape[0])
except Exception as e:
    print(e)
print('$'*50+'FIN :: Translate Google awards & honors '+'$'*50)

out('_04_awards')
awards.head(10)

# %%
print('*'*50+'Translate Google early life '+'*'*50)
step = 100
ci = 0 
try:
    while ci + step < awards.shape[0] :
        awards = create_telugu_google_by_split('early life',awards,ci,ci+step)
        ci += step
    awards = create_telugu_google_by_split('early life',awards,ci,awards.shape[0])
except Exception as e:
    print(e)
print('$'*50+'FIN :: Translate Google early life '+'$'*50)

out('_05')

print('DONE !')
awards.head(10)
