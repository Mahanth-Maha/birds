# %%
# %pip install --upgrade deeptranslit
# Out:
# ...
#   Using cached deeptranslit-1.1.1-py2.py3-none-any.whl (16 kB)
# ...
#   Using cached pydload-1.0.9-py2.py3-none-any.whl (16 kB)
# ...
#   Using cached txt2txt-1.1.2-py2.py3-none-any.whl (18 kB)
# ...
#   Using cached progressbar2-4.0.0-py2.py3-none-any.whl (26 kB)
# ...
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# ...
#   Using cached python_utils-3.1.0-py2.py3-none-any.whl (19 kB)
# ...
#   Using cached charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# ...
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# ...
#   Using cached urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
# ...
#   Using cached keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# from deeptranslit import DeepTranslit
# Out:
# WARNING:tensorflow:From C:\Users\LEGION\anaconda3\envs\deeptrasnlit\lib\site-packages\txt2txt\txt2txt.py:10: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
# Using TensorFlow backend.

# %%
# %pip install keras==2.2.4
# Out:
# ...
#   Using cached Keras-2.2.4-py2.py3-none-any.whl (312 kB)
# ...
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Telugu
# transliterator = DeepTranslit('telugu')
# Out:
# Loading the params file
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5916\1094023959.py in <module>
#       1 # Telugu
# ----> 2 transliterator = DeepTranslit('telugu')
#
# ~\anaconda3\envs\deeptrasnlit\lib\site-packages\deeptranslit\deeptranslit.py in __init__(self, lang_code)
#      92
#      93         self.model, self.params = build_model(params_path=params_path, enc_lstm_units=64, use_gru=True, display_summary=False)
# ---> 94         self.model.load_weights(checkpoint_path)
#      95
#      96
#
# ~\anaconda3\envs\deeptrasnlit\lib\site-packages\keras\engine\network.py in load_weights(self, filepath, by_name, skip_mismatch, reshape)
#    1164             else:
#    1165                 saving.load_weights_from_hdf5_group(
# -> 1166                     f, self.layers, reshape=reshape)
#    1167
#    1168     def _updated_config(self):
#
# ...

# %%
# # Single sentence prediction
# transliterator.transliterate('maha anu nenu...')

# %%
# %pip uninstall googletrans
# %pip install googletrans==4.0.0-rc1
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import googletrans

# %%
googletrans.LANGUAGES['te']
# Out:
# 'telugu'

# %%
translator = googletrans.Translator()

# %%
translated = translator.translate('maha anu nenu...',src='english',dest='telugu')
translated.text
# Out:
# 'మహా అయు నను ...'

# %%
from googletrans import Translator
def trans_tel(text):
    tr = Translator()
    t = tr.translate(text,dest='telugu',src='english')
    return t.text
trans_tel('just like animals')
# Out:
# 'కేవలం జంతువులు వంటి'

# %%
import anuvaad
# anuvaad.__doc__

# %%
from anuvaad import Anuvaad
anu = Anuvaad("english-telugu")

# %%
anu.anuvaad('maha ane nenu...')
# Out:
# 'మహా అనే నేను...'

# %%
trans_tel('flight')
# Out:
# 'విమాన.'

# %%
anu.anuvaad('flight')
# Out:
# 'ఫ్లైట్'

# %%
def comp_trans(sample_text = 'ram ram setji'):
    gpre = trans_tel(sample_text)
    apre = anu.anuvaad(sample_text)
    print('Google : ',gpre)
    print('Anuvaad : ',apre)
    if gpre != apre:
        print("BOTH R NOT SAME 🦁 !") 
    else:
        print('🟰 | TIE ')
    return (gpre,apre)
comp_trans()
# Out:
# Google :  రామ్ రామ్ సెట్జీ
# Anuvaad :  రామ్ రామ్ సెట్జీ
# 🟰 | TIE
# ('రామ్ రామ్ సెట్జీ', 'రామ్ రామ్ సెట్జీ')

# %%
comp_trans('forest')
# Out:
# Google :  అడవి
# Anuvaad :  అడవి
# 🟰 | TIE
# ('అడవి', 'అడవి')

# %%
comp_trans('Pellorneidae')
# Out:
# Google :  Pellornelea.
# Anuvaad :  పెల్లోర్నీడే
# BOTH R NOT SAME 🦁 !
# ('Pellornelea.', 'పెల్లోర్నీడే')

# %% [markdown]
# ## using anuvaad rather than google

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
data = pd.read_pickle('../Week1_Strucured_Data_Gen/Dataset_v1_06.pkl')
data.head(4)

# %%
import numpy as np

# %%
data['Bird Name Telugu'] = np.nan
data['Bird Name Telugu'][0]
# Out:
# nan

# %%
for i in range(data.shape[0]):
    data['Bird Name Telugu'][i] = anu.anuvaad(data['Bird Name'][i])
data.head(5)
# Out:
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_22460\3693747903.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Bird Name Telugu'][i] = anu.anuvaad(data['Bird Name'][i])
# ...

# %%
# %pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data.to_pickle('data_v1_name_anuvaad.pkl')
data.to_csv('data_v1_name_anuvaad.csv')
data.to_excel('data_v1_name_anuvaad.xlsx')

# %%
# %pip install tqdm
# from tqdm import tqdm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data.head(4)
# Out:
#          Bird Name         Binomial Name                             Synonyms                            Old latin name for bird   Kingdom Subkingdom   Infrakingdom    Phylum   Subphylum    Infraphylum Superclass Class          Order         Family                          Genus       Species Conservation status Habitat           Country geographic distribution includes biogeographic realm population trend Breeding region  Breeding subregion visual system      auditory system hearing range hearing threshold        locomotion mineralized skeleton contains body mass                                          Wiki_Link                                              Image                                         References                                   Wiki_Description                         Ebird_Link                                  Ebird_Description                        Eol_Link                                    Eol_Description                                   Dibird_Link
# ...

# %%
# %pip install tqdm
from tqdm import tqdm
def create_telugu_col(col = 'Binomial Name',data=data):
    data[col+ ' Telugu'] = np.nan
    for i in tqdm(range(data.shape[0])):
        # print(i)
        if type(data[col][i]) == float:
            data[col + ' Telugu'][i] = np.nan
        else:
            data[col + ' Telugu'][i] = anu.anuvaad(data[col][i])
    return data

data = create_telugu_col(data=data)
data.head(5)
# Out:
#   0%|          | 0/11099 [00:00<?, ?it/s]C:\Users\LEGION\AppData\Local\Temp\ipykernel_18404\3706920061.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col + ' Telugu'][i] = anu.anuvaad(data[col][i])
# 100%|██████████| 11099/11099 [5:24:02<00:00,  1.75s/it]
# ...

# %%
data[['Binomial Name','Binomial Name Telugu']]
# Out:
#                    Binomial Name      Binomial Name Telugu
# 0           Malacocincla abbotti      మాలాకోసిన్లా అబ్బోటి
# 1               Papasula abbotti           పాపసులా అబ్బోటి
# 2            Poeoptera femoralis       పూపెట్రా ఫెటోరిలిస్
# 3                            NaN                       NaN
# 4              Passer hemileucus          పాసర్ హెమిలేయుస్
# ...                          ...                       ...
# 11094       Ploceus castaneiceps       ప్లాసస్ కాస్టనెటిస్
# 11095     Arizelocichla neumanni   అరిజెలోసిచ్లా న్యూమన్ని
# 11096  Arizelocichla tephrolaema  అరిజెలోసిక్లా టెఫ్రోలియా
# 11097      Oriolus brachyrynchus     ఒరియోస్ బ్రచిరిన్చుస్
# 11098             Anthus nyassae             ఆంథస్ న్యాససే
#
# [11099 rows x 2 columns]

# %%
data.to_pickle('data_v2_Bname_anuvaad.pkl')
data.to_csv('data_v2_Bname_anuvaad.csv')
data.to_excel('data_v2_Bname_anuvaad.xlsx')

# %%
data = create_telugu_col(col='Species',data=data)
data.head(5)
# Out:
#   0%|          | 0/11099 [00:00<?, ?it/s]C:\Users\LEGION\AppData\Local\Temp\ipykernel_18404\3706920061.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col + ' Telugu'][i] = anu.anuvaad(data[col][i])
# 100%|██████████| 11099/11099 [5:16:59<00:00,  1.71s/it]
# ...

# %%
data.to_pickle('data_v3_Spe_anuvaad.pkl')
data.to_csv('data_v3_Spe_anuvaad.csv')
data.to_excel('data_v3_Spe_anuvaad.xlsx')

# %%
import numpy as np
from tqdm import tqdm
def create_telugu_col(col = 'Binomial Name',data=data):
    data[col+ ' Telugu'] = np.nan
    for i in tqdm(range(data.shape[0])):
        # print(i)
        if type(data[col][i]) == float:
            data[col + ' Telugu'][i] = np.nan
        else:
            data[col + ' Telugu'][i] = anu.anuvaad(data[col][i])
    return data

# %%
data = pd.read_pickle('data_v3_Spe_anuvaad.pkl')
data.head(4)
# Out:
#          Bird Name         Binomial Name                             Synonyms                            Old latin name for bird   Kingdom Subkingdom   Infrakingdom    Phylum   Subphylum    Infraphylum Superclass Class          Order         Family                          Genus       Species Conservation status Habitat           Country geographic distribution includes biogeographic realm population trend Breeding region  Breeding subregion visual system      auditory system hearing range hearing threshold        locomotion mineralized skeleton contains body mass                                          Wiki_Link                                              Image                                         References                                   Wiki_Description                         Ebird_Link                                  Ebird_Description                        Eol_Link                                    Eol_Description                                   Dibird_Link  \
# ...

# %%
data = create_telugu_col(col='Old latin name for bird',data=data)
data.head(5)
# Out:
#   0%|          | 0/11099 [00:00<?, ?it/s]C:\Users\LEGION\AppData\Local\Temp\ipykernel_12084\3571053756.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col + ' Telugu'][i] = np.nan
#   0%|          | 1/11099 [00:00<2:06:33,  1.46it/s]C:\Users\LEGION\AppData\Local\Temp\ipykernel_12084\3571053756.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col + ' Telugu'][i] = anu.anuvaad(data[col][i])
# 100%|██████████| 11099/11099 [8:18:49<00:00,  2.70s/it]
# ...

# %%
data.to_pickle('data_v4_Latin_anuvaad.pkl')
data.to_csv('data_v4_Latin_anuvaad.csv')
data.to_excel('data_v4_Latin_anuvaad.xlsx')

# %%
data = create_telugu_col(col='Habitat',data=data)
data.head(5)
# Out:
#   0%|          | 0/11099 [00:00<?, ?it/s]C:\Users\LEGION\AppData\Local\Temp\ipykernel_12084\3571053756.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col + ' Telugu'][i] = anu.anuvaad(data[col][i])
# 100%|██████████| 11099/11099 [2:52:55<00:00,  1.07it/s]
# ...

# %%
data.to_pickle('data_v5_habitat_anuvaad.pkl')
data.to_csv('data_v5_habitat_anuvaad.csv')
data.to_excel('data_v5_habitat_anuvaad.xlsx')
